# %% [markdown]
# 总榜性别画像

# %%
pip pyecharts
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: unknown command "pyecharts"

# %%
#input the need tools
from pyecharts.charts import Pie
from pyecharts import options as opts
from pyecharts.charts import Pie
import pandas as pd

# %%
#read the data base
data=pd.read_csv('e:\Microsoft VS Code\原创榜清理后的数据（性别）.csv',header=None,names=['nickname','user_id','age','gender','city','signature','content','comment_id','like_count','comment_time'],encoding='utf-8-sig')

# %%
# 填充 NaN 值
data['gender'] = data['gender'].fillna(0)  # 或者选择其他合适的默认值
# 转换 gender 列为整数
data['gender'] = data['gender'].astype(int)

# %%
data.sample(10)#随机抽取10个查看
# Out:
#          nickname     user_id age  gender  city  \
# 2206         承辈yu  1719369707   无       1    未知
# 2065      Dgh不迷糊版   409900050   无       1   长沙市
# 5097    格局之美U自带光芒   538059725   无       1   陇南市
# 2835  stilljJCole   426710375   无       1    未知
# 2616  德鲁大叔andkeys  1523484935  21       1  葫芦岛市
# 1817   onmyyouthv  1706363457   无       2   大连市
# 3416      超爱富贵啊啊啊  1437537380  20       2   上饶市
# 2885         -引玉-  1746085601   无       2    未知
# 3130        烤红薯小猫   530716262  20       2   衡水市
# 955          歌手李锐    12716577  35       1   聊城市
#
#                                               signature  \
# 2206                                                NaN
# 2065                                              做一个少年
# 5097                                                NaN
# 2835                     She made me real like Jermaine
# 2616                                               哔不哔不
# 1817                                          流星自有来去之处。
# 3416                                                NaN
# 2885                                                NaN
# 3130                                            天天开心^_^
# 955   李锐，89年生于山东的摩羯男，沉闷木讷，心如深海。 2011年背一把吉他离家开始，浪迹山河城...
#
#                                                 content    comment_id  \
# 2206                                   我这是之前评论的，你翻到下面来了  3.123401e+09
# 2065  肯定不是一个档次啦，就是打个比方啦，陈和王年轻的时候也没有自己写太多歌啦。   是不是打着复...  3.171301e+09
# 5097                                                 依然  4.736703e+08
# 2835                                        原创有花粥???我佛了  1.520089e+09
# 2616                                          红色！！（喊破音）  1.608125e+09
# 1817                                         意别第二啊啊啊啊冲啊  3.309659e+09
# 3416                                   黄明昊啊啊啊超好听的！！麻麻爱你  1.294151e+09
# 2885                                         有她的《浮白》，口区  1.503911e+09
# 3130                                               绿色绿色  1.401515e+09
# 955                              恶魔不要啊居然乱入了。。。哭晕在厕所[大哭]  1.557634e+07
#
#      like_count     comment_time
# 2206          0  2020/1/20 10:58
# 2065          4  2020/2/24 23:31
# 5097          2  2017/7/16 17:08
# 2835          3  2019/6/12 13:57
# 2616          8  2019/8/24 19:44
# 1817          2  2020/5/14 23:18
# 3416          1  2018/11/8 15:49
# 2885          0  2019/5/28 19:41
# 3130          1  2019/2/23 21:05
# 955           2  2015/4/18 20:18

# %%
#分组汇总
gender_message=data.groupby(['gender'])
gender_com=gender_message['gender'].agg(['count'])
gender_com.reset_index(inplace=True)
attr=['男','女']
v1=gender_com['count']
v1=v1[1:3]
pie = (
    Pie()
    .add("", [list(z) for z in zip(attr, v1)], radius=[40, 75], label_opts=opts.LabelOpts(is_show=True,formatter="{b}:{d}%"))
    .set_global_opts(title_opts=opts.TitleOpts(title="评论用户的性别情况", pos_left='center', pos_top='10%'),
                     legend_opts=opts.LegendOpts(orient="vertical", pos_left="left", pos_top="10%"))
)
pie.render("评论用户的性别情况.html")
# Out:
# 'e:\\Microsoft VS Code\\评论用户的性别情况.html'

# %% [markdown]
# 2013-2016性别画像

# %%
#read the data base
data=pd.read_csv('e:/Microsoft VS Code/2013-2016gender.csv',header=None,names=['nickname','user_id','age','gender','city','signature','content','comment_id','like_count','comment_time'],encoding='utf-8-sig')

# %%
data.sample(10)#随机抽取10个查看
# Out:
#              nickname user_id age gender             city  \
# happy_UjGn   67871068      21   2    合肥市      ヽ(=^･ω･^=)丿
# Abby0405    307732781      26   2    杭州市              NaN
# 九千的吉他        47076733      35   1     未知         别吵吵，好好听歌
# 三年二班柠檬精     121519447       无   1     未知              NaN
# 捆星星         357831192       无   1     未知           .. ...
# 象风_D         71215633       无   1     未知              NaN
# Yi丢          85129119      34   1    沈阳市   你给我点阳光 我就得瑟起来咯
# MissG且听风吟   382846843       无   2     未知              NaN
# 抱着姑娘的盒子      47237703       无   2    镇江市  让我们面对现实，让我们忠于理想
# 不都媽生的___    105368250       无   1    达州市         你可以随时离开/
#
#                                                     signature    content  \
# happy_UjGn  留个名 万一有人一不小心点了我头像 进了我歌单 猛然发现咋这么好听 果断收藏 还粉我 缘分这...  188303892
# Abby0405                                              满舒克说唱最屌  261904635
# 九千的吉他                                  段同愿的想象力很赞，慢慢品[强][强][强]   51132170
# 三年二班柠檬精     把12月份所有赞雷子的评论都赞了一遍，没别的，只想说雷子是最棒的独立音乐人～缘分也是个怪东西...  274512023
# 捆星星                                                       听听我  261952042
# 象风_D                                       原创榜以推荐优秀独立音乐人作品为目的  173477307
# Yi丢                                                  [大哭]大爱苦艾   45646643
# MissG且听风吟                                              八十年代的歌  270365012
# 抱着姑娘的盒子                                               耶！归乡第一！   40991196
# 不都媽生的___                                    草东 牛逼[大哭][大哭][大哭]  159696096
#
#            comment_id        like_count  comment_time
# happy_UjGn          5   2016/7/25 17:23           NaN
# Abby0405            4    2016/12/9 8:57           NaN
# 九千的吉他               2   2015/12/3 22:29           NaN
# 三年二班柠檬精             7  2016/12/27 19:24           NaN
# 捆星星                 4    2016/12/9 2:24           NaN
# 象风_D                1   2016/6/24 12:14           NaN
# Yi丢                 1   2015/11/8 21:56           NaN
# MissG且听风吟           7  2016/12/21 23:02           NaN
# 抱着姑娘的盒子             3  2015/10/15 21:11           NaN
# 不都媽生的___            1   2016/5/25 11:31           NaN

# %%
#分组汇总
gender_message=data.groupby(['gender'])
gender_com=gender_message['gender'].agg(['count'])
gender_com.reset_index(inplace=True)
attr=['男','女']
v1=gender_com['count']
v1=v1[1:3]
pie = (
    Pie()
    .add("", [list(z) for z in zip(attr, v1)], radius=[40, 75], label_opts=opts.LabelOpts(is_show=True,formatter="{b}:{d}%"))
    .set_global_opts(title_opts=opts.TitleOpts(title="2013-2016评论用户的性别情况", pos_left='center', pos_top='10%'),
                     legend_opts=opts.LegendOpts(orient="vertical", pos_left="left", pos_top="10%"))
)
pie.render("2013-2016评论用户的性别情况.html")
# Out:
# 'e:\\Microsoft VS Code\\2013-2016评论用户的性别情况.html'

# %% [markdown]
# 2017-2020评论用户性别画像

# %%
#read the data base
data=pd.read_csv('e:/Microsoft VS Code/2017-2020gender.csv',header=None,names=['nickname','user_id','age','gender','city','signature','content','comment_id','like_count','comment_time'],encoding='utf-8-sig')

# %%
#分组汇总
gender_message=data.groupby(['gender'])
gender_com=gender_message['gender'].agg(['count'])
gender_com.reset_index(inplace=True)
attr=['男','女']
v1=gender_com['count']
v1=v1[1:3]
pie = (
    Pie()
    .add("", [list(z) for z in zip(attr, v1)], radius=[40, 75], label_opts=opts.LabelOpts(is_show=True,formatter="{b}:{d}%"))
    .set_global_opts(title_opts=opts.TitleOpts(title="2017-2020评论用户的性别情况", pos_left='center', pos_top='10%'),
                     legend_opts=opts.LegendOpts(orient="vertical", pos_left="left", pos_top="10%"))
)
pie.render("2017-2020评论用户的性别情况.html")
# Out:
# 'e:\\Microsoft VS Code\\2017-2020评论用户的性别情况.html'

# %% [markdown]
# 2021-2024评论用户性别画像

# %%
#read the data base
data=pd.read_csv('e:/Microsoft VS Code/2021-2024gender.csv',header=None,names=['nickname','user_id','age','gender','city','signature','content','comment_id','like_count','comment_time'],encoding='utf-8-sig')

# %%
#分组汇总
gender_message=data.groupby(['gender'])
gender_com=gender_message['gender'].agg(['count'])
gender_com.reset_index(inplace=True)
attr=['男','女']
v1=gender_com['count']
v1=v1[1:3]
pie = (
    Pie()
    .add("", [list(z) for z in zip(attr, v1)], radius=[40, 75], label_opts=opts.LabelOpts(is_show=True,formatter="{b}:{d}%"))
    .set_global_opts(title_opts=opts.TitleOpts(title="2021-2024评论用户的性别情况", pos_left='center', pos_top='10%'),
                     legend_opts=opts.LegendOpts(orient="vertical", pos_left="left", pos_top="10%"))
)
pie.render("2021-2024评论用户的性别情况.html")
# Out:
# 'e:\\Microsoft VS Code\\2021-2024评论用户的性别情况.html'
