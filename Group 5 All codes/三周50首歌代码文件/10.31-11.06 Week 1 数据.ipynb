# %%
import json
import time
import requests

headers = {
    'Host': 'music.163.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
}

def get_comments(page):
    """获取评论信息"""
    # 评论API地址
    url = 'http://music.163.com/api/v1/resource/comments/R_SO_4_2640767680?limit=100&offset=' + str(page)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    result = json.loads(response.text)
    # 只提取comments的内容
    items = result['comments']
    for item in items:
        # 用户ID
        user_id = str(item['user']['userId'])
        # 4、评论时间
        pub_time = item['time']
        pub_time = time.strftime("%Y-%m-%d", time.localtime(pub_time / 1000))
        # 获取用户信息
        user_message = get_user(user_id)
        # 用户年龄
        user_age = str(user_message['age'])
        # 用户性别
        user_gender = str(user_message['gender'])
        # 用户所在地区
        user_city = str(user_message['city'])
        # 保存到本地
        with open('comments_data.csv', 'a', encoding='utf-8-sig') as f:
            f.write(user_id + ',' + pub_time +',' + user_age + ',' + user_gender + ',' + user_city + ','  +'\n')


def get_user(user_id):
    """ 获取用户注册时间"""
    data = {}
    # 用户API
    url = 'https://music.163.com/api/v1/user/detail/' + str(user_id)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    js = json.loads(response.text)
    if js['code'] == 200:
        # 性别
        data['gender'] = js['profile']['gender']
        # 年龄
        if int(js['profile']['birthday']) < 0:
            data['age'] = 0
        else:
            data['age'] = (2018 - 1970) - (int(js['profile']['birthday']) // (1000 * 365 * 24 * 3600))
        if int(data['age']) < 0:
            data['age'] = 0
        # 城市
        data['city'] = js['profile']['city']
    else:
        data['gender'] = '无'
        data['age'] = '无'
        data['city'] = '无'
    return data

def main():
    for i in range(0, 1050, 20):
        print('\n---------------第 ' + str(i // 20 + 1) + ' 页---------------')
        get_comments(i)

if __name__ == '__main__':
    main()
# Out:
# ---------------第 1 页---------------
#
# ---------------第 2 页---------------
#
# ---------------第 3 页---------------
#
# ---------------第 4 页---------------
#
# ---------------第 5 页---------------
#
# ---------------第 6 页---------------
#
# ---------------第 7 页---------------
#
# ---------------第 8 页---------------
#
# ---------------第 9 页---------------
#
# ---------------第 10 页---------------
#
# ---------------第 11 页---------------
#
# ---------------第 12 页---------------
#
# ---------------第 13 页---------------
#
# ---------------第 14 页---------------
#
# ---------------第 15 页---------------
#
# ---------------第 16 页---------------
#
# ---------------第 17 页---------------
#
# ---------------第 18 页---------------
#
# ---------------第 19 页---------------
#
# ---------------第 20 页---------------
#
# ---------------第 21 页---------------
#
# ---------------第 22 页---------------
#
# ---------------第 23 页---------------
#
# ---------------第 24 页---------------
#
# ---------------第 25 页---------------
#
# ---------------第 26 页---------------
#
# ---------------第 27 页---------------
#
# ---------------第 28 页---------------
#
# ---------------第 29 页---------------
#
# ---------------第 30 页---------------
#
# ---------------第 31 页---------------
#
# ---------------第 32 页---------------
#
# ---------------第 33 页---------------
#
# ---------------第 34 页---------------
#
# ---------------第 35 页---------------
#
# ---------------第 36 页---------------
#
# ---------------第 37 页---------------
#
# ---------------第 38 页---------------
#
# ---------------第 39 页---------------
#
# ---------------第 40 页---------------
#
# ---------------第 41 页---------------
#
# ---------------第 42 页---------------
#
# ---------------第 43 页---------------
#
# ---------------第 44 页---------------
#
# ---------------第 45 页---------------
#
# ---------------第 46 页---------------
#
# ---------------第 47 页---------------
#
# ---------------第 48 页---------------
#
# ---------------第 49 页---------------
#
# ---------------第 50 页---------------
#
# ---------------第 51 页---------------
#
# ---------------第 52 页---------------
#
# ---------------第 53 页---------------

# %%
import json
import time
import requests

headers = {
    'Host': 'music.163.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
}

def get_comments(page):
    """获取评论信息"""
    # 评论API地址
    url = 'http://music.163.com/api/v1/resource/comments/R_SO_4_2638568962?limit=100&offset=' + str(page)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    result = json.loads(response.text)
    # 只提取comments的内容
    items = result['comments']
    for item in items:
        # 用户ID
        user_id = str(item['user']['userId'])
        # 4、评论时间
        pub_time = item['time']
        pub_time = time.strftime("%Y-%m-%d", time.localtime(pub_time / 1000))
        # 获取用户信息
        user_message = get_user(user_id)
        # 用户年龄
        user_age = str(user_message['age'])
        # 用户性别
        user_gender = str(user_message['gender'])
        # 用户所在地区
        user_city = str(user_message['city'])
        # 保存到本地
        with open('comments_data2.csv', 'a', encoding='utf-8-sig') as f:
            f.write(user_id + ',' + pub_time +',' + user_age + ',' + user_gender + ',' + user_city + ','  +'\n')


def get_user(user_id):
    """ 获取用户注册时间"""
    data = {}
    # 用户API
    url = 'https://music.163.com/api/v1/user/detail/' + str(user_id)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    js = json.loads(response.text)
    if js['code'] == 200:
        # 性别
        data['gender'] = js['profile']['gender']
        # 年龄
        if int(js['profile']['birthday']) < 0:
            data['age'] = 0
        else:
            data['age'] = (2018 - 1970) - (int(js['profile']['birthday']) // (1000 * 365 * 24 * 3600))
        if int(data['age']) < 0:
            data['age'] = 0
        # 城市
        data['city'] = js['profile']['city']
    else:
        data['gender'] = '无'
        data['age'] = '无'
        data['city'] = '无'
    return data

def main():
    for i in range(0, 1050, 20):
        print('\n---------------第 ' + str(i // 20 + 1) + ' 页---------------')
        get_comments(i)

if __name__ == '__main__':
    main()
# Out:
# ---------------第 1 页---------------
#
# ---------------第 2 页---------------
#
# ---------------第 3 页---------------
#
# ---------------第 4 页---------------
#
# ---------------第 5 页---------------
#
# ---------------第 6 页---------------
#
# ---------------第 7 页---------------
#
# ---------------第 8 页---------------
#
# ---------------第 9 页---------------
#
# ---------------第 10 页---------------
#
# ---------------第 11 页---------------
#
# ---------------第 12 页---------------
#
# ---------------第 13 页---------------
#
# ---------------第 14 页---------------
#
# ---------------第 15 页---------------
#
# ---------------第 16 页---------------
#
# ---------------第 17 页---------------
#
# ---------------第 18 页---------------
#
# ---------------第 19 页---------------
#
# ---------------第 20 页---------------
#
# ---------------第 21 页---------------
#
# ---------------第 22 页---------------
#
# ---------------第 23 页---------------
#
# ---------------第 24 页---------------
#
# ---------------第 25 页---------------
#
# ---------------第 26 页---------------
#
# ---------------第 27 页---------------
#
# ---------------第 28 页---------------
#
# ---------------第 29 页---------------
#
# ---------------第 30 页---------------
#
# ---------------第 31 页---------------
#
# ---------------第 32 页---------------
#
# ---------------第 33 页---------------
#
# ---------------第 34 页---------------
#
# ---------------第 35 页---------------
#
# ---------------第 36 页---------------
#
# ---------------第 37 页---------------
#
# ---------------第 38 页---------------
#
# ---------------第 39 页---------------
#
# ---------------第 40 页---------------
#
# ---------------第 41 页---------------
#
# ---------------第 42 页---------------
#
# ---------------第 43 页---------------
#
# ---------------第 44 页---------------
#
# ---------------第 45 页---------------
#
# ---------------第 46 页---------------
#
# ---------------第 47 页---------------
#
# ---------------第 48 页---------------
#
# ---------------第 49 页---------------
#
# ---------------第 50 页---------------
#
# ---------------第 51 页---------------
#
# ---------------第 52 页---------------
#
# ---------------第 53 页---------------

# %%
import json
import time
import requests

headers = {
    'Host': 'music.163.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
}

def get_comments(page):
    """获取评论信息"""
    # 评论API地址
    url = 'http://music.163.com/api/v1/resource/comments/R_SO_4_2640855515?limit=100&offset=' + str(page)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    result = json.loads(response.text)
    # 只提取comments的内容
    items = result['comments']
    for item in items:
        # 用户ID
        user_id = str(item['user']['userId'])
        # 4、评论时间
        pub_time = item['time']
        pub_time = time.strftime("%Y-%m-%d", time.localtime(pub_time / 1000))
        # 获取用户信息
        user_message = get_user(user_id)
        # 用户年龄
        user_age = str(user_message['age'])
        # 用户性别
        user_gender = str(user_message['gender'])
        # 用户所在地区
        user_city = str(user_message['city'])
        # 保存到本地
        with open('comments_data3.csv', 'a', encoding='utf-8-sig') as f:
            f.write(user_id + ',' + pub_time +',' + user_age + ',' + user_gender + ',' + user_city + ','  +'\n')


def get_user(user_id):
    """ 获取用户注册时间"""
    data = {}
    # 用户API
    url = 'https://music.163.com/api/v1/user/detail/' + str(user_id)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    js = json.loads(response.text)
    if js['code'] == 200:
        # 性别
        data['gender'] = js['profile']['gender']
        # 年龄
        if int(js['profile']['birthday']) < 0:
            data['age'] = 0
        else:
            data['age'] = (2018 - 1970) - (int(js['profile']['birthday']) // (1000 * 365 * 24 * 3600))
        if int(data['age']) < 0:
            data['age'] = 0
        # 城市
        data['city'] = js['profile']['city']
    else:
        data['gender'] = '无'
        data['age'] = '无'
        data['city'] = '无'
    return data

def main():
    for i in range(0, 1050, 20):
        print('\n---------------第 ' + str(i // 20 + 1) + ' 页---------------')
        get_comments(i)

if __name__ == '__main__':
    main()
# Out:
# ---------------第 1 页---------------
#
# ---------------第 2 页---------------
#
# ---------------第 3 页---------------
#
# ---------------第 4 页---------------
#
# ---------------第 5 页---------------
#
# ---------------第 6 页---------------
#
# ---------------第 7 页---------------
#
# ---------------第 8 页---------------
#
# ---------------第 9 页---------------
#
# ---------------第 10 页---------------
#
# ---------------第 11 页---------------
#
# ---------------第 12 页---------------
#
# ---------------第 13 页---------------
#
# ---------------第 14 页---------------
#
# ---------------第 15 页---------------
#
# ---------------第 16 页---------------
#
# ---------------第 17 页---------------
#
# ---------------第 18 页---------------
#
# ---------------第 19 页---------------
#
# ---------------第 20 页---------------
#
# ---------------第 21 页---------------
#
# ---------------第 22 页---------------
#
# ---------------第 23 页---------------
#
# ---------------第 24 页---------------
#
# ---------------第 25 页---------------
#
# ---------------第 26 页---------------
#
# ---------------第 27 页---------------
#
# ---------------第 28 页---------------
#
# ---------------第 29 页---------------
#
# ---------------第 30 页---------------
#
# ---------------第 31 页---------------
#
# ---------------第 32 页---------------
#
# ---------------第 33 页---------------
#
# ---------------第 34 页---------------
#
# ---------------第 35 页---------------
#
# ---------------第 36 页---------------
#
# ---------------第 37 页---------------
#
# ---------------第 38 页---------------
#
# ---------------第 39 页---------------
#
# ---------------第 40 页---------------
#
# ---------------第 41 页---------------
#
# ---------------第 42 页---------------
#
# ---------------第 43 页---------------
#
# ---------------第 44 页---------------
#
# ---------------第 45 页---------------
#
# ---------------第 46 页---------------
#
# ---------------第 47 页---------------
#
# ---------------第 48 页---------------
#
# ---------------第 49 页---------------
#
# ---------------第 50 页---------------
#
# ---------------第 51 页---------------
#
# ---------------第 52 页---------------
#
# ---------------第 53 页---------------

# %%
import json
import time
import requests

headers = {
    'Host': 'music.163.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
}

def get_comments(page):
    """获取评论信息"""
    # 评论API地址
    url = 'http://music.163.com/api/v1/resource/comments/R_SO_4_2640175107?limit=100&offset=' + str(page)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    result = json.loads(response.text)
    # 只提取comments的内容
    items = result['comments']
    for item in items:
        # 用户ID
        user_id = str(item['user']['userId'])
        # 4、评论时间
        pub_time = item['time']
        pub_time = time.strftime("%Y-%m-%d", time.localtime(pub_time / 1000))
        # 获取用户信息
        user_message = get_user(user_id)
        # 用户年龄
        user_age = str(user_message['age'])
        # 用户性别
        user_gender = str(user_message['gender'])
        # 用户所在地区
        user_city = str(user_message['city'])
        # 保存到本地
        with open('comments_data4.csv', 'a', encoding='utf-8-sig') as f:
            f.write(user_id + ',' + pub_time +',' + user_age + ',' + user_gender + ',' + user_city + ','  +'\n')


def get_user(user_id):
    """ 获取用户注册时间"""
    data = {}
    # 用户API
    url = 'https://music.163.com/api/v1/user/detail/' + str(user_id)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    js = json.loads(response.text)
    if js['code'] == 200:
        # 性别
        data['gender'] = js['profile']['gender']
        # 年龄
        if int(js['profile']['birthday']) < 0:
            data['age'] = 0
        else:
            data['age'] = (2018 - 1970) - (int(js['profile']['birthday']) // (1000 * 365 * 24 * 3600))
        if int(data['age']) < 0:
            data['age'] = 0
        # 城市
        data['city'] = js['profile']['city']
    else:
        data['gender'] = '无'
        data['age'] = '无'
        data['city'] = '无'
    return data

def main():
    for i in range(0, 1050, 20):
        print('\n---------------第 ' + str(i // 20 + 1) + ' 页---------------')
        get_comments(i)

if __name__ == '__main__':
    main()
# Out:
# ---------------第 1 页---------------
#
# ---------------第 2 页---------------
#
# ---------------第 3 页---------------
#
# ---------------第 4 页---------------
#
# ---------------第 5 页---------------
#
# ---------------第 6 页---------------
#
# ---------------第 7 页---------------
#
# ---------------第 8 页---------------
#
# ---------------第 9 页---------------
#
# ---------------第 10 页---------------
#
# ---------------第 11 页---------------
#
# ---------------第 12 页---------------
#
# ---------------第 13 页---------------
#
# ---------------第 14 页---------------
#
# ---------------第 15 页---------------
#
# ---------------第 16 页---------------
#
# ---------------第 17 页---------------
#
# ---------------第 18 页---------------
#
# ---------------第 19 页---------------
#
# ---------------第 20 页---------------
#
# ---------------第 21 页---------------
#
# ---------------第 22 页---------------
#
# ---------------第 23 页---------------
#
# ---------------第 24 页---------------
#
# ---------------第 25 页---------------
#
# ---------------第 26 页---------------
#
# ---------------第 27 页---------------
#
# ---------------第 28 页---------------
#
# ---------------第 29 页---------------
#
# ---------------第 30 页---------------
#
# ---------------第 31 页---------------
#
# ---------------第 32 页---------------
#
# ---------------第 33 页---------------
#
# ---------------第 34 页---------------
#
# ---------------第 35 页---------------
#
# ---------------第 36 页---------------
#
# ---------------第 37 页---------------
#
# ---------------第 38 页---------------
#
# ---------------第 39 页---------------
#
# ---------------第 40 页---------------
#
# ---------------第 41 页---------------
#
# ---------------第 42 页---------------
#
# ---------------第 43 页---------------
#
# ---------------第 44 页---------------
#
# ---------------第 45 页---------------
#
# ---------------第 46 页---------------
#
# ---------------第 47 页---------------
#
# ---------------第 48 页---------------
#
# ---------------第 49 页---------------
#
# ---------------第 50 页---------------
#
# ---------------第 51 页---------------
#
# ---------------第 52 页---------------
#
# ---------------第 53 页---------------

# %%
import json
import time
import requests

headers = {
    'Host': 'music.163.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
}

def get_comments(page):
    """获取评论信息"""
    # 评论API地址
    url = 'http://music.163.com/api/v1/resource/comments/R_SO_4_2639943324?limit=100&offset=' + str(page)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    result = json.loads(response.text)
    # 只提取comments的内容
    items = result['comments']
    for item in items:
        # 用户ID
        user_id = str(item['user']['userId'])
        # 4、评论时间
        pub_time = item['time']
        pub_time = time.strftime("%Y-%m-%d", time.localtime(pub_time / 1000))
        # 获取用户信息
        user_message = get_user(user_id)
        # 用户年龄
        user_age = str(user_message['age'])
        # 用户性别
        user_gender = str(user_message['gender'])
        # 用户所在地区
        user_city = str(user_message['city'])
        # 保存到本地
        with open('comments_data5.csv', 'a', encoding='utf-8-sig') as f:
            f.write(user_id + ',' + pub_time +',' + user_age + ',' + user_gender + ',' + user_city + ','  +'\n')


def get_user(user_id):
    """ 获取用户注册时间"""
    data = {}
    # 用户API
    url = 'https://music.163.com/api/v1/user/detail/' + str(user_id)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    js = json.loads(response.text)
    if js['code'] == 200:
        # 性别
        data['gender'] = js['profile']['gender']
        # 年龄
        if int(js['profile']['birthday']) < 0:
            data['age'] = 0
        else:
            data['age'] = (2018 - 1970) - (int(js['profile']['birthday']) // (1000 * 365 * 24 * 3600))
        if int(data['age']) < 0:
            data['age'] = 0
        # 城市
        data['city'] = js['profile']['city']
    else:
        data['gender'] = '无'
        data['age'] = '无'
        data['city'] = '无'
    return data

def main():
    for i in range(0, 1050, 20):
        print('\n---------------第 ' + str(i // 20 + 1) + ' 页---------------')
        get_comments(i)

if __name__ == '__main__':
    main()
# Out:
# ---------------第 1 页---------------
#
# ---------------第 2 页---------------
#
# ---------------第 3 页---------------
#
# ---------------第 4 页---------------
#
# ---------------第 5 页---------------
#
# ---------------第 6 页---------------
#
# ---------------第 7 页---------------
#
# ---------------第 8 页---------------
#
# ---------------第 9 页---------------
#
# ---------------第 10 页---------------
#
# ---------------第 11 页---------------
#
# ---------------第 12 页---------------
#
# ---------------第 13 页---------------
#
# ---------------第 14 页---------------
#
# ---------------第 15 页---------------
#
# ---------------第 16 页---------------
#
# ---------------第 17 页---------------
#
# ---------------第 18 页---------------
#
# ---------------第 19 页---------------
#
# ---------------第 20 页---------------
#
# ---------------第 21 页---------------
#
# ---------------第 22 页---------------
#
# ---------------第 23 页---------------
#
# ---------------第 24 页---------------
#
# ---------------第 25 页---------------
#
# ---------------第 26 页---------------
#
# ---------------第 27 页---------------
#
# ---------------第 28 页---------------
#
# ---------------第 29 页---------------
#
# ---------------第 30 页---------------
#
# ---------------第 31 页---------------
#
# ---------------第 32 页---------------
#
# ---------------第 33 页---------------
#
# ---------------第 34 页---------------
#
# ---------------第 35 页---------------
#
# ---------------第 36 页---------------
#
# ---------------第 37 页---------------
#
# ---------------第 38 页---------------
#
# ---------------第 39 页---------------
#
# ---------------第 40 页---------------
#
# ---------------第 41 页---------------
#
# ---------------第 42 页---------------
#
# ---------------第 43 页---------------
#
# ---------------第 44 页---------------
#
# ---------------第 45 页---------------
#
# ---------------第 46 页---------------
#
# ---------------第 47 页---------------
#
# ---------------第 48 页---------------
#
# ---------------第 49 页---------------
#
# ---------------第 50 页---------------
#
# ---------------第 51 页---------------
#
# ---------------第 52 页---------------
#
# ---------------第 53 页---------------

# %%
import json
import time
import requests

headers = {
    'Host': 'music.163.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
}

def get_comments(page):
    """获取评论信息"""
    # 评论API地址
    url = 'http://music.163.com/api/v1/resource/comments/R_SO_4_2640854643?limit=100&offset=' + str(page)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    result = json.loads(response.text)
    # 只提取comments的内容
    items = result['comments']
    for item in items:
        # 用户ID
        user_id = str(item['user']['userId'])
        # 4、评论时间
        pub_time = item['time']
        pub_time = time.strftime("%Y-%m-%d", time.localtime(pub_time / 1000))
        # 获取用户信息
        user_message = get_user(user_id)
        # 用户年龄
        user_age = str(user_message['age'])
        # 用户性别
        user_gender = str(user_message['gender'])
        # 用户所在地区
        user_city = str(user_message['city'])
        # 保存到本地
        with open('comments_data6.csv', 'a', encoding='utf-8-sig') as f:
            f.write(user_id + ',' + pub_time +',' + user_age + ',' + user_gender + ',' + user_city + ','  +'\n')


def get_user(user_id):
    """ 获取用户注册时间"""
    data = {}
    # 用户API
    url = 'https://music.163.com/api/v1/user/detail/' + str(user_id)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    js = json.loads(response.text)
    if js['code'] == 200:
        # 性别
        data['gender'] = js['profile']['gender']
        # 年龄
        if int(js['profile']['birthday']) < 0:
            data['age'] = 0
        else:
            data['age'] = (2018 - 1970) - (int(js['profile']['birthday']) // (1000 * 365 * 24 * 3600))
        if int(data['age']) < 0:
            data['age'] = 0
        # 城市
        data['city'] = js['profile']['city']
    else:
        data['gender'] = '无'
        data['age'] = '无'
        data['city'] = '无'
    return data

def main():
    for i in range(0, 1050, 20):
        print('\n---------------第 ' + str(i // 20 + 1) + ' 页---------------')
        get_comments(i)

if __name__ == '__main__':
    main()
# Out:
# ---------------第 1 页---------------
#
# ---------------第 2 页---------------
#
# ---------------第 3 页---------------
#
# ---------------第 4 页---------------
#
# ---------------第 5 页---------------
#
# ---------------第 6 页---------------
#
# ---------------第 7 页---------------
#
# ---------------第 8 页---------------
#
# ---------------第 9 页---------------
#
# ---------------第 10 页---------------
#
# ---------------第 11 页---------------
#
# ---------------第 12 页---------------
#
# ---------------第 13 页---------------
#
# ---------------第 14 页---------------
#
# ---------------第 15 页---------------
#
# ---------------第 16 页---------------
#
# ---------------第 17 页---------------
#
# ---------------第 18 页---------------
#
# ---------------第 19 页---------------
#
# ---------------第 20 页---------------
#
# ---------------第 21 页---------------
#
# ---------------第 22 页---------------
#
# ---------------第 23 页---------------
#
# ---------------第 24 页---------------
#
# ---------------第 25 页---------------
#
# ---------------第 26 页---------------
#
# ---------------第 27 页---------------
#
# ---------------第 28 页---------------
#
# ---------------第 29 页---------------
#
# ---------------第 30 页---------------
#
# ---------------第 31 页---------------
#
# ---------------第 32 页---------------
#
# ---------------第 33 页---------------
#
# ---------------第 34 页---------------
#
# ---------------第 35 页---------------
#
# ---------------第 36 页---------------
#
# ---------------第 37 页---------------
#
# ---------------第 38 页---------------
#
# ---------------第 39 页---------------
#
# ---------------第 40 页---------------
#
# ---------------第 41 页---------------
#
# ---------------第 42 页---------------
#
# ---------------第 43 页---------------
#
# ---------------第 44 页---------------
#
# ---------------第 45 页---------------
#
# ---------------第 46 页---------------
#
# ---------------第 47 页---------------
#
# ---------------第 48 页---------------
#
# ---------------第 49 页---------------
#
# ---------------第 50 页---------------
#
# ---------------第 51 页---------------
#
# ---------------第 52 页---------------
#
# ---------------第 53 页---------------

# %%
import json
import time
import requests

headers = {
    'Host': 'music.163.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
}

def get_comments(page):
    """获取评论信息"""
    # 评论API地址
    url = 'http://music.163.com/api/v1/resource/comments/R_SO_4_2639259577?limit=100&offset=' + str(page)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    result = json.loads(response.text)
    # 只提取comments的内容
    items = result['comments']
    for item in items:
        # 用户ID
        user_id = str(item['user']['userId'])
        # 4、评论时间
        pub_time = item['time']
        pub_time = time.strftime("%Y-%m-%d", time.localtime(pub_time / 1000))
        # 获取用户信息
        user_message = get_user(user_id)
        # 用户年龄
        user_age = str(user_message['age'])
        # 用户性别
        user_gender = str(user_message['gender'])
        # 用户所在地区
        user_city = str(user_message['city'])
        # 保存到本地
        with open('comments_data7.csv', 'a', encoding='utf-8-sig') as f:
            f.write(user_id + ',' + pub_time +',' + user_age + ',' + user_gender + ',' + user_city + ','  +'\n')


def get_user(user_id):
    """ 获取用户注册时间"""
    data = {}
    # 用户API
    url = 'https://music.163.com/api/v1/user/detail/' + str(user_id)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    js = json.loads(response.text)
    if js['code'] == 200:
        # 性别
        data['gender'] = js['profile']['gender']
        # 年龄
        if int(js['profile']['birthday']) < 0:
            data['age'] = 0
        else:
            data['age'] = (2018 - 1970) - (int(js['profile']['birthday']) // (1000 * 365 * 24 * 3600))
        if int(data['age']) < 0:
            data['age'] = 0
        # 城市
        data['city'] = js['profile']['city']
    else:
        data['gender'] = '无'
        data['age'] = '无'
        data['city'] = '无'
    return data

def main():
    for i in range(0, 1050, 20):
        print('\n---------------第 ' + str(i // 20 + 1) + ' 页---------------')
        get_comments(i)

if __name__ == '__main__':
    main()
# Out:
# ---------------第 1 页---------------
#
# ---------------第 2 页---------------
#
# ---------------第 3 页---------------
#
# ---------------第 4 页---------------
#
# ---------------第 5 页---------------
#
# ---------------第 6 页---------------
#
# ---------------第 7 页---------------
#
# ---------------第 8 页---------------
#
# ---------------第 9 页---------------
#
# ---------------第 10 页---------------
#
# ---------------第 11 页---------------
#
# ---------------第 12 页---------------
#
# ---------------第 13 页---------------
#
# ---------------第 14 页---------------
#
# ---------------第 15 页---------------
#
# ---------------第 16 页---------------
#
# ---------------第 17 页---------------
#
# ---------------第 18 页---------------
#
# ---------------第 19 页---------------
#
# ---------------第 20 页---------------
#
# ---------------第 21 页---------------
#
# ---------------第 22 页---------------
#
# ---------------第 23 页---------------
#
# ---------------第 24 页---------------
#
# ---------------第 25 页---------------
#
# ---------------第 26 页---------------
#
# ---------------第 27 页---------------
#
# ---------------第 28 页---------------
#
# ---------------第 29 页---------------
#
# ---------------第 30 页---------------
#
# ---------------第 31 页---------------
#
# ---------------第 32 页---------------
#
# ---------------第 33 页---------------
#
# ---------------第 34 页---------------
#
# ---------------第 35 页---------------
#
# ---------------第 36 页---------------
#
# ---------------第 37 页---------------
#
# ---------------第 38 页---------------
#
# ---------------第 39 页---------------
#
# ---------------第 40 页---------------
#
# ---------------第 41 页---------------
#
# ---------------第 42 页---------------
#
# ---------------第 43 页---------------
#
# ---------------第 44 页---------------
#
# ---------------第 45 页---------------
#
# ---------------第 46 页---------------
#
# ---------------第 47 页---------------
#
# ---------------第 48 页---------------
#
# ---------------第 49 页---------------
#
# ---------------第 50 页---------------
#
# ---------------第 51 页---------------
#
# ---------------第 52 页---------------
#
# ---------------第 53 页---------------

# %%
import json
import time
import requests

headers = {
    'Host': 'music.163.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
}

def get_comments(page):
    """获取评论信息"""
    # 评论API地址
    url = 'http://music.163.com/api/v1/resource/comments/R_SO_4_2639328471?limit=100&offset=' + str(page)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    result = json.loads(response.text)
    # 只提取comments的内容
    items = result['comments']
    for item in items:
        # 用户ID
        user_id = str(item['user']['userId'])
        # 4、评论时间
        pub_time = item['time']
        pub_time = time.strftime("%Y-%m-%d", time.localtime(pub_time / 1000))
        # 获取用户信息
        user_message = get_user(user_id)
        # 用户年龄
        user_age = str(user_message['age'])
        # 用户性别
        user_gender = str(user_message['gender'])
        # 用户所在地区
        user_city = str(user_message['city'])
        # 保存到本地
        with open('comments_data8.csv', 'a', encoding='utf-8-sig') as f:
            f.write(user_id + ',' + pub_time +',' + user_age + ',' + user_gender + ',' + user_city + ','  +'\n')


def get_user(user_id):
    """ 获取用户注册时间"""
    data = {}
    # 用户API
    url = 'https://music.163.com/api/v1/user/detail/' + str(user_id)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    js = json.loads(response.text)
    if js['code'] == 200:
        # 性别
        data['gender'] = js['profile']['gender']
        # 年龄
        if int(js['profile']['birthday']) < 0:
            data['age'] = 0
        else:
            data['age'] = (2018 - 1970) - (int(js['profile']['birthday']) // (1000 * 365 * 24 * 3600))
        if int(data['age']) < 0:
            data['age'] = 0
        # 城市
        data['city'] = js['profile']['city']
    else:
        data['gender'] = '无'
        data['age'] = '无'
        data['city'] = '无'
    return data

def main():
    for i in range(0, 1050, 20):
        print('\n---------------第 ' + str(i // 20 + 1) + ' 页---------------')
        get_comments(i)

if __name__ == '__main__':
    main()
# Out:
# ---------------第 1 页---------------
#
# ---------------第 2 页---------------
#
# ---------------第 3 页---------------
#
# ---------------第 4 页---------------
#
# ---------------第 5 页---------------
#
# ---------------第 6 页---------------
#
# ---------------第 7 页---------------
#
# ---------------第 8 页---------------
#
# ---------------第 9 页---------------
#
# ---------------第 10 页---------------
#
# ---------------第 11 页---------------
#
# ---------------第 12 页---------------
#
# ---------------第 13 页---------------
#
# ---------------第 14 页---------------
#
# ---------------第 15 页---------------
#
# ---------------第 16 页---------------
#
# ---------------第 17 页---------------
#
# ---------------第 18 页---------------
#
# ---------------第 19 页---------------
#
# ---------------第 20 页---------------
#
# ---------------第 21 页---------------
#
# ---------------第 22 页---------------
#
# ---------------第 23 页---------------
#
# ---------------第 24 页---------------
#
# ---------------第 25 页---------------
#
# ---------------第 26 页---------------
#
# ---------------第 27 页---------------
#
# ---------------第 28 页---------------
#
# ---------------第 29 页---------------
#
# ---------------第 30 页---------------
#
# ---------------第 31 页---------------
#
# ---------------第 32 页---------------
#
# ---------------第 33 页---------------
#
# ---------------第 34 页---------------
#
# ---------------第 35 页---------------
#
# ---------------第 36 页---------------
#
# ---------------第 37 页---------------
#
# ---------------第 38 页---------------
#
# ---------------第 39 页---------------
#
# ---------------第 40 页---------------
#
# ---------------第 41 页---------------
#
# ---------------第 42 页---------------
#
# ---------------第 43 页---------------
#
# ---------------第 44 页---------------
#
# ---------------第 45 页---------------
#
# ---------------第 46 页---------------
#
# ---------------第 47 页---------------
#
# ---------------第 48 页---------------
#
# ---------------第 49 页---------------
#
# ---------------第 50 页---------------
#
# ---------------第 51 页---------------
#
# ---------------第 52 页---------------
#
# ---------------第 53 页---------------

# %%
import json
import time
import requests

headers = {
    'Host': 'music.163.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
}

def get_comments(page):
    """获取评论信息"""
    # 评论API地址
    url = 'http://music.163.com/api/v1/resource/comments/R_SO_4_2639955423?limit=100&offset=' + str(page)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    result = json.loads(response.text)
    # 只提取comments的内容
    items = result['comments']
    for item in items:
        # 用户ID
        user_id = str(item['user']['userId'])
        # 4、评论时间
        pub_time = item['time']
        pub_time = time.strftime("%Y-%m-%d", time.localtime(pub_time / 1000))
        # 获取用户信息
        user_message = get_user(user_id)
        # 用户年龄
        user_age = str(user_message['age'])
        # 用户性别
        user_gender = str(user_message['gender'])
        # 用户所在地区
        user_city = str(user_message['city'])
        # 保存到本地
        with open('comments_data9.csv', 'a', encoding='utf-8-sig') as f:
            f.write(user_id + ',' + pub_time +',' + user_age + ',' + user_gender + ',' + user_city + ','  +'\n')


def get_user(user_id):
    """ 获取用户注册时间"""
    data = {}
    # 用户API
    url = 'https://music.163.com/api/v1/user/detail/' + str(user_id)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    js = json.loads(response.text)
    if js['code'] == 200:
        # 性别
        data['gender'] = js['profile']['gender']
        # 年龄
        if int(js['profile']['birthday']) < 0:
            data['age'] = 0
        else:
            data['age'] = (2018 - 1970) - (int(js['profile']['birthday']) // (1000 * 365 * 24 * 3600))
        if int(data['age']) < 0:
            data['age'] = 0
        # 城市
        data['city'] = js['profile']['city']
    else:
        data['gender'] = '无'
        data['age'] = '无'
        data['city'] = '无'
    return data

def main():
    for i in range(0, 1050, 20):
        print('\n---------------第 ' + str(i // 20 + 1) + ' 页---------------')
        get_comments(i)

if __name__ == '__main__':
    main()
# Out:
# ---------------第 1 页---------------
#
# ---------------第 2 页---------------
#
# ---------------第 3 页---------------
#
# ---------------第 4 页---------------
#
# ---------------第 5 页---------------
#
# ---------------第 6 页---------------
#
# ---------------第 7 页---------------
#
# ---------------第 8 页---------------
#
# ---------------第 9 页---------------
#
# ---------------第 10 页---------------
#
# ---------------第 11 页---------------
#
# ---------------第 12 页---------------
#
# ---------------第 13 页---------------
#
# ---------------第 14 页---------------
#
# ---------------第 15 页---------------
#
# ---------------第 16 页---------------
#
# ---------------第 17 页---------------
#
# ---------------第 18 页---------------
#
# ---------------第 19 页---------------
#
# ---------------第 20 页---------------
#
# ---------------第 21 页---------------
#
# ---------------第 22 页---------------
#
# ---------------第 23 页---------------
#
# ---------------第 24 页---------------
#
# ---------------第 25 页---------------
#
# ---------------第 26 页---------------
#
# ---------------第 27 页---------------
#
# ---------------第 28 页---------------
#
# ---------------第 29 页---------------
#
# ---------------第 30 页---------------
#
# ---------------第 31 页---------------
#
# ---------------第 32 页---------------
#
# ---------------第 33 页---------------
#
# ---------------第 34 页---------------
#
# ---------------第 35 页---------------
#
# ---------------第 36 页---------------
#
# ---------------第 37 页---------------
#
# ---------------第 38 页---------------
#
# ---------------第 39 页---------------
#
# ---------------第 40 页---------------
#
# ---------------第 41 页---------------
#
# ---------------第 42 页---------------
#
# ---------------第 43 页---------------
#
# ---------------第 44 页---------------
#
# ---------------第 45 页---------------
#
# ---------------第 46 页---------------
#
# ---------------第 47 页---------------
#
# ---------------第 48 页---------------
#
# ---------------第 49 页---------------
#
# ---------------第 50 页---------------
#
# ---------------第 51 页---------------
#
# ---------------第 52 页---------------
#
# ---------------第 53 页---------------

# %%
import json
import time
import requests

headers = {
    'Host': 'music.163.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
}

def get_comments(page):
    """获取评论信息"""
    # 评论API地址
    url = 'http://music.163.com/api/v1/resource/comments/R_SO_4_2641086658?limit=100&offset=' + str(page)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    result = json.loads(response.text)
    # 只提取comments的内容
    items = result['comments']
    for item in items:
        # 用户ID
        user_id = str(item['user']['userId'])
        # 4、评论时间
        pub_time = item['time']
        pub_time = time.strftime("%Y-%m-%d", time.localtime(pub_time / 1000))
        # 获取用户信息
        user_message = get_user(user_id)
        # 用户年龄
        user_age = str(user_message['age'])
        # 用户性别
        user_gender = str(user_message['gender'])
        # 用户所在地区
        user_city = str(user_message['city'])
        # 保存到本地
        with open('comments_data10.csv', 'a', encoding='utf-8-sig') as f:
            f.write(user_id + ',' + pub_time +',' + user_age + ',' + user_gender + ',' + user_city + ','  +'\n')


def get_user(user_id):
    """ 获取用户注册时间"""
    data = {}
    # 用户API
    url = 'https://music.163.com/api/v1/user/detail/' + str(user_id)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    js = json.loads(response.text)
    if js['code'] == 200:
        # 性别
        data['gender'] = js['profile']['gender']
        # 年龄
        if int(js['profile']['birthday']) < 0:
            data['age'] = 0
        else:
            data['age'] = (2018 - 1970) - (int(js['profile']['birthday']) // (1000 * 365 * 24 * 3600))
        if int(data['age']) < 0:
            data['age'] = 0
        # 城市
        data['city'] = js['profile']['city']
    else:
        data['gender'] = '无'
        data['age'] = '无'
        data['city'] = '无'
    return data

def main():
    for i in range(0, 1050, 20):
        print('\n---------------第 ' + str(i // 20 + 1) + ' 页---------------')
        get_comments(i)

if __name__ == '__main__':
    main()
# Out:
# ---------------第 1 页---------------
#
# ---------------第 2 页---------------
#
# ---------------第 3 页---------------
#
# ---------------第 4 页---------------
#
# ---------------第 5 页---------------
#
# ---------------第 6 页---------------
#
# ---------------第 7 页---------------
#
# ---------------第 8 页---------------
#
# ---------------第 9 页---------------
#
# ---------------第 10 页---------------
#
# ---------------第 11 页---------------
#
# ---------------第 12 页---------------
#
# ---------------第 13 页---------------
#
# ---------------第 14 页---------------
#
# ---------------第 15 页---------------
#
# ---------------第 16 页---------------
#
# ---------------第 17 页---------------
#
# ---------------第 18 页---------------
#
# ---------------第 19 页---------------
#
# ---------------第 20 页---------------
#
# ---------------第 21 页---------------
#
# ---------------第 22 页---------------
#
# ---------------第 23 页---------------
#
# ---------------第 24 页---------------
#
# ---------------第 25 页---------------
#
# ---------------第 26 页---------------
#
# ---------------第 27 页---------------
#
# ---------------第 28 页---------------
#
# ---------------第 29 页---------------
#
# ---------------第 30 页---------------
#
# ---------------第 31 页---------------
#
# ---------------第 32 页---------------
#
# ---------------第 33 页---------------
#
# ---------------第 34 页---------------
#
# ---------------第 35 页---------------
#
# ---------------第 36 页---------------
#
# ---------------第 37 页---------------
#
# ---------------第 38 页---------------
#
# ---------------第 39 页---------------
#
# ---------------第 40 页---------------
#
# ---------------第 41 页---------------
#
# ---------------第 42 页---------------
#
# ---------------第 43 页---------------
#
# ---------------第 44 页---------------
#
# ---------------第 45 页---------------
#
# ---------------第 46 页---------------
#
# ---------------第 47 页---------------
#
# ---------------第 48 页---------------
#
# ---------------第 49 页---------------
#
# ---------------第 50 页---------------
#
# ---------------第 51 页---------------
#
# ---------------第 52 页---------------
#
# ---------------第 53 页---------------

# %%
import json
import time
import requests

headers = {
    'Host': 'music.163.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
}

def get_comments(page):
    """获取评论信息"""
    # 评论API地址
    url = 'http://music.163.com/api/v1/resource/comments/R_SO_4_2641070895?limit=100&offset=' + str(page)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    result = json.loads(response.text)
    # 只提取comments的内容
    items = result['comments']
    for item in items:
        # 用户ID
        user_id = str(item['user']['userId'])
        # 4、评论时间
        pub_time = item['time']
        pub_time = time.strftime("%Y-%m-%d", time.localtime(pub_time / 1000))
        # 获取用户信息
        user_message = get_user(user_id)
        # 用户年龄
        user_age = str(user_message['age'])
        # 用户性别
        user_gender = str(user_message['gender'])
        # 用户所在地区
        user_city = str(user_message['city'])
        # 保存到本地
        with open('comments_data11.csv', 'a', encoding='utf-8-sig') as f:
            f.write(user_id + ',' + pub_time +',' + user_age + ',' + user_gender + ',' + user_city + ','  +'\n')


def get_user(user_id):
    """ 获取用户注册时间"""
    data = {}
    # 用户API
    url = 'https://music.163.com/api/v1/user/detail/' + str(user_id)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    js = json.loads(response.text)
    if js['code'] == 200:
        # 性别
        data['gender'] = js['profile']['gender']
        # 年龄
        if int(js['profile']['birthday']) < 0:
            data['age'] = 0
        else:
            data['age'] = (2018 - 1970) - (int(js['profile']['birthday']) // (1000 * 365 * 24 * 3600))
        if int(data['age']) < 0:
            data['age'] = 0
        # 城市
        data['city'] = js['profile']['city']
    else:
        data['gender'] = '无'
        data['age'] = '无'
        data['city'] = '无'
    return data

def main():
    for i in range(0, 1050, 20):
        print('\n---------------第 ' + str(i // 20 + 1) + ' 页---------------')
        get_comments(i)

if __name__ == '__main__':
    main()
# Out:
# ---------------第 1 页---------------
#
# ---------------第 2 页---------------
#
# ---------------第 3 页---------------
#
# ---------------第 4 页---------------
#
# ---------------第 5 页---------------
#
# ---------------第 6 页---------------
#
# ---------------第 7 页---------------
#
# ---------------第 8 页---------------
#
# ---------------第 9 页---------------
#
# ---------------第 10 页---------------
#
# ---------------第 11 页---------------
#
# ---------------第 12 页---------------
#
# ---------------第 13 页---------------
#
# ---------------第 14 页---------------
#
# ---------------第 15 页---------------
#
# ---------------第 16 页---------------
#
# ---------------第 17 页---------------
#
# ---------------第 18 页---------------
#
# ---------------第 19 页---------------
#
# ---------------第 20 页---------------
#
# ---------------第 21 页---------------
#
# ---------------第 22 页---------------
#
# ---------------第 23 页---------------
#
# ---------------第 24 页---------------
#
# ---------------第 25 页---------------
#
# ---------------第 26 页---------------
#
# ---------------第 27 页---------------
#
# ---------------第 28 页---------------
#
# ---------------第 29 页---------------
#
# ---------------第 30 页---------------
#
# ---------------第 31 页---------------
#
# ---------------第 32 页---------------
#
# ---------------第 33 页---------------
#
# ---------------第 34 页---------------
#
# ---------------第 35 页---------------
#
# ---------------第 36 页---------------
#
# ---------------第 37 页---------------
#
# ---------------第 38 页---------------
#
# ---------------第 39 页---------------
#
# ---------------第 40 页---------------
#
# ---------------第 41 页---------------
#
# ---------------第 42 页---------------
#
# ---------------第 43 页---------------
#
# ---------------第 44 页---------------
#
# ---------------第 45 页---------------
#
# ---------------第 46 页---------------
#
# ---------------第 47 页---------------
#
# ---------------第 48 页---------------
#
# ---------------第 49 页---------------
#
# ---------------第 50 页---------------
#
# ---------------第 51 页---------------
#
# ---------------第 52 页---------------
#
# ---------------第 53 页---------------

# %%
import json
import time
import requests

headers = {
    'Host': 'music.163.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
}

def get_comments(page):
    """获取评论信息"""
    # 评论API地址
    url = 'http://music.163.com/api/v1/resource/comments/R_SO_4_2639654009?limit=100&offset=' + str(page)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    result = json.loads(response.text)
    # 只提取comments的内容
    items = result['comments']
    for item in items:
        # 用户ID
        user_id = str(item['user']['userId'])
        # 4、评论时间
        pub_time = item['time']
        pub_time = time.strftime("%Y-%m-%d", time.localtime(pub_time / 1000))
        # 获取用户信息
        user_message = get_user(user_id)
        # 用户年龄
        user_age = str(user_message['age'])
        # 用户性别
        user_gender = str(user_message['gender'])
        # 用户所在地区
        user_city = str(user_message['city'])
        # 保存到本地
        with open('comments_data12.csv', 'a', encoding='utf-8-sig') as f:
            f.write(user_id + ',' + pub_time +',' + user_age + ',' + user_gender + ',' + user_city + ','  +'\n')


def get_user(user_id):
    """ 获取用户注册时间"""
    data = {}
    # 用户API
    url = 'https://music.163.com/api/v1/user/detail/' + str(user_id)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    js = json.loads(response.text)
    if js['code'] == 200:
        # 性别
        data['gender'] = js['profile']['gender']
        # 年龄
        if int(js['profile']['birthday']) < 0:
            data['age'] = 0
        else:
            data['age'] = (2018 - 1970) - (int(js['profile']['birthday']) // (1000 * 365 * 24 * 3600))
        if int(data['age']) < 0:
            data['age'] = 0
        # 城市
        data['city'] = js['profile']['city']
    else:
        data['gender'] = '无'
        data['age'] = '无'
        data['city'] = '无'
    return data

def main():
    for i in range(0, 1050, 20):
        print('\n---------------第 ' + str(i // 20 + 1) + ' 页---------------')
        get_comments(i)

if __name__ == '__main__':
    main()
# Out:
# ---------------第 1 页---------------
#
# ---------------第 2 页---------------
#
# ---------------第 3 页---------------
#
# ---------------第 4 页---------------
#
# ---------------第 5 页---------------
#
# ---------------第 6 页---------------
#
# ---------------第 7 页---------------
#
# ---------------第 8 页---------------
#
# ---------------第 9 页---------------
#
# ---------------第 10 页---------------
#
# ---------------第 11 页---------------
#
# ---------------第 12 页---------------
#
# ---------------第 13 页---------------
#
# ---------------第 14 页---------------
#
# ---------------第 15 页---------------
#
# ---------------第 16 页---------------
#
# ---------------第 17 页---------------
#
# ---------------第 18 页---------------
#
# ---------------第 19 页---------------
#
# ---------------第 20 页---------------
#
# ---------------第 21 页---------------
#
# ---------------第 22 页---------------
#
# ---------------第 23 页---------------
#
# ---------------第 24 页---------------
#
# ---------------第 25 页---------------
#
# ---------------第 26 页---------------
#
# ---------------第 27 页---------------
#
# ---------------第 28 页---------------
#
# ---------------第 29 页---------------
#
# ---------------第 30 页---------------
#
# ---------------第 31 页---------------
#
# ---------------第 32 页---------------
#
# ---------------第 33 页---------------
#
# ---------------第 34 页---------------
#
# ---------------第 35 页---------------
#
# ---------------第 36 页---------------
#
# ---------------第 37 页---------------
#
# ---------------第 38 页---------------
#
# ---------------第 39 页---------------
#
# ---------------第 40 页---------------
#
# ---------------第 41 页---------------
#
# ---------------第 42 页---------------
#
# ---------------第 43 页---------------
#
# ---------------第 44 页---------------
#
# ---------------第 45 页---------------
#
# ---------------第 46 页---------------
#
# ---------------第 47 页---------------
#
# ---------------第 48 页---------------
#
# ---------------第 49 页---------------
#
# ---------------第 50 页---------------
#
# ---------------第 51 页---------------
#
# ---------------第 52 页---------------
#
# ---------------第 53 页---------------

# %%
import json
import time
import requests

headers = {
    'Host': 'music.163.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
}

def get_comments(page):
    """获取评论信息"""
    # 评论API地址
    url = 'http://music.163.com/api/v1/resource/comments/R_SO_4_2639639291?limit=100&offset=' + str(page)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    result = json.loads(response.text)
    # 只提取comments的内容
    items = result['comments']
    for item in items:
        # 用户ID
        user_id = str(item['user']['userId'])
        # 4、评论时间
        pub_time = item['time']
        pub_time = time.strftime("%Y-%m-%d", time.localtime(pub_time / 1000))
        # 获取用户信息
        user_message = get_user(user_id)
        # 用户年龄
        user_age = str(user_message['age'])
        # 用户性别
        user_gender = str(user_message['gender'])
        # 用户所在地区
        user_city = str(user_message['city'])
        # 保存到本地
        with open('comments_data13.csv', 'a', encoding='utf-8-sig') as f:
            f.write(user_id + ',' + pub_time +',' + user_age + ',' + user_gender + ',' + user_city + ','  +'\n')


def get_user(user_id):
    """ 获取用户注册时间"""
    data = {}
    # 用户API
    url = 'https://music.163.com/api/v1/user/detail/' + str(user_id)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    js = json.loads(response.text)
    if js['code'] == 200:
        # 性别
        data['gender'] = js['profile']['gender']
        # 年龄
        if int(js['profile']['birthday']) < 0:
            data['age'] = 0
        else:
            data['age'] = (2018 - 1970) - (int(js['profile']['birthday']) // (1000 * 365 * 24 * 3600))
        if int(data['age']) < 0:
            data['age'] = 0
        # 城市
        data['city'] = js['profile']['city']
    else:
        data['gender'] = '无'
        data['age'] = '无'
        data['city'] = '无'
    return data

def main():
    for i in range(0, 1050, 20):
        print('\n---------------第 ' + str(i // 20 + 1) + ' 页---------------')
        get_comments(i)

if __name__ == '__main__':
    main()
# Out:
# ---------------第 1 页---------------
#
# ---------------第 2 页---------------
#
# ---------------第 3 页---------------
#
# ---------------第 4 页---------------
#
# ---------------第 5 页---------------
#
# ---------------第 6 页---------------
#
# ---------------第 7 页---------------
#
# ---------------第 8 页---------------
#
# ---------------第 9 页---------------
#
# ---------------第 10 页---------------
#
# ---------------第 11 页---------------
#
# ---------------第 12 页---------------
#
# ---------------第 13 页---------------
#
# ---------------第 14 页---------------
#
# ---------------第 15 页---------------
#
# ---------------第 16 页---------------
#
# ---------------第 17 页---------------
#
# ---------------第 18 页---------------
#
# ---------------第 19 页---------------
#
# ---------------第 20 页---------------
#
# ---------------第 21 页---------------
#
# ---------------第 22 页---------------
#
# ---------------第 23 页---------------
#
# ---------------第 24 页---------------
#
# ---------------第 25 页---------------
#
# ---------------第 26 页---------------
#
# ---------------第 27 页---------------
#
# ---------------第 28 页---------------
#
# ---------------第 29 页---------------
#
# ---------------第 30 页---------------
#
# ---------------第 31 页---------------
#
# ---------------第 32 页---------------
#
# ---------------第 33 页---------------
#
# ---------------第 34 页---------------
#
# ---------------第 35 页---------------
#
# ---------------第 36 页---------------
#
# ---------------第 37 页---------------
#
# ---------------第 38 页---------------
#
# ---------------第 39 页---------------
#
# ---------------第 40 页---------------
#
# ---------------第 41 页---------------
#
# ---------------第 42 页---------------
#
# ---------------第 43 页---------------
#
# ---------------第 44 页---------------
#
# ---------------第 45 页---------------
#
# ---------------第 46 页---------------
#
# ---------------第 47 页---------------
#
# ---------------第 48 页---------------
#
# ---------------第 49 页---------------
#
# ---------------第 50 页---------------
#
# ---------------第 51 页---------------
#
# ---------------第 52 页---------------
#
# ---------------第 53 页---------------

# %%
import json
import time
import requests

headers = {
    'Host': 'music.163.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
}

def get_comments(page):
    """获取评论信息"""
    # 评论API地址
    url = 'http://music.163.com/api/v1/resource/comments/R_SO_4_2639155555?limit=100&offset=' + str(page)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    result = json.loads(response.text)
    # 只提取comments的内容
    items = result['comments']
    for item in items:
        # 用户ID
        user_id = str(item['user']['userId'])
        # 4、评论时间
        pub_time = item['time']
        pub_time = time.strftime("%Y-%m-%d", time.localtime(pub_time / 1000))
        # 获取用户信息
        user_message = get_user(user_id)
        # 用户年龄
        user_age = str(user_message['age'])
        # 用户性别
        user_gender = str(user_message['gender'])
        # 用户所在地区
        user_city = str(user_message['city'])
        # 保存到本地
        with open('comments_data14.csv', 'a', encoding='utf-8-sig') as f:
            f.write(user_id + ',' + pub_time +',' + user_age + ',' + user_gender + ',' + user_city + ','  +'\n')


def get_user(user_id):
    """ 获取用户注册时间"""
    data = {}
    # 用户API
    url = 'https://music.163.com/api/v1/user/detail/' + str(user_id)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    js = json.loads(response.text)
    if js['code'] == 200:
        # 性别
        data['gender'] = js['profile']['gender']
        # 年龄
        if int(js['profile']['birthday']) < 0:
            data['age'] = 0
        else:
            data['age'] = (2018 - 1970) - (int(js['profile']['birthday']) // (1000 * 365 * 24 * 3600))
        if int(data['age']) < 0:
            data['age'] = 0
        # 城市
        data['city'] = js['profile']['city']
    else:
        data['gender'] = '无'
        data['age'] = '无'
        data['city'] = '无'
    return data

def main():
    for i in range(0, 1050, 20):
        print('\n---------------第 ' + str(i // 20 + 1) + ' 页---------------')
        get_comments(i)

if __name__ == '__main__':
    main()
# Out:
# ---------------第 1 页---------------
#
# ---------------第 2 页---------------
#
# ---------------第 3 页---------------
#
# ---------------第 4 页---------------
#
# ---------------第 5 页---------------
#
# ---------------第 6 页---------------
#
# ---------------第 7 页---------------
#
# ---------------第 8 页---------------
#
# ---------------第 9 页---------------
#
# ---------------第 10 页---------------
#
# ---------------第 11 页---------------
#
# ---------------第 12 页---------------
#
# ---------------第 13 页---------------
#
# ---------------第 14 页---------------
#
# ---------------第 15 页---------------
#
# ---------------第 16 页---------------
#
# ---------------第 17 页---------------
#
# ---------------第 18 页---------------
#
# ---------------第 19 页---------------
#
# ---------------第 20 页---------------
#
# ---------------第 21 页---------------
#
# ---------------第 22 页---------------
#
# ---------------第 23 页---------------
#
# ---------------第 24 页---------------
#
# ---------------第 25 页---------------
#
# ---------------第 26 页---------------
#
# ---------------第 27 页---------------
#
# ---------------第 28 页---------------
#
# ---------------第 29 页---------------
#
# ---------------第 30 页---------------
#
# ---------------第 31 页---------------
#
# ---------------第 32 页---------------
#
# ---------------第 33 页---------------
#
# ---------------第 34 页---------------
#
# ---------------第 35 页---------------
#
# ---------------第 36 页---------------
#
# ---------------第 37 页---------------
#
# ---------------第 38 页---------------
#
# ---------------第 39 页---------------
#
# ---------------第 40 页---------------
#
# ---------------第 41 页---------------
#
# ---------------第 42 页---------------
#
# ---------------第 43 页---------------
#
# ---------------第 44 页---------------
#
# ---------------第 45 页---------------
#
# ---------------第 46 页---------------
#
# ---------------第 47 页---------------
#
# ---------------第 48 页---------------
#
# ---------------第 49 页---------------
#
# ---------------第 50 页---------------
#
# ---------------第 51 页---------------
#
# ---------------第 52 页---------------
#
# ---------------第 53 页---------------

# %%
import json
import time
import requests

headers = {
    'Host': 'music.163.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
}

def get_comments(page):
    """获取评论信息"""
    # 评论API地址
    url = 'http://music.163.com/api/v1/resource/comments/R_SO_4_2640815045?limit=100&offset=' + str(page)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    result = json.loads(response.text)
    # 只提取comments的内容
    items = result['comments']
    for item in items:
        # 用户ID
        user_id = str(item['user']['userId'])
        # 4、评论时间
        pub_time = item['time']
        pub_time = time.strftime("%Y-%m-%d", time.localtime(pub_time / 1000))
        # 获取用户信息
        user_message = get_user(user_id)
        # 用户年龄
        user_age = str(user_message['age'])
        # 用户性别
        user_gender = str(user_message['gender'])
        # 用户所在地区
        user_city = str(user_message['city'])
        # 保存到本地
        with open('comments_data15.csv', 'a', encoding='utf-8-sig') as f:
            f.write(user_id + ',' + pub_time +',' + user_age + ',' + user_gender + ',' + user_city + ','  +'\n')


def get_user(user_id):
    """ 获取用户注册时间"""
    data = {}
    # 用户API
    url = 'https://music.163.com/api/v1/user/detail/' + str(user_id)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    js = json.loads(response.text)
    if js['code'] == 200:
        # 性别
        data['gender'] = js['profile']['gender']
        # 年龄
        if int(js['profile']['birthday']) < 0:
            data['age'] = 0
        else:
            data['age'] = (2018 - 1970) - (int(js['profile']['birthday']) // (1000 * 365 * 24 * 3600))
        if int(data['age']) < 0:
            data['age'] = 0
        # 城市
        data['city'] = js['profile']['city']
    else:
        data['gender'] = '无'
        data['age'] = '无'
        data['city'] = '无'
    return data

def main():
    for i in range(0, 1050, 20):
        print('\n---------------第 ' + str(i // 20 + 1) + ' 页---------------')
        get_comments(i)

if __name__ == '__main__':
    main()
# Out:
# ---------------第 1 页---------------
#
# ---------------第 2 页---------------
#
# ---------------第 3 页---------------
#
# ---------------第 4 页---------------
#
# ---------------第 5 页---------------
#
# ---------------第 6 页---------------
#
# ---------------第 7 页---------------
#
# ---------------第 8 页---------------
#
# ---------------第 9 页---------------
#
# ---------------第 10 页---------------
#
# ---------------第 11 页---------------
#
# ---------------第 12 页---------------
#
# ---------------第 13 页---------------
#
# ---------------第 14 页---------------
#
# ---------------第 15 页---------------
#
# ---------------第 16 页---------------
#
# ---------------第 17 页---------------
#
# ---------------第 18 页---------------
#
# ---------------第 19 页---------------
#
# ---------------第 20 页---------------
#
# ---------------第 21 页---------------
#
# ---------------第 22 页---------------
#
# ---------------第 23 页---------------
#
# ---------------第 24 页---------------
#
# ---------------第 25 页---------------
#
# ---------------第 26 页---------------
#
# ---------------第 27 页---------------
#
# ---------------第 28 页---------------
#
# ---------------第 29 页---------------
#
# ---------------第 30 页---------------
#
# ---------------第 31 页---------------
#
# ---------------第 32 页---------------
#
# ---------------第 33 页---------------
#
# ---------------第 34 页---------------
#
# ---------------第 35 页---------------
#
# ---------------第 36 页---------------
#
# ---------------第 37 页---------------
#
# ---------------第 38 页---------------
#
# ---------------第 39 页---------------
#
# ---------------第 40 页---------------
#
# ---------------第 41 页---------------
#
# ---------------第 42 页---------------
#
# ---------------第 43 页---------------
#
# ---------------第 44 页---------------
#
# ---------------第 45 页---------------
#
# ---------------第 46 页---------------
#
# ---------------第 47 页---------------
#
# ---------------第 48 页---------------
#
# ---------------第 49 页---------------
#
# ---------------第 50 页---------------
#
# ---------------第 51 页---------------
#
# ---------------第 52 页---------------
#
# ---------------第 53 页---------------

# %%
import json
import time
import requests

headers = {
    'Host': 'music.163.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
}

def get_comments(page):
    """获取评论信息"""
    # 评论API地址
    url = 'http://music.163.com/api/v1/resource/comments/R_SO_4_2638631174?limit=100&offset=' + str(page)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    result = json.loads(response.text)
    # 只提取comments的内容
    items = result['comments']
    for item in items:
        # 用户ID
        user_id = str(item['user']['userId'])
        # 4、评论时间
        pub_time = item['time']
        pub_time = time.strftime("%Y-%m-%d", time.localtime(pub_time / 1000))
        # 获取用户信息
        user_message = get_user(user_id)
        # 用户年龄
        user_age = str(user_message['age'])
        # 用户性别
        user_gender = str(user_message['gender'])
        # 用户所在地区
        user_city = str(user_message['city'])
        # 保存到本地
        with open('comments_data16.csv', 'a', encoding='utf-8-sig') as f:
            f.write(user_id + ',' + pub_time +',' + user_age + ',' + user_gender + ',' + user_city + ','  +'\n')


def get_user(user_id):
    """ 获取用户注册时间"""
    data = {}
    # 用户API
    url = 'https://music.163.com/api/v1/user/detail/' + str(user_id)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    js = json.loads(response.text)
    if js['code'] == 200:
        # 性别
        data['gender'] = js['profile']['gender']
        # 年龄
        if int(js['profile']['birthday']) < 0:
            data['age'] = 0
        else:
            data['age'] = (2018 - 1970) - (int(js['profile']['birthday']) // (1000 * 365 * 24 * 3600))
        if int(data['age']) < 0:
            data['age'] = 0
        # 城市
        data['city'] = js['profile']['city']
    else:
        data['gender'] = '无'
        data['age'] = '无'
        data['city'] = '无'
    return data

def main():
    for i in range(0, 1050, 20):
        print('\n---------------第 ' + str(i // 20 + 1) + ' 页---------------')
        get_comments(i)

if __name__ == '__main__':
    main()
# Out:
# ---------------第 1 页---------------
#
# ---------------第 2 页---------------
#
# ---------------第 3 页---------------
#
# ---------------第 4 页---------------
#
# ---------------第 5 页---------------
#
# ---------------第 6 页---------------
#
# ---------------第 7 页---------------
#
# ---------------第 8 页---------------
#
# ---------------第 9 页---------------
#
# ---------------第 10 页---------------
#
# ---------------第 11 页---------------
#
# ---------------第 12 页---------------
#
# ---------------第 13 页---------------
#
# ---------------第 14 页---------------
#
# ---------------第 15 页---------------
#
# ---------------第 16 页---------------
#
# ---------------第 17 页---------------
#
# ---------------第 18 页---------------
#
# ---------------第 19 页---------------
#
# ---------------第 20 页---------------
#
# ---------------第 21 页---------------
#
# ---------------第 22 页---------------
#
# ---------------第 23 页---------------
#
# ---------------第 24 页---------------
#
# ---------------第 25 页---------------
#
# ---------------第 26 页---------------
#
# ---------------第 27 页---------------
#
# ---------------第 28 页---------------
#
# ---------------第 29 页---------------
#
# ---------------第 30 页---------------
#
# ---------------第 31 页---------------
#
# ---------------第 32 页---------------
#
# ---------------第 33 页---------------
#
# ---------------第 34 页---------------
#
# ---------------第 35 页---------------
#
# ---------------第 36 页---------------
#
# ---------------第 37 页---------------
#
# ---------------第 38 页---------------
#
# ---------------第 39 页---------------
#
# ---------------第 40 页---------------
#
# ---------------第 41 页---------------
#
# ---------------第 42 页---------------
#
# ---------------第 43 页---------------
#
# ---------------第 44 页---------------
#
# ---------------第 45 页---------------
#
# ---------------第 46 页---------------
#
# ---------------第 47 页---------------
#
# ---------------第 48 页---------------
#
# ---------------第 49 页---------------
#
# ---------------第 50 页---------------
#
# ---------------第 51 页---------------
#
# ---------------第 52 页---------------
#
# ---------------第 53 页---------------

# %%
import json
import time
import requests

headers = {
    'Host': 'music.163.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
}

def get_comments(page):
    """获取评论信息"""
    # 评论API地址
    url = 'http://music.163.com/api/v1/resource/comments/R_SO_4_2639703074?limit=100&offset=' + str(page)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    result = json.loads(response.text)
    # 只提取comments的内容
    items = result['comments']
    for item in items:
        # 用户ID
        user_id = str(item['user']['userId'])
        # 4、评论时间
        pub_time = item['time']
        pub_time = time.strftime("%Y-%m-%d", time.localtime(pub_time / 1000))
        # 获取用户信息
        user_message = get_user(user_id)
        # 用户年龄
        user_age = str(user_message['age'])
        # 用户性别
        user_gender = str(user_message['gender'])
        # 用户所在地区
        user_city = str(user_message['city'])
        # 保存到本地
        with open('comments_data17.csv', 'a', encoding='utf-8-sig') as f:
            f.write(user_id + ',' + pub_time +',' + user_age + ',' + user_gender + ',' + user_city + ','  +'\n')


def get_user(user_id):
    """ 获取用户注册时间"""
    data = {}
    # 用户API
    url = 'https://music.163.com/api/v1/user/detail/' + str(user_id)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    js = json.loads(response.text)
    if js['code'] == 200:
        # 性别
        data['gender'] = js['profile']['gender']
        # 年龄
        if int(js['profile']['birthday']) < 0:
            data['age'] = 0
        else:
            data['age'] = (2018 - 1970) - (int(js['profile']['birthday']) // (1000 * 365 * 24 * 3600))
        if int(data['age']) < 0:
            data['age'] = 0
        # 城市
        data['city'] = js['profile']['city']
    else:
        data['gender'] = '无'
        data['age'] = '无'
        data['city'] = '无'
    return data

def main():
    for i in range(0, 1050, 20):
        print('\n---------------第 ' + str(i // 20 + 1) + ' 页---------------')
        get_comments(i)

if __name__ == '__main__':
    main()
# Out:
# ---------------第 1 页---------------
#
# ---------------第 2 页---------------
#
# ---------------第 3 页---------------
#
# ---------------第 4 页---------------
#
# ---------------第 5 页---------------
#
# ---------------第 6 页---------------
#
# ---------------第 7 页---------------
#
# ---------------第 8 页---------------
#
# ---------------第 9 页---------------
#
# ---------------第 10 页---------------
#
# ---------------第 11 页---------------
#
# ---------------第 12 页---------------
#
# ---------------第 13 页---------------
#
# ---------------第 14 页---------------
#
# ---------------第 15 页---------------
#
# ---------------第 16 页---------------
#
# ---------------第 17 页---------------
#
# ---------------第 18 页---------------
#
# ---------------第 19 页---------------
#
# ---------------第 20 页---------------
#
# ---------------第 21 页---------------
#
# ---------------第 22 页---------------
#
# ---------------第 23 页---------------
#
# ---------------第 24 页---------------
#
# ---------------第 25 页---------------
#
# ---------------第 26 页---------------
#
# ---------------第 27 页---------------
#
# ---------------第 28 页---------------
#
# ---------------第 29 页---------------
#
# ---------------第 30 页---------------
#
# ---------------第 31 页---------------
#
# ---------------第 32 页---------------
#
# ---------------第 33 页---------------
#
# ---------------第 34 页---------------
#
# ---------------第 35 页---------------
#
# ---------------第 36 页---------------
#
# ---------------第 37 页---------------
#
# ---------------第 38 页---------------
#
# ---------------第 39 页---------------
#
# ---------------第 40 页---------------
#
# ---------------第 41 页---------------
#
# ---------------第 42 页---------------
#
# ---------------第 43 页---------------
#
# ---------------第 44 页---------------
#
# ---------------第 45 页---------------
#
# ---------------第 46 页---------------
#
# ---------------第 47 页---------------
#
# ---------------第 48 页---------------
#
# ---------------第 49 页---------------
#
# ---------------第 50 页---------------
#
# ---------------第 51 页---------------
#
# ---------------第 52 页---------------
#
# ---------------第 53 页---------------

# %%
import json
import time
import requests

headers = {
    'Host': 'music.163.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
}

def get_comments(page):
    """获取评论信息"""
    # 评论API地址
    url = 'http://music.163.com/api/v1/resource/comments/R_SO_4_2641221838?limit=100&offset=' + str(page)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    result = json.loads(response.text)
    # 只提取comments的内容
    items = result['comments']
    for item in items:
        # 用户ID
        user_id = str(item['user']['userId'])
        # 4、评论时间
        pub_time = item['time']
        pub_time = time.strftime("%Y-%m-%d", time.localtime(pub_time / 1000))
        # 获取用户信息
        user_message = get_user(user_id)
        # 用户年龄
        user_age = str(user_message['age'])
        # 用户性别
        user_gender = str(user_message['gender'])
        # 用户所在地区
        user_city = str(user_message['city'])
        # 保存到本地
        with open('comments_data18.csv', 'a', encoding='utf-8-sig') as f:
            f.write(user_id + ',' + pub_time +',' + user_age + ',' + user_gender + ',' + user_city + ','  +'\n')


def get_user(user_id):
    """ 获取用户注册时间"""
    data = {}
    # 用户API
    url = 'https://music.163.com/api/v1/user/detail/' + str(user_id)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    js = json.loads(response.text)
    if js['code'] == 200:
        # 性别
        data['gender'] = js['profile']['gender']
        # 年龄
        if int(js['profile']['birthday']) < 0:
            data['age'] = 0
        else:
            data['age'] = (2018 - 1970) - (int(js['profile']['birthday']) // (1000 * 365 * 24 * 3600))
        if int(data['age']) < 0:
            data['age'] = 0
        # 城市
        data['city'] = js['profile']['city']
    else:
        data['gender'] = '无'
        data['age'] = '无'
        data['city'] = '无'
    return data

def main():
    for i in range(0, 1050, 20):
        print('\n---------------第 ' + str(i // 20 + 1) + ' 页---------------')
        get_comments(i)

if __name__ == '__main__':
    main()
# Out:
# ---------------第 1 页---------------
#
# ---------------第 2 页---------------
#
# ---------------第 3 页---------------
#
# ---------------第 4 页---------------
#
# ---------------第 5 页---------------
#
# ---------------第 6 页---------------
#
# ---------------第 7 页---------------
#
# ---------------第 8 页---------------
#
# ---------------第 9 页---------------
#
# ---------------第 10 页---------------
#
# ---------------第 11 页---------------
#
# ---------------第 12 页---------------
#
# ---------------第 13 页---------------
#
# ---------------第 14 页---------------
#
# ---------------第 15 页---------------
#
# ---------------第 16 页---------------
#
# ---------------第 17 页---------------
#
# ---------------第 18 页---------------
#
# ---------------第 19 页---------------
#
# ---------------第 20 页---------------
#
# ---------------第 21 页---------------
#
# ---------------第 22 页---------------
#
# ---------------第 23 页---------------
#
# ---------------第 24 页---------------
#
# ---------------第 25 页---------------
#
# ---------------第 26 页---------------
#
# ---------------第 27 页---------------
#
# ---------------第 28 页---------------
#
# ---------------第 29 页---------------
#
# ---------------第 30 页---------------
#
# ---------------第 31 页---------------
#
# ---------------第 32 页---------------
#
# ---------------第 33 页---------------
#
# ---------------第 34 页---------------
#
# ---------------第 35 页---------------
#
# ---------------第 36 页---------------
#
# ---------------第 37 页---------------
#
# ---------------第 38 页---------------
#
# ---------------第 39 页---------------
#
# ---------------第 40 页---------------
#
# ---------------第 41 页---------------
#
# ---------------第 42 页---------------
#
# ---------------第 43 页---------------
#
# ---------------第 44 页---------------
#
# ---------------第 45 页---------------
#
# ---------------第 46 页---------------
#
# ---------------第 47 页---------------
#
# ---------------第 48 页---------------
#
# ---------------第 49 页---------------
#
# ---------------第 50 页---------------
#
# ---------------第 51 页---------------
#
# ---------------第 52 页---------------
#
# ---------------第 53 页---------------

# %%
import json
import time
import requests

headers = {
    'Host': 'music.163.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
}

def get_comments(page):
    """获取评论信息"""
    # 评论API地址
    url = 'http://music.163.com/api/v1/resource/comments/R_SO_4_2641146470?limit=100&offset=' + str(page)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    result = json.loads(response.text)
    # 只提取comments的内容
    items = result['comments']
    for item in items:
        # 用户ID
        user_id = str(item['user']['userId'])
        # 4、评论时间
        pub_time = item['time']
        pub_time = time.strftime("%Y-%m-%d", time.localtime(pub_time / 1000))
        # 获取用户信息
        user_message = get_user(user_id)
        # 用户年龄
        user_age = str(user_message['age'])
        # 用户性别
        user_gender = str(user_message['gender'])
        # 用户所在地区
        user_city = str(user_message['city'])
        # 保存到本地
        with open('comments_data19.csv', 'a', encoding='utf-8-sig') as f:
            f.write(user_id + ',' + pub_time +',' + user_age + ',' + user_gender + ',' + user_city + ','  +'\n')


def get_user(user_id):
    """ 获取用户注册时间"""
    data = {}
    # 用户API
    url = 'https://music.163.com/api/v1/user/detail/' + str(user_id)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    js = json.loads(response.text)
    if js['code'] == 200:
        # 性别
        data['gender'] = js['profile']['gender']
        # 年龄
        if int(js['profile']['birthday']) < 0:
            data['age'] = 0
        else:
            data['age'] = (2018 - 1970) - (int(js['profile']['birthday']) // (1000 * 365 * 24 * 3600))
        if int(data['age']) < 0:
            data['age'] = 0
        # 城市
        data['city'] = js['profile']['city']
    else:
        data['gender'] = '无'
        data['age'] = '无'
        data['city'] = '无'
    return data

def main():
    for i in range(0, 1050, 20):
        print('\n---------------第 ' + str(i // 20 + 1) + ' 页---------------')
        get_comments(i)

if __name__ == '__main__':
    main()
# Out:
# ---------------第 1 页---------------
#
# ---------------第 2 页---------------
#
# ---------------第 3 页---------------
#
# ---------------第 4 页---------------
#
# ---------------第 5 页---------------
#
# ---------------第 6 页---------------
#
# ---------------第 7 页---------------
#
# ---------------第 8 页---------------
#
# ---------------第 9 页---------------
#
# ---------------第 10 页---------------
#
# ---------------第 11 页---------------
#
# ---------------第 12 页---------------
#
# ---------------第 13 页---------------
#
# ---------------第 14 页---------------
#
# ---------------第 15 页---------------
#
# ---------------第 16 页---------------
#
# ---------------第 17 页---------------
#
# ---------------第 18 页---------------
#
# ---------------第 19 页---------------
#
# ---------------第 20 页---------------
#
# ---------------第 21 页---------------
#
# ---------------第 22 页---------------
#
# ---------------第 23 页---------------
#
# ---------------第 24 页---------------
#
# ---------------第 25 页---------------
#
# ---------------第 26 页---------------
#
# ---------------第 27 页---------------
#
# ---------------第 28 页---------------
#
# ---------------第 29 页---------------
#
# ---------------第 30 页---------------
#
# ---------------第 31 页---------------
#
# ---------------第 32 页---------------
#
# ---------------第 33 页---------------
#
# ---------------第 34 页---------------
#
# ---------------第 35 页---------------
#
# ---------------第 36 页---------------
#
# ---------------第 37 页---------------
#
# ---------------第 38 页---------------
#
# ---------------第 39 页---------------
#
# ---------------第 40 页---------------
#
# ---------------第 41 页---------------
#
# ---------------第 42 页---------------
#
# ---------------第 43 页---------------
#
# ---------------第 44 页---------------
#
# ---------------第 45 页---------------
#
# ---------------第 46 页---------------
#
# ---------------第 47 页---------------
#
# ---------------第 48 页---------------
#
# ---------------第 49 页---------------
#
# ---------------第 50 页---------------
#
# ---------------第 51 页---------------
#
# ---------------第 52 页---------------
#
# ---------------第 53 页---------------

# %%
import json
import time
import requests

headers = {
    'Host': 'music.163.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
}

def get_comments(page):
    """获取评论信息"""
    # 评论API地址
    url = 'http://music.163.com/api/v1/resource/comments/R_SO_4_2640373089?limit=100&offset=' + str(page)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    result = json.loads(response.text)
    # 只提取comments的内容
    items = result['comments']
    for item in items:
        # 用户ID
        user_id = str(item['user']['userId'])
        # 4、评论时间
        pub_time = item['time']
        pub_time = time.strftime("%Y-%m-%d", time.localtime(pub_time / 1000))
        # 获取用户信息
        user_message = get_user(user_id)
        # 用户年龄
        user_age = str(user_message['age'])
        # 用户性别
        user_gender = str(user_message['gender'])
        # 用户所在地区
        user_city = str(user_message['city'])
        # 保存到本地
        with open('comments_data20.csv', 'a', encoding='utf-8-sig') as f:
            f.write(user_id + ',' + pub_time +',' + user_age + ',' + user_gender + ',' + user_city + ','  +'\n')


def get_user(user_id):
    """ 获取用户注册时间"""
    data = {}
    # 用户API
    url = 'https://music.163.com/api/v1/user/detail/' + str(user_id)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    js = json.loads(response.text)
    if js['code'] == 200:
        # 性别
        data['gender'] = js['profile']['gender']
        # 年龄
        if int(js['profile']['birthday']) < 0:
            data['age'] = 0
        else:
            data['age'] = (2018 - 1970) - (int(js['profile']['birthday']) // (1000 * 365 * 24 * 3600))
        if int(data['age']) < 0:
            data['age'] = 0
        # 城市
        data['city'] = js['profile']['city']
    else:
        data['gender'] = '无'
        data['age'] = '无'
        data['city'] = '无'
    return data

def main():
    for i in range(0, 1050, 20):
        print('\n---------------第 ' + str(i // 20 + 1) + ' 页---------------')
        get_comments(i)

if __name__ == '__main__':
    main()
# Out:
# ---------------第 1 页---------------
#
# ---------------第 2 页---------------
#
# ---------------第 3 页---------------
#
# ---------------第 4 页---------------
#
# ---------------第 5 页---------------
#
# ---------------第 6 页---------------
#
# ---------------第 7 页---------------
#
# ---------------第 8 页---------------
#
# ---------------第 9 页---------------
#
# ---------------第 10 页---------------
#
# ---------------第 11 页---------------
#
# ---------------第 12 页---------------
#
# ---------------第 13 页---------------
#
# ---------------第 14 页---------------
#
# ---------------第 15 页---------------
#
# ---------------第 16 页---------------
#
# ---------------第 17 页---------------
#
# ---------------第 18 页---------------
#
# ---------------第 19 页---------------
#
# ---------------第 20 页---------------
#
# ---------------第 21 页---------------
#
# ---------------第 22 页---------------
#
# ---------------第 23 页---------------
#
# ---------------第 24 页---------------
#
# ---------------第 25 页---------------
#
# ---------------第 26 页---------------
#
# ---------------第 27 页---------------
#
# ---------------第 28 页---------------
#
# ---------------第 29 页---------------
#
# ---------------第 30 页---------------
#
# ---------------第 31 页---------------
#
# ---------------第 32 页---------------
#
# ---------------第 33 页---------------
#
# ---------------第 34 页---------------
#
# ---------------第 35 页---------------
#
# ---------------第 36 页---------------
#
# ---------------第 37 页---------------
#
# ---------------第 38 页---------------
#
# ---------------第 39 页---------------
#
# ---------------第 40 页---------------
#
# ---------------第 41 页---------------
#
# ---------------第 42 页---------------
#
# ---------------第 43 页---------------
#
# ---------------第 44 页---------------
#
# ---------------第 45 页---------------
#
# ---------------第 46 页---------------
#
# ---------------第 47 页---------------
#
# ---------------第 48 页---------------
#
# ---------------第 49 页---------------
#
# ---------------第 50 页---------------
#
# ---------------第 51 页---------------
#
# ---------------第 52 页---------------
#
# ---------------第 53 页---------------

# %%
import json
import time
import requests

headers = {
    'Host': 'music.163.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
}

def get_comments(page):
    """获取评论信息"""
    # 评论API地址
    url = 'http://music.163.com/api/v1/resource/comments/R_SO_4_2637774902?limit=100&offset=' + str(page)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    result = json.loads(response.text)
    # 只提取comments的内容
    items = result['comments']
    for item in items:
        # 用户ID
        user_id = str(item['user']['userId'])
        # 4、评论时间
        pub_time = item['time']
        pub_time = time.strftime("%Y-%m-%d", time.localtime(pub_time / 1000))
        # 获取用户信息
        user_message = get_user(user_id)
        # 用户年龄
        user_age = str(user_message['age'])
        # 用户性别
        user_gender = str(user_message['gender'])
        # 用户所在地区
        user_city = str(user_message['city'])
        # 保存到本地
        with open('comments_data21.csv', 'a', encoding='utf-8-sig') as f:
            f.write(user_id + ',' + pub_time +',' + user_age + ',' + user_gender + ',' + user_city + ','  +'\n')


def get_user(user_id):
    """ 获取用户注册时间"""
    data = {}
    # 用户API
    url = 'https://music.163.com/api/v1/user/detail/' + str(user_id)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    js = json.loads(response.text)
    if js['code'] == 200:
        # 性别
        data['gender'] = js['profile']['gender']
        # 年龄
        if int(js['profile']['birthday']) < 0:
            data['age'] = 0
        else:
            data['age'] = (2018 - 1970) - (int(js['profile']['birthday']) // (1000 * 365 * 24 * 3600))
        if int(data['age']) < 0:
            data['age'] = 0
        # 城市
        data['city'] = js['profile']['city']
    else:
        data['gender'] = '无'
        data['age'] = '无'
        data['city'] = '无'
    return data

def main():
    for i in range(0, 1050, 20):
        print('\n---------------第 ' + str(i // 20 + 1) + ' 页---------------')
        get_comments(i)

if __name__ == '__main__':
    main()
# Out:
# ---------------第 1 页---------------
#
# ---------------第 2 页---------------
#
# ---------------第 3 页---------------
#
# ---------------第 4 页---------------
#
# ---------------第 5 页---------------
#
# ---------------第 6 页---------------
#
# ---------------第 7 页---------------
#
# ---------------第 8 页---------------
#
# ---------------第 9 页---------------
#
# ---------------第 10 页---------------
#
# ---------------第 11 页---------------
#
# ---------------第 12 页---------------
#
# ---------------第 13 页---------------
#
# ---------------第 14 页---------------
#
# ---------------第 15 页---------------
#
# ---------------第 16 页---------------
#
# ---------------第 17 页---------------
#
# ---------------第 18 页---------------
#
# ---------------第 19 页---------------
#
# ---------------第 20 页---------------
#
# ---------------第 21 页---------------
#
# ---------------第 22 页---------------
#
# ---------------第 23 页---------------
#
# ---------------第 24 页---------------
#
# ---------------第 25 页---------------
#
# ---------------第 26 页---------------
#
# ---------------第 27 页---------------
#
# ---------------第 28 页---------------
#
# ---------------第 29 页---------------
#
# ---------------第 30 页---------------
#
# ---------------第 31 页---------------
#
# ---------------第 32 页---------------
#
# ---------------第 33 页---------------
#
# ---------------第 34 页---------------
#
# ---------------第 35 页---------------
#
# ---------------第 36 页---------------
#
# ---------------第 37 页---------------
#
# ---------------第 38 页---------------
#
# ---------------第 39 页---------------
#
# ---------------第 40 页---------------
#
# ---------------第 41 页---------------
#
# ---------------第 42 页---------------
#
# ---------------第 43 页---------------
#
# ---------------第 44 页---------------
#
# ---------------第 45 页---------------
#
# ---------------第 46 页---------------
#
# ---------------第 47 页---------------
#
# ---------------第 48 页---------------
#
# ---------------第 49 页---------------
#
# ---------------第 50 页---------------
#
# ---------------第 51 页---------------
#
# ---------------第 52 页---------------
#
# ---------------第 53 页---------------

# %%
import json
import time
import requests

headers = {
    'Host': 'music.163.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
}

def get_comments(page):
    """获取评论信息"""
    # 评论API地址
    url = 'http://music.163.com/api/v1/resource/comments/R_SO_4_2639710803?limit=100&offset=' + str(page)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    result = json.loads(response.text)
    # 只提取comments的内容
    items = result['comments']
    for item in items:
        # 用户ID
        user_id = str(item['user']['userId'])
        # 4、评论时间
        pub_time = item['time']
        pub_time = time.strftime("%Y-%m-%d", time.localtime(pub_time / 1000))
        # 获取用户信息
        user_message = get_user(user_id)
        # 用户年龄
        user_age = str(user_message['age'])
        # 用户性别
        user_gender = str(user_message['gender'])
        # 用户所在地区
        user_city = str(user_message['city'])
        # 保存到本地
        with open('comments_data22.csv', 'a', encoding='utf-8-sig') as f:
            f.write(user_id + ',' + pub_time +',' + user_age + ',' + user_gender + ',' + user_city + ','  +'\n')


def get_user(user_id):
    """ 获取用户注册时间"""
    data = {}
    # 用户API
    url = 'https://music.163.com/api/v1/user/detail/' + str(user_id)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    js = json.loads(response.text)
    if js['code'] == 200:
        # 性别
        data['gender'] = js['profile']['gender']
        # 年龄
        if int(js['profile']['birthday']) < 0:
            data['age'] = 0
        else:
            data['age'] = (2018 - 1970) - (int(js['profile']['birthday']) // (1000 * 365 * 24 * 3600))
        if int(data['age']) < 0:
            data['age'] = 0
        # 城市
        data['city'] = js['profile']['city']
    else:
        data['gender'] = '无'
        data['age'] = '无'
        data['city'] = '无'
    return data

def main():
    for i in range(0, 1050, 20):
        print('\n---------------第 ' + str(i // 20 + 1) + ' 页---------------')
        get_comments(i)

if __name__ == '__main__':
    main()
# Out:
# ---------------第 1 页---------------
#
# ---------------第 2 页---------------
#
# ---------------第 3 页---------------
#
# ---------------第 4 页---------------
#
# ---------------第 5 页---------------
#
# ---------------第 6 页---------------
#
# ---------------第 7 页---------------
#
# ---------------第 8 页---------------
#
# ---------------第 9 页---------------
#
# ---------------第 10 页---------------
#
# ---------------第 11 页---------------
#
# ---------------第 12 页---------------
#
# ---------------第 13 页---------------
#
# ---------------第 14 页---------------
#
# ---------------第 15 页---------------
#
# ---------------第 16 页---------------
#
# ---------------第 17 页---------------
#
# ---------------第 18 页---------------
#
# ---------------第 19 页---------------
#
# ---------------第 20 页---------------
#
# ---------------第 21 页---------------
#
# ---------------第 22 页---------------
#
# ---------------第 23 页---------------
#
# ---------------第 24 页---------------
#
# ---------------第 25 页---------------
#
# ---------------第 26 页---------------
#
# ---------------第 27 页---------------
#
# ---------------第 28 页---------------
#
# ---------------第 29 页---------------
#
# ---------------第 30 页---------------
#
# ---------------第 31 页---------------
#
# ---------------第 32 页---------------
#
# ---------------第 33 页---------------
#
# ---------------第 34 页---------------
#
# ---------------第 35 页---------------
#
# ---------------第 36 页---------------
#
# ---------------第 37 页---------------
#
# ---------------第 38 页---------------
#
# ---------------第 39 页---------------
#
# ---------------第 40 页---------------
#
# ---------------第 41 页---------------
#
# ---------------第 42 页---------------
#
# ---------------第 43 页---------------
#
# ---------------第 44 页---------------
#
# ---------------第 45 页---------------
#
# ---------------第 46 页---------------
#
# ---------------第 47 页---------------
#
# ---------------第 48 页---------------
#
# ---------------第 49 页---------------
#
# ---------------第 50 页---------------
#
# ---------------第 51 页---------------
#
# ---------------第 52 页---------------
#
# ---------------第 53 页---------------

# %%
import json
import time
import requests

headers = {
    'Host': 'music.163.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
}

def get_comments(page):
    """获取评论信息"""
    # 评论API地址
    url = 'http://music.163.com/api/v1/resource/comments/R_SO_4_2641070896?limit=100&offset=' + str(page)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    result = json.loads(response.text)
    # 只提取comments的内容
    items = result['comments']
    for item in items:
        # 用户ID
        user_id = str(item['user']['userId'])
        # 4、评论时间
        pub_time = item['time']
        pub_time = time.strftime("%Y-%m-%d", time.localtime(pub_time / 1000))
        # 获取用户信息
        user_message = get_user(user_id)
        # 用户年龄
        user_age = str(user_message['age'])
        # 用户性别
        user_gender = str(user_message['gender'])
        # 用户所在地区
        user_city = str(user_message['city'])
        # 保存到本地
        with open('comments_data23.csv', 'a', encoding='utf-8-sig') as f:
            f.write(user_id + ',' + pub_time +',' + user_age + ',' + user_gender + ',' + user_city + ','  +'\n')


def get_user(user_id):
    """ 获取用户注册时间"""
    data = {}
    # 用户API
    url = 'https://music.163.com/api/v1/user/detail/' + str(user_id)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    js = json.loads(response.text)
    if js['code'] == 200:
        # 性别
        data['gender'] = js['profile']['gender']
        # 年龄
        if int(js['profile']['birthday']) < 0:
            data['age'] = 0
        else:
            data['age'] = (2018 - 1970) - (int(js['profile']['birthday']) // (1000 * 365 * 24 * 3600))
        if int(data['age']) < 0:
            data['age'] = 0
        # 城市
        data['city'] = js['profile']['city']
    else:
        data['gender'] = '无'
        data['age'] = '无'
        data['city'] = '无'
    return data

def main():
    for i in range(0, 1050, 20):
        print('\n---------------第 ' + str(i // 20 + 1) + ' 页---------------')
        get_comments(i)

if __name__ == '__main__':
    main()
# Out:
# ---------------第 1 页---------------
#
# ---------------第 2 页---------------
#
# ---------------第 3 页---------------
#
# ---------------第 4 页---------------
#
# ---------------第 5 页---------------
#
# ---------------第 6 页---------------
#
# ---------------第 7 页---------------
#
# ---------------第 8 页---------------
#
# ---------------第 9 页---------------
#
# ---------------第 10 页---------------
#
# ---------------第 11 页---------------
#
# ---------------第 12 页---------------
#
# ---------------第 13 页---------------
#
# ---------------第 14 页---------------
#
# ---------------第 15 页---------------
#
# ---------------第 16 页---------------
#
# ---------------第 17 页---------------
#
# ---------------第 18 页---------------
#
# ---------------第 19 页---------------
#
# ---------------第 20 页---------------
#
# ---------------第 21 页---------------
#
# ---------------第 22 页---------------
#
# ---------------第 23 页---------------
#
# ---------------第 24 页---------------
#
# ---------------第 25 页---------------
#
# ---------------第 26 页---------------
#
# ---------------第 27 页---------------
#
# ---------------第 28 页---------------
#
# ---------------第 29 页---------------
#
# ---------------第 30 页---------------
#
# ---------------第 31 页---------------
#
# ---------------第 32 页---------------
#
# ---------------第 33 页---------------
#
# ---------------第 34 页---------------
#
# ---------------第 35 页---------------
#
# ---------------第 36 页---------------
#
# ---------------第 37 页---------------
#
# ---------------第 38 页---------------
#
# ---------------第 39 页---------------
#
# ---------------第 40 页---------------
#
# ---------------第 41 页---------------
#
# ---------------第 42 页---------------
#
# ---------------第 43 页---------------
#
# ---------------第 44 页---------------
#
# ---------------第 45 页---------------
#
# ---------------第 46 页---------------
#
# ---------------第 47 页---------------
#
# ---------------第 48 页---------------
#
# ---------------第 49 页---------------
#
# ---------------第 50 页---------------
#
# ---------------第 51 页---------------
#
# ---------------第 52 页---------------
#
# ---------------第 53 页---------------

# %%
import json
import time
import requests

headers = {
    'Host': 'music.163.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
}

def get_comments(page):
    """获取评论信息"""
    # 评论API地址
    url = 'http://music.163.com/api/v1/resource/comments/R_SO_4_2638550590?limit=100&offset=' + str(page)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    result = json.loads(response.text)
    # 只提取comments的内容
    items = result['comments']
    for item in items:
        # 用户ID
        user_id = str(item['user']['userId'])
        # 4、评论时间
        pub_time = item['time']
        pub_time = time.strftime("%Y-%m-%d", time.localtime(pub_time / 1000))
        # 获取用户信息
        user_message = get_user(user_id)
        # 用户年龄
        user_age = str(user_message['age'])
        # 用户性别
        user_gender = str(user_message['gender'])
        # 用户所在地区
        user_city = str(user_message['city'])
        # 保存到本地
        with open('comments_data24.csv', 'a', encoding='utf-8-sig') as f:
            f.write(user_id + ',' + pub_time +',' + user_age + ',' + user_gender + ',' + user_city + ','  +'\n')


def get_user(user_id):
    """ 获取用户注册时间"""
    data = {}
    # 用户API
    url = 'https://music.163.com/api/v1/user/detail/' + str(user_id)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    js = json.loads(response.text)
    if js['code'] == 200:
        # 性别
        data['gender'] = js['profile']['gender']
        # 年龄
        if int(js['profile']['birthday']) < 0:
            data['age'] = 0
        else:
            data['age'] = (2018 - 1970) - (int(js['profile']['birthday']) // (1000 * 365 * 24 * 3600))
        if int(data['age']) < 0:
            data['age'] = 0
        # 城市
        data['city'] = js['profile']['city']
    else:
        data['gender'] = '无'
        data['age'] = '无'
        data['city'] = '无'
    return data

def main():
    for i in range(0, 1050, 20):
        print('\n---------------第 ' + str(i // 20 + 1) + ' 页---------------')
        get_comments(i)

if __name__ == '__main__':
    main()
# Out:
# ---------------第 1 页---------------
#
# ---------------第 2 页---------------
#
# ---------------第 3 页---------------
#
# ---------------第 4 页---------------
#
# ---------------第 5 页---------------
#
# ---------------第 6 页---------------
#
# ---------------第 7 页---------------
#
# ---------------第 8 页---------------
#
# ---------------第 9 页---------------
#
# ---------------第 10 页---------------
#
# ---------------第 11 页---------------
#
# ---------------第 12 页---------------
#
# ---------------第 13 页---------------
#
# ---------------第 14 页---------------
#
# ---------------第 15 页---------------
#
# ---------------第 16 页---------------
#
# ---------------第 17 页---------------
#
# ---------------第 18 页---------------
#
# ---------------第 19 页---------------
#
# ---------------第 20 页---------------
#
# ---------------第 21 页---------------
#
# ---------------第 22 页---------------
#
# ---------------第 23 页---------------
#
# ---------------第 24 页---------------
#
# ---------------第 25 页---------------
#
# ---------------第 26 页---------------
#
# ---------------第 27 页---------------
#
# ---------------第 28 页---------------
#
# ---------------第 29 页---------------
#
# ---------------第 30 页---------------
#
# ---------------第 31 页---------------
#
# ---------------第 32 页---------------
#
# ---------------第 33 页---------------
#
# ---------------第 34 页---------------
#
# ---------------第 35 页---------------
#
# ---------------第 36 页---------------
#
# ---------------第 37 页---------------
#
# ---------------第 38 页---------------
#
# ---------------第 39 页---------------
#
# ---------------第 40 页---------------
#
# ---------------第 41 页---------------
#
# ---------------第 42 页---------------
#
# ---------------第 43 页---------------
#
# ---------------第 44 页---------------
#
# ---------------第 45 页---------------
#
# ---------------第 46 页---------------
#
# ---------------第 47 页---------------
#
# ---------------第 48 页---------------
#
# ---------------第 49 页---------------
#
# ---------------第 50 页---------------
#
# ---------------第 51 页---------------
#
# ---------------第 52 页---------------
#
# ---------------第 53 页---------------

# %%
import json
import time
import requests

headers = {
    'Host': 'music.163.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
}

def get_comments(page):
    """获取评论信息"""
    # 评论API地址
    url = 'http://music.163.com/api/v1/resource/comments/R_SO_4_2640303430?limit=100&offset=' + str(page)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    result = json.loads(response.text)
    # 只提取comments的内容
    items = result['comments']
    for item in items:
        # 用户ID
        user_id = str(item['user']['userId'])
        # 4、评论时间
        pub_time = item['time']
        pub_time = time.strftime("%Y-%m-%d", time.localtime(pub_time / 1000))
        # 获取用户信息
        user_message = get_user(user_id)
        # 用户年龄
        user_age = str(user_message['age'])
        # 用户性别
        user_gender = str(user_message['gender'])
        # 用户所在地区
        user_city = str(user_message['city'])
        # 保存到本地
        with open('comments_data25.csv', 'a', encoding='utf-8-sig') as f:
            f.write(user_id + ',' + pub_time +',' + user_age + ',' + user_gender + ',' + user_city + ','  +'\n')


def get_user(user_id):
    """ 获取用户注册时间"""
    data = {}
    # 用户API
    url = 'https://music.163.com/api/v1/user/detail/' + str(user_id)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    js = json.loads(response.text)
    if js['code'] == 200:
        # 性别
        data['gender'] = js['profile']['gender']
        # 年龄
        if int(js['profile']['birthday']) < 0:
            data['age'] = 0
        else:
            data['age'] = (2018 - 1970) - (int(js['profile']['birthday']) // (1000 * 365 * 24 * 3600))
        if int(data['age']) < 0:
            data['age'] = 0
        # 城市
        data['city'] = js['profile']['city']
    else:
        data['gender'] = '无'
        data['age'] = '无'
        data['city'] = '无'
    return data

def main():
    for i in range(0, 1050, 20):
        print('\n---------------第 ' + str(i // 20 + 1) + ' 页---------------')
        get_comments(i)

if __name__ == '__main__':
    main()
# Out:
# ---------------第 1 页---------------
#
# ---------------第 2 页---------------
#
# ---------------第 3 页---------------
#
# ---------------第 4 页---------------
#
# ---------------第 5 页---------------
#
# ---------------第 6 页---------------
#
# ---------------第 7 页---------------
#
# ---------------第 8 页---------------
#
# ---------------第 9 页---------------
#
# ---------------第 10 页---------------
#
# ---------------第 11 页---------------
#
# ---------------第 12 页---------------
#
# ---------------第 13 页---------------
#
# ---------------第 14 页---------------
#
# ---------------第 15 页---------------
#
# ---------------第 16 页---------------
#
# ---------------第 17 页---------------
#
# ---------------第 18 页---------------
#
# ---------------第 19 页---------------
#
# ---------------第 20 页---------------
#
# ---------------第 21 页---------------
#
# ---------------第 22 页---------------
#
# ---------------第 23 页---------------
#
# ---------------第 24 页---------------
#
# ---------------第 25 页---------------
#
# ---------------第 26 页---------------
#
# ---------------第 27 页---------------
#
# ---------------第 28 页---------------
#
# ---------------第 29 页---------------
#
# ---------------第 30 页---------------
#
# ---------------第 31 页---------------
#
# ---------------第 32 页---------------
#
# ---------------第 33 页---------------
#
# ---------------第 34 页---------------
#
# ---------------第 35 页---------------
#
# ---------------第 36 页---------------
#
# ---------------第 37 页---------------
#
# ---------------第 38 页---------------
#
# ---------------第 39 页---------------
#
# ---------------第 40 页---------------
#
# ---------------第 41 页---------------
#
# ---------------第 42 页---------------
#
# ---------------第 43 页---------------
#
# ---------------第 44 页---------------
#
# ---------------第 45 页---------------
#
# ---------------第 46 页---------------
#
# ---------------第 47 页---------------
#
# ---------------第 48 页---------------
#
# ---------------第 49 页---------------
#
# ---------------第 50 页---------------
#
# ---------------第 51 页---------------
#
# ---------------第 52 页---------------
#
# ---------------第 53 页---------------

# %%
import json
import time
import requests

headers = {
    'Host': 'music.163.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
}

def get_comments(page):
    """获取评论信息"""
    # 评论API地址
    url = 'http://music.163.com/api/v1/resource/comments/R_SO_4_2638675581?limit=100&offset=' + str(page)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    result = json.loads(response.text)
    # 只提取comments的内容
    items = result['comments']
    for item in items:
        # 用户ID
        user_id = str(item['user']['userId'])
        # 4、评论时间
        pub_time = item['time']
        pub_time = time.strftime("%Y-%m-%d", time.localtime(pub_time / 1000))
        # 获取用户信息
        user_message = get_user(user_id)
        # 用户年龄
        user_age = str(user_message['age'])
        # 用户性别
        user_gender = str(user_message['gender'])
        # 用户所在地区
        user_city = str(user_message['city'])
        # 保存到本地
        with open('comments_data26.csv', 'a', encoding='utf-8-sig') as f:
            f.write(user_id + ',' + pub_time +',' + user_age + ',' + user_gender + ',' + user_city + ','  +'\n')


def get_user(user_id):
    """ 获取用户注册时间"""
    data = {}
    # 用户API
    url = 'https://music.163.com/api/v1/user/detail/' + str(user_id)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    js = json.loads(response.text)
    if js['code'] == 200:
        # 性别
        data['gender'] = js['profile']['gender']
        # 年龄
        if int(js['profile']['birthday']) < 0:
            data['age'] = 0
        else:
            data['age'] = (2018 - 1970) - (int(js['profile']['birthday']) // (1000 * 365 * 24 * 3600))
        if int(data['age']) < 0:
            data['age'] = 0
        # 城市
        data['city'] = js['profile']['city']
    else:
        data['gender'] = '无'
        data['age'] = '无'
        data['city'] = '无'
    return data

def main():
    for i in range(0, 1050, 20):
        print('\n---------------第 ' + str(i // 20 + 1) + ' 页---------------')
        get_comments(i)

if __name__ == '__main__':
    main()
# Out:
# ---------------第 1 页---------------
#
# ---------------第 2 页---------------
#
# ---------------第 3 页---------------
#
# ---------------第 4 页---------------
#
# ---------------第 5 页---------------
#
# ---------------第 6 页---------------
#
# ---------------第 7 页---------------
#
# ---------------第 8 页---------------
#
# ---------------第 9 页---------------
#
# ---------------第 10 页---------------
#
# ---------------第 11 页---------------
#
# ---------------第 12 页---------------
#
# ---------------第 13 页---------------
#
# ---------------第 14 页---------------
#
# ---------------第 15 页---------------
#
# ---------------第 16 页---------------
#
# ---------------第 17 页---------------
#
# ---------------第 18 页---------------
#
# ---------------第 19 页---------------
#
# ---------------第 20 页---------------
#
# ---------------第 21 页---------------
#
# ---------------第 22 页---------------
#
# ---------------第 23 页---------------
#
# ---------------第 24 页---------------
#
# ---------------第 25 页---------------
#
# ---------------第 26 页---------------
#
# ---------------第 27 页---------------
#
# ---------------第 28 页---------------
#
# ---------------第 29 页---------------
#
# ---------------第 30 页---------------
#
# ---------------第 31 页---------------
#
# ---------------第 32 页---------------
#
# ---------------第 33 页---------------
#
# ---------------第 34 页---------------
#
# ---------------第 35 页---------------
#
# ---------------第 36 页---------------
#
# ---------------第 37 页---------------
#
# ---------------第 38 页---------------
#
# ---------------第 39 页---------------
#
# ---------------第 40 页---------------
#
# ---------------第 41 页---------------
#
# ---------------第 42 页---------------
#
# ---------------第 43 页---------------
#
# ---------------第 44 页---------------
#
# ---------------第 45 页---------------
#
# ---------------第 46 页---------------
#
# ---------------第 47 页---------------
#
# ---------------第 48 页---------------
#
# ---------------第 49 页---------------
#
# ---------------第 50 页---------------
#
# ---------------第 51 页---------------
#
# ---------------第 52 页---------------
#
# ---------------第 53 页---------------

# %%
import json
import time
import requests

headers = {
    'Host': 'music.163.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
}

def get_comments(page):
    """获取评论信息"""
    # 评论API地址
    url = 'http://music.163.com/api/v1/resource/comments/R_SO_4_2641070900?limit=100&offset=' + str(page)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    result = json.loads(response.text)
    # 只提取comments的内容
    items = result['comments']
    for item in items:
        # 用户ID
        user_id = str(item['user']['userId'])
        # 4、评论时间
        pub_time = item['time']
        pub_time = time.strftime("%Y-%m-%d", time.localtime(pub_time / 1000))
        # 获取用户信息
        user_message = get_user(user_id)
        # 用户年龄
        user_age = str(user_message['age'])
        # 用户性别
        user_gender = str(user_message['gender'])
        # 用户所在地区
        user_city = str(user_message['city'])
        # 保存到本地
        with open('comments_data27.csv', 'a', encoding='utf-8-sig') as f:
            f.write(user_id + ',' + pub_time +',' + user_age + ',' + user_gender + ',' + user_city + ','  +'\n')


def get_user(user_id):
    """ 获取用户注册时间"""
    data = {}
    # 用户API
    url = 'https://music.163.com/api/v1/user/detail/' + str(user_id)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    js = json.loads(response.text)
    if js['code'] == 200:
        # 性别
        data['gender'] = js['profile']['gender']
        # 年龄
        if int(js['profile']['birthday']) < 0:
            data['age'] = 0
        else:
            data['age'] = (2018 - 1970) - (int(js['profile']['birthday']) // (1000 * 365 * 24 * 3600))
        if int(data['age']) < 0:
            data['age'] = 0
        # 城市
        data['city'] = js['profile']['city']
    else:
        data['gender'] = '无'
        data['age'] = '无'
        data['city'] = '无'
    return data

def main():
    for i in range(0, 1050, 20):
        print('\n---------------第 ' + str(i // 20 + 1) + ' 页---------------')
        get_comments(i)

if __name__ == '__main__':
    main()
# Out:
# ---------------第 1 页---------------
#
# ---------------第 2 页---------------
#
# ---------------第 3 页---------------
#
# ---------------第 4 页---------------
#
# ---------------第 5 页---------------
#
# ---------------第 6 页---------------
#
# ---------------第 7 页---------------
#
# ---------------第 8 页---------------
#
# ---------------第 9 页---------------
#
# ---------------第 10 页---------------
#
# ---------------第 11 页---------------
#
# ---------------第 12 页---------------
#
# ---------------第 13 页---------------
#
# ---------------第 14 页---------------
#
# ---------------第 15 页---------------
#
# ---------------第 16 页---------------
#
# ---------------第 17 页---------------
#
# ---------------第 18 页---------------
#
# ---------------第 19 页---------------
#
# ---------------第 20 页---------------
#
# ---------------第 21 页---------------
#
# ---------------第 22 页---------------
#
# ---------------第 23 页---------------
#
# ---------------第 24 页---------------
#
# ---------------第 25 页---------------
#
# ---------------第 26 页---------------
#
# ---------------第 27 页---------------
#
# ---------------第 28 页---------------
#
# ---------------第 29 页---------------
#
# ---------------第 30 页---------------
#
# ---------------第 31 页---------------
#
# ---------------第 32 页---------------
#
# ---------------第 33 页---------------
#
# ---------------第 34 页---------------
#
# ---------------第 35 页---------------
#
# ---------------第 36 页---------------
#
# ---------------第 37 页---------------
#
# ---------------第 38 页---------------
#
# ---------------第 39 页---------------
#
# ---------------第 40 页---------------
#
# ---------------第 41 页---------------
#
# ---------------第 42 页---------------
#
# ---------------第 43 页---------------
#
# ---------------第 44 页---------------
#
# ---------------第 45 页---------------
#
# ---------------第 46 页---------------
#
# ---------------第 47 页---------------
#
# ---------------第 48 页---------------
#
# ---------------第 49 页---------------
#
# ---------------第 50 页---------------
#
# ---------------第 51 页---------------
#
# ---------------第 52 页---------------
#
# ---------------第 53 页---------------

# %%
import json
import time
import requests

headers = {
    'Host': 'music.163.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
}

def get_comments(page):
    """获取评论信息"""
    # 评论API地址
    url = 'http://music.163.com/api/v1/resource/comments/R_SO_4_2640452795?limit=100&offset=' + str(page)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    result = json.loads(response.text)
    # 只提取comments的内容
    items = result['comments']
    for item in items:
        # 用户ID
        user_id = str(item['user']['userId'])
        # 4、评论时间
        pub_time = item['time']
        pub_time = time.strftime("%Y-%m-%d", time.localtime(pub_time / 1000))
        # 获取用户信息
        user_message = get_user(user_id)
        # 用户年龄
        user_age = str(user_message['age'])
        # 用户性别
        user_gender = str(user_message['gender'])
        # 用户所在地区
        user_city = str(user_message['city'])
        # 保存到本地
        with open('comments_data28.csv', 'a', encoding='utf-8-sig') as f:
            f.write(user_id + ',' + pub_time +',' + user_age + ',' + user_gender + ',' + user_city + ','  +'\n')


def get_user(user_id):
    """ 获取用户注册时间"""
    data = {}
    # 用户API
    url = 'https://music.163.com/api/v1/user/detail/' + str(user_id)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    js = json.loads(response.text)
    if js['code'] == 200:
        # 性别
        data['gender'] = js['profile']['gender']
        # 年龄
        if int(js['profile']['birthday']) < 0:
            data['age'] = 0
        else:
            data['age'] = (2018 - 1970) - (int(js['profile']['birthday']) // (1000 * 365 * 24 * 3600))
        if int(data['age']) < 0:
            data['age'] = 0
        # 城市
        data['city'] = js['profile']['city']
    else:
        data['gender'] = '无'
        data['age'] = '无'
        data['city'] = '无'
    return data

def main():
    for i in range(0, 1050, 20):
        print('\n---------------第 ' + str(i // 20 + 1) + ' 页---------------')
        get_comments(i)

if __name__ == '__main__':
    main()
# Out:
# ---------------第 1 页---------------
#
# ---------------第 2 页---------------
#
# ---------------第 3 页---------------
#
# ---------------第 4 页---------------
#
# ---------------第 5 页---------------
#
# ---------------第 6 页---------------
#
# ---------------第 7 页---------------
#
# ---------------第 8 页---------------
#
# ---------------第 9 页---------------
#
# ---------------第 10 页---------------
#
# ---------------第 11 页---------------
#
# ---------------第 12 页---------------
#
# ---------------第 13 页---------------
#
# ---------------第 14 页---------------
#
# ---------------第 15 页---------------
#
# ---------------第 16 页---------------
#
# ---------------第 17 页---------------
#
# ---------------第 18 页---------------
#
# ---------------第 19 页---------------
#
# ---------------第 20 页---------------
#
# ---------------第 21 页---------------
#
# ---------------第 22 页---------------
#
# ---------------第 23 页---------------
#
# ---------------第 24 页---------------
#
# ---------------第 25 页---------------
#
# ---------------第 26 页---------------
#
# ---------------第 27 页---------------
#
# ---------------第 28 页---------------
#
# ---------------第 29 页---------------
#
# ---------------第 30 页---------------
#
# ---------------第 31 页---------------
#
# ---------------第 32 页---------------
#
# ---------------第 33 页---------------
#
# ---------------第 34 页---------------
#
# ---------------第 35 页---------------
#
# ---------------第 36 页---------------
#
# ---------------第 37 页---------------
#
# ---------------第 38 页---------------
#
# ---------------第 39 页---------------
#
# ---------------第 40 页---------------
#
# ---------------第 41 页---------------
#
# ---------------第 42 页---------------
#
# ---------------第 43 页---------------
#
# ---------------第 44 页---------------
#
# ---------------第 45 页---------------
#
# ---------------第 46 页---------------
#
# ---------------第 47 页---------------
#
# ---------------第 48 页---------------
#
# ---------------第 49 页---------------
#
# ---------------第 50 页---------------
#
# ---------------第 51 页---------------
#
# ---------------第 52 页---------------
#
# ---------------第 53 页---------------

# %%
import json
import time
import requests

headers = {
    'Host': 'music.163.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
}

def get_comments(page):
    """获取评论信息"""
    # 评论API地址
    url = 'http://music.163.com/api/v1/resource/comments/R_SO_4_2640590721?limit=100&offset=' + str(page)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    result = json.loads(response.text)
    # 只提取comments的内容
    items = result['comments']
    for item in items:
        # 用户ID
        user_id = str(item['user']['userId'])
        # 4、评论时间
        pub_time = item['time']
        pub_time = time.strftime("%Y-%m-%d", time.localtime(pub_time / 1000))
        # 获取用户信息
        user_message = get_user(user_id)
        # 用户年龄
        user_age = str(user_message['age'])
        # 用户性别
        user_gender = str(user_message['gender'])
        # 用户所在地区
        user_city = str(user_message['city'])
        # 保存到本地
        with open('comments_data29.csv', 'a', encoding='utf-8-sig') as f:
            f.write(user_id + ',' + pub_time +',' + user_age + ',' + user_gender + ',' + user_city + ','  +'\n')


def get_user(user_id):
    """ 获取用户注册时间"""
    data = {}
    # 用户API
    url = 'https://music.163.com/api/v1/user/detail/' + str(user_id)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    js = json.loads(response.text)
    if js['code'] == 200:
        # 性别
        data['gender'] = js['profile']['gender']
        # 年龄
        if int(js['profile']['birthday']) < 0:
            data['age'] = 0
        else:
            data['age'] = (2018 - 1970) - (int(js['profile']['birthday']) // (1000 * 365 * 24 * 3600))
        if int(data['age']) < 0:
            data['age'] = 0
        # 城市
        data['city'] = js['profile']['city']
    else:
        data['gender'] = '无'
        data['age'] = '无'
        data['city'] = '无'
    return data

def main():
    for i in range(0, 1050, 20):
        print('\n---------------第 ' + str(i // 20 + 1) + ' 页---------------')
        get_comments(i)

if __name__ == '__main__':
    main()
# Out:
# ---------------第 1 页---------------
#
# ---------------第 2 页---------------
#
# ---------------第 3 页---------------
#
# ---------------第 4 页---------------
#
# ---------------第 5 页---------------
#
# ---------------第 6 页---------------
#
# ---------------第 7 页---------------
#
# ---------------第 8 页---------------
#
# ---------------第 9 页---------------
#
# ---------------第 10 页---------------
#
# ---------------第 11 页---------------
#
# ---------------第 12 页---------------
#
# ---------------第 13 页---------------
#
# ---------------第 14 页---------------
#
# ---------------第 15 页---------------
#
# ---------------第 16 页---------------
#
# ---------------第 17 页---------------
#
# ---------------第 18 页---------------
#
# ---------------第 19 页---------------
#
# ---------------第 20 页---------------
#
# ---------------第 21 页---------------
#
# ---------------第 22 页---------------
#
# ---------------第 23 页---------------
#
# ---------------第 24 页---------------
#
# ---------------第 25 页---------------
#
# ---------------第 26 页---------------
#
# ---------------第 27 页---------------
#
# ---------------第 28 页---------------
#
# ---------------第 29 页---------------
#
# ---------------第 30 页---------------
#
# ---------------第 31 页---------------
#
# ---------------第 32 页---------------
#
# ---------------第 33 页---------------
#
# ---------------第 34 页---------------
#
# ---------------第 35 页---------------
#
# ---------------第 36 页---------------
#
# ---------------第 37 页---------------
#
# ---------------第 38 页---------------
#
# ---------------第 39 页---------------
#
# ---------------第 40 页---------------
#
# ---------------第 41 页---------------
#
# ---------------第 42 页---------------
#
# ---------------第 43 页---------------
#
# ---------------第 44 页---------------
#
# ---------------第 45 页---------------
#
# ---------------第 46 页---------------
#
# ---------------第 47 页---------------
#
# ---------------第 48 页---------------
#
# ---------------第 49 页---------------
#
# ---------------第 50 页---------------
#
# ---------------第 51 页---------------
#
# ---------------第 52 页---------------
#
# ---------------第 53 页---------------

# %%
import json
import time
import requests

headers = {
    'Host': 'music.163.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
}

def get_comments(page):
    """获取评论信息"""
    # 评论API地址
    url = 'http://music.163.com/api/v1/resource/comments/R_SO_4_2639762426?limit=100&offset=' + str(page)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    result = json.loads(response.text)
    # 只提取comments的内容
    items = result['comments']
    for item in items:
        # 用户ID
        user_id = str(item['user']['userId'])
        # 4、评论时间
        pub_time = item['time']
        pub_time = time.strftime("%Y-%m-%d", time.localtime(pub_time / 1000))
        # 获取用户信息
        user_message = get_user(user_id)
        # 用户年龄
        user_age = str(user_message['age'])
        # 用户性别
        user_gender = str(user_message['gender'])
        # 用户所在地区
        user_city = str(user_message['city'])
        # 保存到本地
        with open('comments_data30.csv', 'a', encoding='utf-8-sig') as f:
            f.write(user_id + ',' + pub_time +',' + user_age + ',' + user_gender + ',' + user_city + ','  +'\n')


def get_user(user_id):
    """ 获取用户注册时间"""
    data = {}
    # 用户API
    url = 'https://music.163.com/api/v1/user/detail/' + str(user_id)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    js = json.loads(response.text)
    if js['code'] == 200:
        # 性别
        data['gender'] = js['profile']['gender']
        # 年龄
        if int(js['profile']['birthday']) < 0:
            data['age'] = 0
        else:
            data['age'] = (2018 - 1970) - (int(js['profile']['birthday']) // (1000 * 365 * 24 * 3600))
        if int(data['age']) < 0:
            data['age'] = 0
        # 城市
        data['city'] = js['profile']['city']
    else:
        data['gender'] = '无'
        data['age'] = '无'
        data['city'] = '无'
    return data

def main():
    for i in range(0, 1050, 20):
        print('\n---------------第 ' + str(i // 20 + 1) + ' 页---------------')
        get_comments(i)

if __name__ == '__main__':
    main()
# Out:
# ---------------第 1 页---------------
#
# ---------------第 2 页---------------
#
# ---------------第 3 页---------------
#
# ---------------第 4 页---------------
#
# ---------------第 5 页---------------
#
# ---------------第 6 页---------------
#
# ---------------第 7 页---------------
#
# ---------------第 8 页---------------
#
# ---------------第 9 页---------------
#
# ---------------第 10 页---------------
#
# ---------------第 11 页---------------
#
# ---------------第 12 页---------------
#
# ---------------第 13 页---------------
#
# ---------------第 14 页---------------
#
# ---------------第 15 页---------------
#
# ---------------第 16 页---------------
#
# ---------------第 17 页---------------
#
# ---------------第 18 页---------------
#
# ---------------第 19 页---------------
#
# ---------------第 20 页---------------
#
# ---------------第 21 页---------------
#
# ---------------第 22 页---------------
#
# ---------------第 23 页---------------
#
# ---------------第 24 页---------------
#
# ---------------第 25 页---------------
#
# ---------------第 26 页---------------
#
# ---------------第 27 页---------------
#
# ---------------第 28 页---------------
#
# ---------------第 29 页---------------
#
# ---------------第 30 页---------------
#
# ---------------第 31 页---------------
#
# ---------------第 32 页---------------
#
# ---------------第 33 页---------------
#
# ---------------第 34 页---------------
#
# ---------------第 35 页---------------
#
# ---------------第 36 页---------------
#
# ---------------第 37 页---------------
#
# ---------------第 38 页---------------
#
# ---------------第 39 页---------------
#
# ---------------第 40 页---------------
#
# ---------------第 41 页---------------
#
# ---------------第 42 页---------------
#
# ---------------第 43 页---------------
#
# ---------------第 44 页---------------
#
# ---------------第 45 页---------------
#
# ---------------第 46 页---------------
#
# ---------------第 47 页---------------
#
# ---------------第 48 页---------------
#
# ---------------第 49 页---------------
#
# ---------------第 50 页---------------
#
# ---------------第 51 页---------------
#
# ---------------第 52 页---------------
#
# ---------------第 53 页---------------

# %%
import json
import time
import requests

headers = {
    'Host': 'music.163.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
}

def get_comments(page):
    """获取评论信息"""
    # 评论API地址
    url = 'http://music.163.com/api/v1/resource/comments/R_SO_4_2639312951?limit=100&offset=' + str(page)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    result = json.loads(response.text)
    # 只提取comments的内容
    items = result['comments']
    for item in items:
        # 用户ID
        user_id = str(item['user']['userId'])
        # 4、评论时间
        pub_time = item['time']
        pub_time = time.strftime("%Y-%m-%d", time.localtime(pub_time / 1000))
        # 获取用户信息
        user_message = get_user(user_id)
        # 用户年龄
        user_age = str(user_message['age'])
        # 用户性别
        user_gender = str(user_message['gender'])
        # 用户所在地区
        user_city = str(user_message['city'])
        # 保存到本地
        with open('comments_data31.csv', 'a', encoding='utf-8-sig') as f:
            f.write(user_id + ',' + pub_time +',' + user_age + ',' + user_gender + ',' + user_city + ','  +'\n')


def get_user(user_id):
    """ 获取用户注册时间"""
    data = {}
    # 用户API
    url = 'https://music.163.com/api/v1/user/detail/' + str(user_id)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    js = json.loads(response.text)
    if js['code'] == 200:
        # 性别
        data['gender'] = js['profile']['gender']
        # 年龄
        if int(js['profile']['birthday']) < 0:
            data['age'] = 0
        else:
            data['age'] = (2018 - 1970) - (int(js['profile']['birthday']) // (1000 * 365 * 24 * 3600))
        if int(data['age']) < 0:
            data['age'] = 0
        # 城市
        data['city'] = js['profile']['city']
    else:
        data['gender'] = '无'
        data['age'] = '无'
        data['city'] = '无'
    return data

def main():
    for i in range(0, 1050, 20):
        print('\n---------------第 ' + str(i // 20 + 1) + ' 页---------------')
        get_comments(i)

if __name__ == '__main__':
    main()
# Out:
# ---------------第 1 页---------------
#
# ---------------第 2 页---------------
#
# ---------------第 3 页---------------
#
# ---------------第 4 页---------------
#
# ---------------第 5 页---------------
#
# ---------------第 6 页---------------
#
# ---------------第 7 页---------------
#
# ---------------第 8 页---------------
#
# ---------------第 9 页---------------
#
# ---------------第 10 页---------------
#
# ---------------第 11 页---------------
#
# ---------------第 12 页---------------
#
# ---------------第 13 页---------------
#
# ---------------第 14 页---------------
#
# ---------------第 15 页---------------
#
# ---------------第 16 页---------------
#
# ---------------第 17 页---------------
#
# ---------------第 18 页---------------
#
# ---------------第 19 页---------------
#
# ---------------第 20 页---------------
#
# ---------------第 21 页---------------
#
# ---------------第 22 页---------------
#
# ---------------第 23 页---------------
#
# ---------------第 24 页---------------
#
# ---------------第 25 页---------------
#
# ---------------第 26 页---------------
#
# ---------------第 27 页---------------
#
# ---------------第 28 页---------------
#
# ---------------第 29 页---------------
#
# ---------------第 30 页---------------
#
# ---------------第 31 页---------------
#
# ---------------第 32 页---------------
#
# ---------------第 33 页---------------
#
# ---------------第 34 页---------------
#
# ---------------第 35 页---------------
#
# ---------------第 36 页---------------
#
# ---------------第 37 页---------------
#
# ---------------第 38 页---------------
#
# ---------------第 39 页---------------
#
# ---------------第 40 页---------------
#
# ---------------第 41 页---------------
#
# ---------------第 42 页---------------
#
# ---------------第 43 页---------------
#
# ---------------第 44 页---------------
#
# ---------------第 45 页---------------
#
# ---------------第 46 页---------------
#
# ---------------第 47 页---------------
#
# ---------------第 48 页---------------
#
# ---------------第 49 页---------------
#
# ---------------第 50 页---------------
#
# ---------------第 51 页---------------
#
# ---------------第 52 页---------------
#
# ---------------第 53 页---------------

# %%
import json
import time
import requests

headers = {
    'Host': 'music.163.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
}

def get_comments(page):
    """获取评论信息"""
    # 评论API地址
    url = 'http://music.163.com/api/v1/resource/comments/R_SO_4_2640930707?limit=100&offset=' + str(page)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    result = json.loads(response.text)
    # 只提取comments的内容
    items = result['comments']
    for item in items:
        # 用户ID
        user_id = str(item['user']['userId'])
        # 4、评论时间
        pub_time = item['time']
        pub_time = time.strftime("%Y-%m-%d", time.localtime(pub_time / 1000))
        # 获取用户信息
        user_message = get_user(user_id)
        # 用户年龄
        user_age = str(user_message['age'])
        # 用户性别
        user_gender = str(user_message['gender'])
        # 用户所在地区
        user_city = str(user_message['city'])
        # 保存到本地
        with open('comments_data32.csv', 'a', encoding='utf-8-sig') as f:
            f.write(user_id + ',' + pub_time +',' + user_age + ',' + user_gender + ',' + user_city + ','  +'\n')


def get_user(user_id):
    """ 获取用户注册时间"""
    data = {}
    # 用户API
    url = 'https://music.163.com/api/v1/user/detail/' + str(user_id)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    js = json.loads(response.text)
    if js['code'] == 200:
        # 性别
        data['gender'] = js['profile']['gender']
        # 年龄
        if int(js['profile']['birthday']) < 0:
            data['age'] = 0
        else:
            data['age'] = (2018 - 1970) - (int(js['profile']['birthday']) // (1000 * 365 * 24 * 3600))
        if int(data['age']) < 0:
            data['age'] = 0
        # 城市
        data['city'] = js['profile']['city']
    else:
        data['gender'] = '无'
        data['age'] = '无'
        data['city'] = '无'
    return data

def main():
    for i in range(0, 1050, 20):
        print('\n---------------第 ' + str(i // 20 + 1) + ' 页---------------')
        get_comments(i)

if __name__ == '__main__':
    main()
# Out:
# ---------------第 1 页---------------
#
# ---------------第 2 页---------------
#
# ---------------第 3 页---------------
#
# ---------------第 4 页---------------
#
# ---------------第 5 页---------------
#
# ---------------第 6 页---------------
#
# ---------------第 7 页---------------
#
# ---------------第 8 页---------------
#
# ---------------第 9 页---------------
#
# ---------------第 10 页---------------
#
# ---------------第 11 页---------------
#
# ---------------第 12 页---------------
#
# ---------------第 13 页---------------
#
# ---------------第 14 页---------------
#
# ---------------第 15 页---------------
#
# ---------------第 16 页---------------
#
# ---------------第 17 页---------------
#
# ---------------第 18 页---------------
#
# ---------------第 19 页---------------
#
# ---------------第 20 页---------------
#
# ---------------第 21 页---------------
#
# ---------------第 22 页---------------
#
# ---------------第 23 页---------------
#
# ---------------第 24 页---------------
#
# ---------------第 25 页---------------
#
# ---------------第 26 页---------------
#
# ---------------第 27 页---------------
#
# ---------------第 28 页---------------
#
# ---------------第 29 页---------------
#
# ---------------第 30 页---------------
#
# ---------------第 31 页---------------
#
# ---------------第 32 页---------------
#
# ---------------第 33 页---------------
#
# ---------------第 34 页---------------
#
# ---------------第 35 页---------------
#
# ---------------第 36 页---------------
#
# ---------------第 37 页---------------
#
# ---------------第 38 页---------------
#
# ---------------第 39 页---------------
#
# ---------------第 40 页---------------
#
# ---------------第 41 页---------------
#
# ---------------第 42 页---------------
#
# ---------------第 43 页---------------
#
# ---------------第 44 页---------------
#
# ---------------第 45 页---------------
#
# ---------------第 46 页---------------
#
# ---------------第 47 页---------------
#
# ---------------第 48 页---------------
#
# ---------------第 49 页---------------
#
# ---------------第 50 页---------------
#
# ---------------第 51 页---------------
#
# ---------------第 52 页---------------
#
# ---------------第 53 页---------------

# %%
import json
import time
import requests

headers = {
    'Host': 'music.163.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
}

def get_comments(page):
    """获取评论信息"""
    # 评论API地址
    url = 'http://music.163.com/api/v1/resource/comments/R_SO_4_2641070891?limit=100&offset=' + str(page)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    result = json.loads(response.text)
    # 只提取comments的内容
    items = result['comments']
    for item in items:
        # 用户ID
        user_id = str(item['user']['userId'])
        # 4、评论时间
        pub_time = item['time']
        pub_time = time.strftime("%Y-%m-%d", time.localtime(pub_time / 1000))
        # 获取用户信息
        user_message = get_user(user_id)
        # 用户年龄
        user_age = str(user_message['age'])
        # 用户性别
        user_gender = str(user_message['gender'])
        # 用户所在地区
        user_city = str(user_message['city'])
        # 保存到本地
        with open('comments_data33.csv', 'a', encoding='utf-8-sig') as f:
            f.write(user_id + ',' + pub_time +',' + user_age + ',' + user_gender + ',' + user_city + ','  +'\n')


def get_user(user_id):
    """ 获取用户注册时间"""
    data = {}
    # 用户API
    url = 'https://music.163.com/api/v1/user/detail/' + str(user_id)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    js = json.loads(response.text)
    if js['code'] == 200:
        # 性别
        data['gender'] = js['profile']['gender']
        # 年龄
        if int(js['profile']['birthday']) < 0:
            data['age'] = 0
        else:
            data['age'] = (2018 - 1970) - (int(js['profile']['birthday']) // (1000 * 365 * 24 * 3600))
        if int(data['age']) < 0:
            data['age'] = 0
        # 城市
        data['city'] = js['profile']['city']
    else:
        data['gender'] = '无'
        data['age'] = '无'
        data['city'] = '无'
    return data

def main():
    for i in range(0, 1050, 20):
        print('\n---------------第 ' + str(i // 20 + 1) + ' 页---------------')
        get_comments(i)

if __name__ == '__main__':
    main()
# Out:
# ---------------第 1 页---------------
#
# ---------------第 2 页---------------
#
# ---------------第 3 页---------------
#
# ---------------第 4 页---------------
#
# ---------------第 5 页---------------
#
# ---------------第 6 页---------------
#
# ---------------第 7 页---------------
#
# ---------------第 8 页---------------
#
# ---------------第 9 页---------------
#
# ---------------第 10 页---------------
#
# ---------------第 11 页---------------
#
# ---------------第 12 页---------------
#
# ---------------第 13 页---------------
#
# ---------------第 14 页---------------
#
# ---------------第 15 页---------------
#
# ---------------第 16 页---------------
#
# ---------------第 17 页---------------
#
# ---------------第 18 页---------------
#
# ---------------第 19 页---------------
#
# ---------------第 20 页---------------
#
# ---------------第 21 页---------------
#
# ---------------第 22 页---------------
#
# ---------------第 23 页---------------
#
# ---------------第 24 页---------------
#
# ---------------第 25 页---------------
#
# ---------------第 26 页---------------
#
# ---------------第 27 页---------------
#
# ---------------第 28 页---------------
#
# ---------------第 29 页---------------
#
# ---------------第 30 页---------------
#
# ---------------第 31 页---------------
#
# ---------------第 32 页---------------
#
# ---------------第 33 页---------------
#
# ---------------第 34 页---------------
#
# ---------------第 35 页---------------
#
# ---------------第 36 页---------------
#
# ---------------第 37 页---------------
#
# ---------------第 38 页---------------
#
# ---------------第 39 页---------------
#
# ---------------第 40 页---------------
#
# ---------------第 41 页---------------
#
# ---------------第 42 页---------------
#
# ---------------第 43 页---------------
#
# ---------------第 44 页---------------
#
# ---------------第 45 页---------------
#
# ---------------第 46 页---------------
#
# ---------------第 47 页---------------
#
# ---------------第 48 页---------------
#
# ---------------第 49 页---------------
#
# ---------------第 50 页---------------
#
# ---------------第 51 页---------------
#
# ---------------第 52 页---------------
#
# ---------------第 53 页---------------

# %%
import json
import time
import requests

headers = {
    'Host': 'music.163.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
}

def get_comments(page):
    """获取评论信息"""
    # 评论API地址
    url = 'http://music.163.com/api/v1/resource/comments/R_SO_4_2639689590?limit=100&offset=' + str(page)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    result = json.loads(response.text)
    # 只提取comments的内容
    items = result['comments']
    for item in items:
        # 用户ID
        user_id = str(item['user']['userId'])
        # 4、评论时间
        pub_time = item['time']
        pub_time = time.strftime("%Y-%m-%d", time.localtime(pub_time / 1000))
        # 获取用户信息
        user_message = get_user(user_id)
        # 用户年龄
        user_age = str(user_message['age'])
        # 用户性别
        user_gender = str(user_message['gender'])
        # 用户所在地区
        user_city = str(user_message['city'])
        # 保存到本地
        with open('comments_data34.csv', 'a', encoding='utf-8-sig') as f:
            f.write(user_id + ',' + pub_time +',' + user_age + ',' + user_gender + ',' + user_city + ','  +'\n')


def get_user(user_id):
    """ 获取用户注册时间"""
    data = {}
    # 用户API
    url = 'https://music.163.com/api/v1/user/detail/' + str(user_id)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    js = json.loads(response.text)
    if js['code'] == 200:
        # 性别
        data['gender'] = js['profile']['gender']
        # 年龄
        if int(js['profile']['birthday']) < 0:
            data['age'] = 0
        else:
            data['age'] = (2018 - 1970) - (int(js['profile']['birthday']) // (1000 * 365 * 24 * 3600))
        if int(data['age']) < 0:
            data['age'] = 0
        # 城市
        data['city'] = js['profile']['city']
    else:
        data['gender'] = '无'
        data['age'] = '无'
        data['city'] = '无'
    return data

def main():
    for i in range(0, 1050, 20):
        print('\n---------------第 ' + str(i // 20 + 1) + ' 页---------------')
        get_comments(i)

if __name__ == '__main__':
    main()
# Out:
# ---------------第 1 页---------------
#
# ---------------第 2 页---------------
#
# ---------------第 3 页---------------
#
# ---------------第 4 页---------------
#
# ---------------第 5 页---------------
#
# ---------------第 6 页---------------
#
# ---------------第 7 页---------------
#
# ---------------第 8 页---------------
#
# ---------------第 9 页---------------
#
# ---------------第 10 页---------------
#
# ---------------第 11 页---------------
#
# ---------------第 12 页---------------
#
# ---------------第 13 页---------------
#
# ---------------第 14 页---------------
#
# ---------------第 15 页---------------
#
# ---------------第 16 页---------------
#
# ---------------第 17 页---------------
#
# ---------------第 18 页---------------
#
# ---------------第 19 页---------------
#
# ---------------第 20 页---------------
#
# ---------------第 21 页---------------
#
# ---------------第 22 页---------------
#
# ---------------第 23 页---------------
#
# ---------------第 24 页---------------
#
# ---------------第 25 页---------------
#
# ---------------第 26 页---------------
#
# ---------------第 27 页---------------
#
# ---------------第 28 页---------------
#
# ---------------第 29 页---------------
#
# ---------------第 30 页---------------
#
# ---------------第 31 页---------------
#
# ---------------第 32 页---------------
#
# ---------------第 33 页---------------
#
# ---------------第 34 页---------------
#
# ---------------第 35 页---------------
#
# ---------------第 36 页---------------
#
# ---------------第 37 页---------------
#
# ---------------第 38 页---------------
#
# ---------------第 39 页---------------
#
# ---------------第 40 页---------------
#
# ---------------第 41 页---------------
#
# ---------------第 42 页---------------
#
# ---------------第 43 页---------------
#
# ---------------第 44 页---------------
#
# ---------------第 45 页---------------
#
# ---------------第 46 页---------------
#
# ---------------第 47 页---------------
#
# ---------------第 48 页---------------
#
# ---------------第 49 页---------------
#
# ---------------第 50 页---------------
#
# ---------------第 51 页---------------
#
# ---------------第 52 页---------------
#
# ---------------第 53 页---------------

# %%
import json
import time
import requests

headers = {
    'Host': 'music.163.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
}

def get_comments(page):
    """获取评论信息"""
    # 评论API地址
    url = 'http://music.163.com/api/v1/resource/comments/R_SO_4_2638539442?limit=100&offset=' + str(page)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    result = json.loads(response.text)
    # 只提取comments的内容
    items = result['comments']
    for item in items:
        # 用户ID
        user_id = str(item['user']['userId'])
        # 4、评论时间
        pub_time = item['time']
        pub_time = time.strftime("%Y-%m-%d", time.localtime(pub_time / 1000))
        # 获取用户信息
        user_message = get_user(user_id)
        # 用户年龄
        user_age = str(user_message['age'])
        # 用户性别
        user_gender = str(user_message['gender'])
        # 用户所在地区
        user_city = str(user_message['city'])
        # 保存到本地
        with open('comments_data35.csv', 'a', encoding='utf-8-sig') as f:
            f.write(user_id + ',' + pub_time +',' + user_age + ',' + user_gender + ',' + user_city + ','  +'\n')


def get_user(user_id):
    """ 获取用户注册时间"""
    data = {}
    # 用户API
    url = 'https://music.163.com/api/v1/user/detail/' + str(user_id)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    js = json.loads(response.text)
    if js['code'] == 200:
        # 性别
        data['gender'] = js['profile']['gender']
        # 年龄
        if int(js['profile']['birthday']) < 0:
            data['age'] = 0
        else:
            data['age'] = (2018 - 1970) - (int(js['profile']['birthday']) // (1000 * 365 * 24 * 3600))
        if int(data['age']) < 0:
            data['age'] = 0
        # 城市
        data['city'] = js['profile']['city']
    else:
        data['gender'] = '无'
        data['age'] = '无'
        data['city'] = '无'
    return data

def main():
    for i in range(0, 1050, 20):
        print('\n---------------第 ' + str(i // 20 + 1) + ' 页---------------')
        get_comments(i)

if __name__ == '__main__':
    main()
# Out:
# ---------------第 1 页---------------
#
# ---------------第 2 页---------------
#
# ---------------第 3 页---------------
#
# ---------------第 4 页---------------
#
# ---------------第 5 页---------------
#
# ---------------第 6 页---------------
#
# ---------------第 7 页---------------
#
# ---------------第 8 页---------------
#
# ---------------第 9 页---------------
#
# ---------------第 10 页---------------
#
# ---------------第 11 页---------------
#
# ---------------第 12 页---------------
#
# ---------------第 13 页---------------
#
# ---------------第 14 页---------------
#
# ---------------第 15 页---------------
#
# ---------------第 16 页---------------
#
# ---------------第 17 页---------------
#
# ---------------第 18 页---------------
#
# ---------------第 19 页---------------
#
# ---------------第 20 页---------------
#
# ---------------第 21 页---------------
#
# ---------------第 22 页---------------
#
# ---------------第 23 页---------------
#
# ---------------第 24 页---------------
#
# ---------------第 25 页---------------
#
# ---------------第 26 页---------------
#
# ---------------第 27 页---------------
#
# ---------------第 28 页---------------
#
# ---------------第 29 页---------------
#
# ---------------第 30 页---------------
#
# ---------------第 31 页---------------
#
# ---------------第 32 页---------------
#
# ---------------第 33 页---------------
#
# ---------------第 34 页---------------
#
# ---------------第 35 页---------------
#
# ---------------第 36 页---------------
#
# ---------------第 37 页---------------
#
# ---------------第 38 页---------------
#
# ---------------第 39 页---------------
#
# ---------------第 40 页---------------
#
# ---------------第 41 页---------------
#
# ---------------第 42 页---------------
#
# ---------------第 43 页---------------
#
# ---------------第 44 页---------------
#
# ---------------第 45 页---------------
#
# ---------------第 46 页---------------
#
# ---------------第 47 页---------------
#
# ---------------第 48 页---------------
#
# ---------------第 49 页---------------
#
# ---------------第 50 页---------------
#
# ---------------第 51 页---------------
#
# ---------------第 52 页---------------
#
# ---------------第 53 页---------------

# %%
import json
import time
import requests

headers = {
    'Host': 'music.163.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
}

def get_comments(page):
    """获取评论信息"""
    # 评论API地址
    url = 'http://music.163.com/api/v1/resource/comments/R_SO_4_2638922379?limit=100&offset=' + str(page)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    result = json.loads(response.text)
    # 只提取comments的内容
    items = result['comments']
    for item in items:
        # 用户ID
        user_id = str(item['user']['userId'])
        # 4、评论时间
        pub_time = item['time']
        pub_time = time.strftime("%Y-%m-%d", time.localtime(pub_time / 1000))
        # 获取用户信息
        user_message = get_user(user_id)
        # 用户年龄
        user_age = str(user_message['age'])
        # 用户性别
        user_gender = str(user_message['gender'])
        # 用户所在地区
        user_city = str(user_message['city'])
        # 保存到本地
        with open('comments_data36.csv', 'a', encoding='utf-8-sig') as f:
            f.write(user_id + ',' + pub_time +',' + user_age + ',' + user_gender + ',' + user_city + ','  +'\n')


def get_user(user_id):
    """ 获取用户注册时间"""
    data = {}
    # 用户API
    url = 'https://music.163.com/api/v1/user/detail/' + str(user_id)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    js = json.loads(response.text)
    if js['code'] == 200:
        # 性别
        data['gender'] = js['profile']['gender']
        # 年龄
        if int(js['profile']['birthday']) < 0:
            data['age'] = 0
        else:
            data['age'] = (2018 - 1970) - (int(js['profile']['birthday']) // (1000 * 365 * 24 * 3600))
        if int(data['age']) < 0:
            data['age'] = 0
        # 城市
        data['city'] = js['profile']['city']
    else:
        data['gender'] = '无'
        data['age'] = '无'
        data['city'] = '无'
    return data

def main():
    for i in range(0, 1050, 20):
        print('\n---------------第 ' + str(i // 20 + 1) + ' 页---------------')
        get_comments(i)

if __name__ == '__main__':
    main()
# Out:
# ---------------第 1 页---------------
#
# ---------------第 2 页---------------
#
# ---------------第 3 页---------------
#
# ---------------第 4 页---------------
#
# ---------------第 5 页---------------
#
# ---------------第 6 页---------------
#
# ---------------第 7 页---------------
#
# ---------------第 8 页---------------
#
# ---------------第 9 页---------------
#
# ---------------第 10 页---------------
#
# ---------------第 11 页---------------
#
# ---------------第 12 页---------------
#
# ---------------第 13 页---------------
#
# ---------------第 14 页---------------
#
# ---------------第 15 页---------------
#
# ---------------第 16 页---------------
#
# ---------------第 17 页---------------
#
# ---------------第 18 页---------------
#
# ---------------第 19 页---------------
#
# ---------------第 20 页---------------
#
# ---------------第 21 页---------------
#
# ---------------第 22 页---------------
#
# ---------------第 23 页---------------
#
# ---------------第 24 页---------------
#
# ---------------第 25 页---------------
#
# ---------------第 26 页---------------
#
# ---------------第 27 页---------------
#
# ---------------第 28 页---------------
#
# ---------------第 29 页---------------
#
# ---------------第 30 页---------------
#
# ---------------第 31 页---------------
#
# ---------------第 32 页---------------
#
# ---------------第 33 页---------------
#
# ---------------第 34 页---------------
#
# ---------------第 35 页---------------
#
# ---------------第 36 页---------------
#
# ---------------第 37 页---------------
#
# ---------------第 38 页---------------
#
# ---------------第 39 页---------------
#
# ---------------第 40 页---------------
#
# ---------------第 41 页---------------
#
# ---------------第 42 页---------------
#
# ---------------第 43 页---------------
#
# ---------------第 44 页---------------
#
# ---------------第 45 页---------------
#
# ---------------第 46 页---------------
#
# ---------------第 47 页---------------
#
# ---------------第 48 页---------------
#
# ---------------第 49 页---------------
#
# ---------------第 50 页---------------
#
# ---------------第 51 页---------------
#
# ---------------第 52 页---------------
#
# ---------------第 53 页---------------

# %%
import json
import time
import requests

headers = {
    'Host': 'music.163.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
}

def get_comments(page):
    """获取评论信息"""
    # 评论API地址
    url = 'http://music.163.com/api/v1/resource/comments/R_SO_4_2638766934?limit=100&offset=' + str(page)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    result = json.loads(response.text)
    # 只提取comments的内容
    items = result['comments']
    for item in items:
        # 用户ID
        user_id = str(item['user']['userId'])
        # 4、评论时间
        pub_time = item['time']
        pub_time = time.strftime("%Y-%m-%d", time.localtime(pub_time / 1000))
        # 获取用户信息
        user_message = get_user(user_id)
        # 用户年龄
        user_age = str(user_message['age'])
        # 用户性别
        user_gender = str(user_message['gender'])
        # 用户所在地区
        user_city = str(user_message['city'])
        # 保存到本地
        with open('comments_data37.csv', 'a', encoding='utf-8-sig') as f:
            f.write(user_id + ',' + pub_time +',' + user_age + ',' + user_gender + ',' + user_city + ','  +'\n')


def get_user(user_id):
    """ 获取用户注册时间"""
    data = {}
    # 用户API
    url = 'https://music.163.com/api/v1/user/detail/' + str(user_id)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    js = json.loads(response.text)
    if js['code'] == 200:
        # 性别
        data['gender'] = js['profile']['gender']
        # 年龄
        if int(js['profile']['birthday']) < 0:
            data['age'] = 0
        else:
            data['age'] = (2018 - 1970) - (int(js['profile']['birthday']) // (1000 * 365 * 24 * 3600))
        if int(data['age']) < 0:
            data['age'] = 0
        # 城市
        data['city'] = js['profile']['city']
    else:
        data['gender'] = '无'
        data['age'] = '无'
        data['city'] = '无'
    return data

def main():
    for i in range(0, 1050, 20):
        print('\n---------------第 ' + str(i // 20 + 1) + ' 页---------------')
        get_comments(i)

if __name__ == '__main__':
    main()
# Out:
# ---------------第 1 页---------------
#
# ---------------第 2 页---------------
#
# ---------------第 3 页---------------
#
# ---------------第 4 页---------------
#
# ---------------第 5 页---------------
#
# ---------------第 6 页---------------
#
# ---------------第 7 页---------------
#
# ---------------第 8 页---------------
#
# ---------------第 9 页---------------
#
# ---------------第 10 页---------------
#
# ---------------第 11 页---------------
#
# ---------------第 12 页---------------
#
# ---------------第 13 页---------------
#
# ---------------第 14 页---------------
#
# ---------------第 15 页---------------
#
# ---------------第 16 页---------------
#
# ---------------第 17 页---------------
#
# ---------------第 18 页---------------
#
# ---------------第 19 页---------------
#
# ---------------第 20 页---------------
#
# ---------------第 21 页---------------
#
# ---------------第 22 页---------------
#
# ---------------第 23 页---------------
#
# ---------------第 24 页---------------
#
# ---------------第 25 页---------------
#
# ---------------第 26 页---------------
#
# ---------------第 27 页---------------
#
# ---------------第 28 页---------------
#
# ---------------第 29 页---------------
#
# ---------------第 30 页---------------
#
# ---------------第 31 页---------------
#
# ---------------第 32 页---------------
#
# ---------------第 33 页---------------
#
# ---------------第 34 页---------------
#
# ---------------第 35 页---------------
#
# ---------------第 36 页---------------
#
# ---------------第 37 页---------------
#
# ---------------第 38 页---------------
#
# ---------------第 39 页---------------
#
# ---------------第 40 页---------------
#
# ---------------第 41 页---------------
#
# ---------------第 42 页---------------
#
# ---------------第 43 页---------------
#
# ---------------第 44 页---------------
#
# ---------------第 45 页---------------
#
# ---------------第 46 页---------------
#
# ---------------第 47 页---------------
#
# ---------------第 48 页---------------
#
# ---------------第 49 页---------------
#
# ---------------第 50 页---------------
#
# ---------------第 51 页---------------
#
# ---------------第 52 页---------------
#
# ---------------第 53 页---------------

# %%
import json
import time
import requests

headers = {
    'Host': 'music.163.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
}

def get_comments(page):
    """获取评论信息"""
    # 评论API地址
    url = 'http://music.163.com/api/v1/resource/comments/R_SO_4_2639421225?limit=100&offset=' + str(page)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    result = json.loads(response.text)
    # 只提取comments的内容
    items = result['comments']
    for item in items:
        # 用户ID
        user_id = str(item['user']['userId'])
        # 4、评论时间
        pub_time = item['time']
        pub_time = time.strftime("%Y-%m-%d", time.localtime(pub_time / 1000))
        # 获取用户信息
        user_message = get_user(user_id)
        # 用户年龄
        user_age = str(user_message['age'])
        # 用户性别
        user_gender = str(user_message['gender'])
        # 用户所在地区
        user_city = str(user_message['city'])
        # 保存到本地
        with open('comments_data38.csv', 'a', encoding='utf-8-sig') as f:
            f.write(user_id + ',' + pub_time +',' + user_age + ',' + user_gender + ',' + user_city + ','  +'\n')


def get_user(user_id):
    """ 获取用户注册时间"""
    data = {}
    # 用户API
    url = 'https://music.163.com/api/v1/user/detail/' + str(user_id)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    js = json.loads(response.text)
    if js['code'] == 200:
        # 性别
        data['gender'] = js['profile']['gender']
        # 年龄
        if int(js['profile']['birthday']) < 0:
            data['age'] = 0
        else:
            data['age'] = (2018 - 1970) - (int(js['profile']['birthday']) // (1000 * 365 * 24 * 3600))
        if int(data['age']) < 0:
            data['age'] = 0
        # 城市
        data['city'] = js['profile']['city']
    else:
        data['gender'] = '无'
        data['age'] = '无'
        data['city'] = '无'
    return data

def main():
    for i in range(0, 1050, 20):
        print('\n---------------第 ' + str(i // 20 + 1) + ' 页---------------')
        get_comments(i)

if __name__ == '__main__':
    main()
# Out:
# ---------------第 1 页---------------
#
# ---------------第 2 页---------------
#
# ---------------第 3 页---------------
#
# ---------------第 4 页---------------
#
# ---------------第 5 页---------------
#
# ---------------第 6 页---------------
#
# ---------------第 7 页---------------
#
# ---------------第 8 页---------------
#
# ---------------第 9 页---------------
#
# ---------------第 10 页---------------
#
# ---------------第 11 页---------------
#
# ---------------第 12 页---------------
#
# ---------------第 13 页---------------
#
# ---------------第 14 页---------------
#
# ---------------第 15 页---------------
#
# ---------------第 16 页---------------
#
# ---------------第 17 页---------------
#
# ---------------第 18 页---------------
#
# ---------------第 19 页---------------
#
# ---------------第 20 页---------------
#
# ---------------第 21 页---------------
#
# ---------------第 22 页---------------
#
# ---------------第 23 页---------------
#
# ---------------第 24 页---------------
#
# ---------------第 25 页---------------
#
# ---------------第 26 页---------------
#
# ---------------第 27 页---------------
#
# ---------------第 28 页---------------
#
# ---------------第 29 页---------------
#
# ---------------第 30 页---------------
#
# ---------------第 31 页---------------
#
# ---------------第 32 页---------------
#
# ---------------第 33 页---------------
#
# ---------------第 34 页---------------
#
# ---------------第 35 页---------------
#
# ---------------第 36 页---------------
#
# ---------------第 37 页---------------
#
# ---------------第 38 页---------------
#
# ---------------第 39 页---------------
#
# ---------------第 40 页---------------
#
# ---------------第 41 页---------------
#
# ---------------第 42 页---------------
#
# ---------------第 43 页---------------
#
# ---------------第 44 页---------------
#
# ---------------第 45 页---------------
#
# ---------------第 46 页---------------
#
# ---------------第 47 页---------------
#
# ---------------第 48 页---------------
#
# ---------------第 49 页---------------
#
# ---------------第 50 页---------------
#
# ---------------第 51 页---------------
#
# ---------------第 52 页---------------
#
# ---------------第 53 页---------------

# %%
import json
import time
import requests

headers = {
    'Host': 'music.163.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
}

def get_comments(page):
    """获取评论信息"""
    # 评论API地址
    url = 'http://music.163.com/api/v1/resource/comments/R_SO_4_2641070898?limit=100&offset=' + str(page)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    result = json.loads(response.text)
    # 只提取comments的内容
    items = result['comments']
    for item in items:
        # 用户ID
        user_id = str(item['user']['userId'])
        # 4、评论时间
        pub_time = item['time']
        pub_time = time.strftime("%Y-%m-%d", time.localtime(pub_time / 1000))
        # 获取用户信息
        user_message = get_user(user_id)
        # 用户年龄
        user_age = str(user_message['age'])
        # 用户性别
        user_gender = str(user_message['gender'])
        # 用户所在地区
        user_city = str(user_message['city'])
        # 保存到本地
        with open('comments_data39.csv', 'a', encoding='utf-8-sig') as f:
            f.write(user_id + ',' + pub_time +',' + user_age + ',' + user_gender + ',' + user_city + ','  +'\n')


def get_user(user_id):
    """ 获取用户注册时间"""
    data = {}
    # 用户API
    url = 'https://music.163.com/api/v1/user/detail/' + str(user_id)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    js = json.loads(response.text)
    if js['code'] == 200:
        # 性别
        data['gender'] = js['profile']['gender']
        # 年龄
        if int(js['profile']['birthday']) < 0:
            data['age'] = 0
        else:
            data['age'] = (2018 - 1970) - (int(js['profile']['birthday']) // (1000 * 365 * 24 * 3600))
        if int(data['age']) < 0:
            data['age'] = 0
        # 城市
        data['city'] = js['profile']['city']
    else:
        data['gender'] = '无'
        data['age'] = '无'
        data['city'] = '无'
    return data

def main():
    for i in range(0, 1050, 20):
        print('\n---------------第 ' + str(i // 20 + 1) + ' 页---------------')
        get_comments(i)

if __name__ == '__main__':
    main()
# Out:
# ---------------第 1 页---------------
#
# ---------------第 2 页---------------
#
# ---------------第 3 页---------------
#
# ---------------第 4 页---------------
#
# ---------------第 5 页---------------
#
# ---------------第 6 页---------------
#
# ---------------第 7 页---------------
#
# ---------------第 8 页---------------
#
# ---------------第 9 页---------------
#
# ---------------第 10 页---------------
#
# ---------------第 11 页---------------
#
# ---------------第 12 页---------------
#
# ---------------第 13 页---------------
#
# ---------------第 14 页---------------
#
# ---------------第 15 页---------------
#
# ---------------第 16 页---------------
#
# ---------------第 17 页---------------
#
# ---------------第 18 页---------------
#
# ---------------第 19 页---------------
#
# ---------------第 20 页---------------
#
# ---------------第 21 页---------------
#
# ---------------第 22 页---------------
#
# ---------------第 23 页---------------
#
# ---------------第 24 页---------------
#
# ---------------第 25 页---------------
#
# ---------------第 26 页---------------
#
# ---------------第 27 页---------------
#
# ---------------第 28 页---------------
#
# ---------------第 29 页---------------
#
# ---------------第 30 页---------------
#
# ---------------第 31 页---------------
#
# ---------------第 32 页---------------
#
# ---------------第 33 页---------------
#
# ---------------第 34 页---------------
#
# ---------------第 35 页---------------
#
# ---------------第 36 页---------------
#
# ---------------第 37 页---------------
#
# ---------------第 38 页---------------
#
# ---------------第 39 页---------------
#
# ---------------第 40 页---------------
#
# ---------------第 41 页---------------
#
# ---------------第 42 页---------------
#
# ---------------第 43 页---------------
#
# ---------------第 44 页---------------
#
# ---------------第 45 页---------------
#
# ---------------第 46 页---------------
#
# ---------------第 47 页---------------
#
# ---------------第 48 页---------------
#
# ---------------第 49 页---------------
#
# ---------------第 50 页---------------
#
# ---------------第 51 页---------------
#
# ---------------第 52 页---------------
#
# ---------------第 53 页---------------

# %%
import json
import time
import requests

headers = {
    'Host': 'music.163.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
}

def get_comments(page):
    """获取评论信息"""
    # 评论API地址
    url = 'http://music.163.com/api/v1/resource/comments/R_SO_4_2640028555?limit=100&offset=' + str(page)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    result = json.loads(response.text)
    # 只提取comments的内容
    items = result['comments']
    for item in items:
        # 用户ID
        user_id = str(item['user']['userId'])
        # 4、评论时间
        pub_time = item['time']
        pub_time = time.strftime("%Y-%m-%d", time.localtime(pub_time / 1000))
        # 获取用户信息
        user_message = get_user(user_id)
        # 用户年龄
        user_age = str(user_message['age'])
        # 用户性别
        user_gender = str(user_message['gender'])
        # 用户所在地区
        user_city = str(user_message['city'])
        # 保存到本地
        with open('comments_data40.csv', 'a', encoding='utf-8-sig') as f:
            f.write(user_id + ',' + pub_time +',' + user_age + ',' + user_gender + ',' + user_city + ','  +'\n')


def get_user(user_id):
    """ 获取用户注册时间"""
    data = {}
    # 用户API
    url = 'https://music.163.com/api/v1/user/detail/' + str(user_id)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    js = json.loads(response.text)
    if js['code'] == 200:
        # 性别
        data['gender'] = js['profile']['gender']
        # 年龄
        if int(js['profile']['birthday']) < 0:
            data['age'] = 0
        else:
            data['age'] = (2018 - 1970) - (int(js['profile']['birthday']) // (1000 * 365 * 24 * 3600))
        if int(data['age']) < 0:
            data['age'] = 0
        # 城市
        data['city'] = js['profile']['city']
    else:
        data['gender'] = '无'
        data['age'] = '无'
        data['city'] = '无'
    return data

def main():
    for i in range(0, 1050, 20):
        print('\n---------------第 ' + str(i // 20 + 1) + ' 页---------------')
        get_comments(i)

if __name__ == '__main__':
    main()
# Out:
# ---------------第 1 页---------------
#
# ---------------第 2 页---------------
#
# ---------------第 3 页---------------
#
# ---------------第 4 页---------------
#
# ---------------第 5 页---------------
#
# ---------------第 6 页---------------
#
# ---------------第 7 页---------------
#
# ---------------第 8 页---------------
#
# ---------------第 9 页---------------
#
# ---------------第 10 页---------------
#
# ---------------第 11 页---------------
#
# ---------------第 12 页---------------
#
# ---------------第 13 页---------------
#
# ---------------第 14 页---------------
#
# ---------------第 15 页---------------
#
# ---------------第 16 页---------------
#
# ---------------第 17 页---------------
#
# ---------------第 18 页---------------
#
# ---------------第 19 页---------------
#
# ---------------第 20 页---------------
#
# ---------------第 21 页---------------
#
# ---------------第 22 页---------------
#
# ---------------第 23 页---------------
#
# ---------------第 24 页---------------
#
# ---------------第 25 页---------------
#
# ---------------第 26 页---------------
#
# ---------------第 27 页---------------
#
# ---------------第 28 页---------------
#
# ---------------第 29 页---------------
#
# ---------------第 30 页---------------
#
# ---------------第 31 页---------------
#
# ---------------第 32 页---------------
#
# ---------------第 33 页---------------
#
# ---------------第 34 页---------------
#
# ---------------第 35 页---------------
#
# ---------------第 36 页---------------
#
# ---------------第 37 页---------------
#
# ---------------第 38 页---------------
#
# ---------------第 39 页---------------
#
# ---------------第 40 页---------------
#
# ---------------第 41 页---------------
#
# ---------------第 42 页---------------
#
# ---------------第 43 页---------------
#
# ---------------第 44 页---------------
#
# ---------------第 45 页---------------
#
# ---------------第 46 页---------------
#
# ---------------第 47 页---------------
#
# ---------------第 48 页---------------
#
# ---------------第 49 页---------------
#
# ---------------第 50 页---------------
#
# ---------------第 51 页---------------
#
# ---------------第 52 页---------------
#
# ---------------第 53 页---------------

# %%
import json
import time
import requests

headers = {
    'Host': 'music.163.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
}

def get_comments(page):
    """获取评论信息"""
    # 评论API地址
    url = 'http://music.163.com/api/v1/resource/comments/R_SO_4_2638979833?limit=100&offset=' + str(page)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    result = json.loads(response.text)
    # 只提取comments的内容
    items = result['comments']
    for item in items:
        # 用户ID
        user_id = str(item['user']['userId'])
        # 4、评论时间
        pub_time = item['time']
        pub_time = time.strftime("%Y-%m-%d", time.localtime(pub_time / 1000))
        # 获取用户信息
        user_message = get_user(user_id)
        # 用户年龄
        user_age = str(user_message['age'])
        # 用户性别
        user_gender = str(user_message['gender'])
        # 用户所在地区
        user_city = str(user_message['city'])
        # 保存到本地
        with open('comments_data41.csv', 'a', encoding='utf-8-sig') as f:
            f.write(user_id + ',' + pub_time +',' + user_age + ',' + user_gender + ',' + user_city + ','  +'\n')


def get_user(user_id):
    """ 获取用户注册时间"""
    data = {}
    # 用户API
    url = 'https://music.163.com/api/v1/user/detail/' + str(user_id)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    js = json.loads(response.text)
    if js['code'] == 200:
        # 性别
        data['gender'] = js['profile']['gender']
        # 年龄
        if int(js['profile']['birthday']) < 0:
            data['age'] = 0
        else:
            data['age'] = (2018 - 1970) - (int(js['profile']['birthday']) // (1000 * 365 * 24 * 3600))
        if int(data['age']) < 0:
            data['age'] = 0
        # 城市
        data['city'] = js['profile']['city']
    else:
        data['gender'] = '无'
        data['age'] = '无'
        data['city'] = '无'
    return data

def main():
    for i in range(0, 1050, 20):
        print('\n---------------第 ' + str(i // 20 + 1) + ' 页---------------')
        get_comments(i)

if __name__ == '__main__':
    main()
# Out:
# ---------------第 1 页---------------
#
# ---------------第 2 页---------------
#
# ---------------第 3 页---------------
#
# ---------------第 4 页---------------
#
# ---------------第 5 页---------------
#
# ---------------第 6 页---------------
#
# ---------------第 7 页---------------
#
# ---------------第 8 页---------------
#
# ---------------第 9 页---------------
#
# ---------------第 10 页---------------
#
# ---------------第 11 页---------------
#
# ---------------第 12 页---------------
#
# ---------------第 13 页---------------
#
# ---------------第 14 页---------------
#
# ---------------第 15 页---------------
#
# ---------------第 16 页---------------
#
# ---------------第 17 页---------------
#
# ---------------第 18 页---------------
#
# ---------------第 19 页---------------
#
# ---------------第 20 页---------------
#
# ---------------第 21 页---------------
#
# ---------------第 22 页---------------
#
# ---------------第 23 页---------------
#
# ---------------第 24 页---------------
#
# ---------------第 25 页---------------
#
# ---------------第 26 页---------------
#
# ---------------第 27 页---------------
#
# ---------------第 28 页---------------
#
# ---------------第 29 页---------------
#
# ---------------第 30 页---------------
#
# ---------------第 31 页---------------
#
# ---------------第 32 页---------------
#
# ---------------第 33 页---------------
#
# ---------------第 34 页---------------
#
# ---------------第 35 页---------------
#
# ---------------第 36 页---------------
#
# ---------------第 37 页---------------
#
# ---------------第 38 页---------------
#
# ---------------第 39 页---------------
#
# ---------------第 40 页---------------
#
# ---------------第 41 页---------------
#
# ---------------第 42 页---------------
#
# ---------------第 43 页---------------
#
# ---------------第 44 页---------------
#
# ---------------第 45 页---------------
#
# ---------------第 46 页---------------
#
# ---------------第 47 页---------------
#
# ---------------第 48 页---------------
#
# ---------------第 49 页---------------
#
# ---------------第 50 页---------------
#
# ---------------第 51 页---------------
#
# ---------------第 52 页---------------
#
# ---------------第 53 页---------------

# %%
import json
import time
import requests

headers = {
    'Host': 'music.163.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
}

def get_comments(page):
    """获取评论信息"""
    # 评论API地址
    url = 'http://music.163.com/api/v1/resource/comments/R_SO_4_2640280932?limit=100&offset=' + str(page)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    result = json.loads(response.text)
    # 只提取comments的内容
    items = result['comments']
    for item in items:
        # 用户ID
        user_id = str(item['user']['userId'])
        # 4、评论时间
        pub_time = item['time']
        pub_time = time.strftime("%Y-%m-%d", time.localtime(pub_time / 1000))
        # 获取用户信息
        user_message = get_user(user_id)
        # 用户年龄
        user_age = str(user_message['age'])
        # 用户性别
        user_gender = str(user_message['gender'])
        # 用户所在地区
        user_city = str(user_message['city'])
        # 保存到本地
        with open('comments_data42.csv', 'a', encoding='utf-8-sig') as f:
            f.write(user_id + ',' + pub_time +',' + user_age + ',' + user_gender + ',' + user_city + ','  +'\n')


def get_user(user_id):
    """ 获取用户注册时间"""
    data = {}
    # 用户API
    url = 'https://music.163.com/api/v1/user/detail/' + str(user_id)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    js = json.loads(response.text)
    if js['code'] == 200:
        # 性别
        data['gender'] = js['profile']['gender']
        # 年龄
        if int(js['profile']['birthday']) < 0:
            data['age'] = 0
        else:
            data['age'] = (2018 - 1970) - (int(js['profile']['birthday']) // (1000 * 365 * 24 * 3600))
        if int(data['age']) < 0:
            data['age'] = 0
        # 城市
        data['city'] = js['profile']['city']
    else:
        data['gender'] = '无'
        data['age'] = '无'
        data['city'] = '无'
    return data

def main():
    for i in range(0, 1050, 20):
        print('\n---------------第 ' + str(i // 20 + 1) + ' 页---------------')
        get_comments(i)

if __name__ == '__main__':
    main()
# Out:
# ---------------第 1 页---------------
#
# ---------------第 2 页---------------
#
# ---------------第 3 页---------------
#
# ---------------第 4 页---------------
#
# ---------------第 5 页---------------
#
# ---------------第 6 页---------------
#
# ---------------第 7 页---------------
#
# ---------------第 8 页---------------
#
# ---------------第 9 页---------------
#
# ---------------第 10 页---------------
#
# ---------------第 11 页---------------
#
# ---------------第 12 页---------------
#
# ---------------第 13 页---------------
#
# ---------------第 14 页---------------
#
# ---------------第 15 页---------------
#
# ---------------第 16 页---------------
#
# ---------------第 17 页---------------
#
# ---------------第 18 页---------------
#
# ---------------第 19 页---------------
#
# ---------------第 20 页---------------
#
# ---------------第 21 页---------------
#
# ---------------第 22 页---------------
#
# ---------------第 23 页---------------
#
# ---------------第 24 页---------------
#
# ---------------第 25 页---------------
#
# ---------------第 26 页---------------
#
# ---------------第 27 页---------------
#
# ---------------第 28 页---------------
#
# ---------------第 29 页---------------
#
# ---------------第 30 页---------------
#
# ---------------第 31 页---------------
#
# ---------------第 32 页---------------
#
# ---------------第 33 页---------------
#
# ---------------第 34 页---------------
#
# ---------------第 35 页---------------
#
# ---------------第 36 页---------------
#
# ---------------第 37 页---------------
#
# ---------------第 38 页---------------
#
# ---------------第 39 页---------------
#
# ---------------第 40 页---------------
#
# ---------------第 41 页---------------
#
# ---------------第 42 页---------------
#
# ---------------第 43 页---------------
#
# ---------------第 44 页---------------
#
# ---------------第 45 页---------------
#
# ---------------第 46 页---------------
#
# ---------------第 47 页---------------
#
# ---------------第 48 页---------------
#
# ---------------第 49 页---------------
#
# ---------------第 50 页---------------
#
# ---------------第 51 页---------------
#
# ---------------第 52 页---------------
#
# ---------------第 53 页---------------

# %%
import json
import time
import requests

headers = {
    'Host': 'music.163.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
}

def get_comments(page):
    """获取评论信息"""
    # 评论API地址
    url = 'http://music.163.com/api/v1/resource/comments/R_SO_4_2640534723?limit=100&offset=' + str(page)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    result = json.loads(response.text)
    # 只提取comments的内容
    items = result['comments']
    for item in items:
        # 用户ID
        user_id = str(item['user']['userId'])
        # 4、评论时间
        pub_time = item['time']
        pub_time = time.strftime("%Y-%m-%d", time.localtime(pub_time / 1000))
        # 获取用户信息
        user_message = get_user(user_id)
        # 用户年龄
        user_age = str(user_message['age'])
        # 用户性别
        user_gender = str(user_message['gender'])
        # 用户所在地区
        user_city = str(user_message['city'])
        # 保存到本地
        with open('comments_data43.csv', 'a', encoding='utf-8-sig') as f:
            f.write(user_id + ',' + pub_time +',' + user_age + ',' + user_gender + ',' + user_city + ','  +'\n')


def get_user(user_id):
    """ 获取用户注册时间"""
    data = {}
    # 用户API
    url = 'https://music.163.com/api/v1/user/detail/' + str(user_id)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    js = json.loads(response.text)
    if js['code'] == 200:
        # 性别
        data['gender'] = js['profile']['gender']
        # 年龄
        if int(js['profile']['birthday']) < 0:
            data['age'] = 0
        else:
            data['age'] = (2018 - 1970) - (int(js['profile']['birthday']) // (1000 * 365 * 24 * 3600))
        if int(data['age']) < 0:
            data['age'] = 0
        # 城市
        data['city'] = js['profile']['city']
    else:
        data['gender'] = '无'
        data['age'] = '无'
        data['city'] = '无'
    return data

def main():
    for i in range(0, 1050, 20):
        print('\n---------------第 ' + str(i // 20 + 1) + ' 页---------------')
        get_comments(i)

if __name__ == '__main__':
    main()
# Out:
# ---------------第 1 页---------------
#
# ---------------第 2 页---------------
#
# ---------------第 3 页---------------
#
# ---------------第 4 页---------------
#
# ---------------第 5 页---------------
#
# ---------------第 6 页---------------
#
# ---------------第 7 页---------------
#
# ---------------第 8 页---------------
#
# ---------------第 9 页---------------
#
# ---------------第 10 页---------------
#
# ---------------第 11 页---------------
#
# ---------------第 12 页---------------
#
# ---------------第 13 页---------------
#
# ---------------第 14 页---------------
#
# ---------------第 15 页---------------
#
# ---------------第 16 页---------------
#
# ---------------第 17 页---------------
#
# ---------------第 18 页---------------
#
# ---------------第 19 页---------------
#
# ---------------第 20 页---------------
#
# ---------------第 21 页---------------
#
# ---------------第 22 页---------------
#
# ---------------第 23 页---------------
#
# ---------------第 24 页---------------
#
# ---------------第 25 页---------------
#
# ---------------第 26 页---------------
#
# ---------------第 27 页---------------
#
# ---------------第 28 页---------------
#
# ---------------第 29 页---------------
#
# ---------------第 30 页---------------
#
# ---------------第 31 页---------------
#
# ---------------第 32 页---------------
#
# ---------------第 33 页---------------
#
# ---------------第 34 页---------------
#
# ---------------第 35 页---------------
#
# ---------------第 36 页---------------
#
# ---------------第 37 页---------------
#
# ---------------第 38 页---------------
#
# ---------------第 39 页---------------
#
# ---------------第 40 页---------------
#
# ---------------第 41 页---------------
#
# ---------------第 42 页---------------
#
# ---------------第 43 页---------------
#
# ---------------第 44 页---------------
#
# ---------------第 45 页---------------
#
# ---------------第 46 页---------------
#
# ---------------第 47 页---------------
#
# ---------------第 48 页---------------
#
# ---------------第 49 页---------------
#
# ---------------第 50 页---------------
#
# ---------------第 51 页---------------
#
# ---------------第 52 页---------------
#
# ---------------第 53 页---------------

# %%
import json
import time
import requests

headers = {
    'Host': 'music.163.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
}

def get_comments(page):
    """获取评论信息"""
    # 评论API地址
    url = 'http://music.163.com/api/v1/resource/comments/R_SO_4_2639711405?limit=100&offset=' + str(page)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    result = json.loads(response.text)
    # 只提取comments的内容
    items = result['comments']
    for item in items:
        # 用户ID
        user_id = str(item['user']['userId'])
        # 4、评论时间
        pub_time = item['time']
        pub_time = time.strftime("%Y-%m-%d", time.localtime(pub_time / 1000))
        # 获取用户信息
        user_message = get_user(user_id)
        # 用户年龄
        user_age = str(user_message['age'])
        # 用户性别
        user_gender = str(user_message['gender'])
        # 用户所在地区
        user_city = str(user_message['city'])
        # 保存到本地
        with open('comments_data44.csv', 'a', encoding='utf-8-sig') as f:
            f.write(user_id + ',' + pub_time +',' + user_age + ',' + user_gender + ',' + user_city + ','  +'\n')


def get_user(user_id):
    """ 获取用户注册时间"""
    data = {}
    # 用户API
    url = 'https://music.163.com/api/v1/user/detail/' + str(user_id)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    js = json.loads(response.text)
    if js['code'] == 200:
        # 性别
        data['gender'] = js['profile']['gender']
        # 年龄
        if int(js['profile']['birthday']) < 0:
            data['age'] = 0
        else:
            data['age'] = (2018 - 1970) - (int(js['profile']['birthday']) // (1000 * 365 * 24 * 3600))
        if int(data['age']) < 0:
            data['age'] = 0
        # 城市
        data['city'] = js['profile']['city']
    else:
        data['gender'] = '无'
        data['age'] = '无'
        data['city'] = '无'
    return data

def main():
    for i in range(0, 1050, 20):
        print('\n---------------第 ' + str(i // 20 + 1) + ' 页---------------')
        get_comments(i)

if __name__ == '__main__':
    main()
# Out:
# ---------------第 1 页---------------
#
# ---------------第 2 页---------------
#
# ---------------第 3 页---------------
#
# ---------------第 4 页---------------
#
# ---------------第 5 页---------------
#
# ---------------第 6 页---------------
#
# ---------------第 7 页---------------
#
# ---------------第 8 页---------------
#
# ---------------第 9 页---------------
#
# ---------------第 10 页---------------
#
# ---------------第 11 页---------------
#
# ---------------第 12 页---------------
#
# ---------------第 13 页---------------
#
# ---------------第 14 页---------------
#
# ---------------第 15 页---------------
#
# ---------------第 16 页---------------
#
# ---------------第 17 页---------------
#
# ---------------第 18 页---------------
#
# ---------------第 19 页---------------
#
# ---------------第 20 页---------------
#
# ---------------第 21 页---------------
#
# ---------------第 22 页---------------
#
# ---------------第 23 页---------------
#
# ---------------第 24 页---------------
#
# ---------------第 25 页---------------
#
# ---------------第 26 页---------------
#
# ---------------第 27 页---------------
#
# ---------------第 28 页---------------
#
# ---------------第 29 页---------------
#
# ---------------第 30 页---------------
#
# ---------------第 31 页---------------
#
# ---------------第 32 页---------------
#
# ---------------第 33 页---------------
#
# ---------------第 34 页---------------
#
# ---------------第 35 页---------------
#
# ---------------第 36 页---------------
#
# ---------------第 37 页---------------
#
# ---------------第 38 页---------------
#
# ---------------第 39 页---------------
#
# ---------------第 40 页---------------
#
# ---------------第 41 页---------------
#
# ---------------第 42 页---------------
#
# ---------------第 43 页---------------
#
# ---------------第 44 页---------------
#
# ---------------第 45 页---------------
#
# ---------------第 46 页---------------
#
# ---------------第 47 页---------------
#
# ---------------第 48 页---------------
#
# ---------------第 49 页---------------
#
# ---------------第 50 页---------------
#
# ---------------第 51 页---------------
#
# ---------------第 52 页---------------
#
# ---------------第 53 页---------------

# %%
import json
import time
import requests

headers = {
    'Host': 'music.163.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
}

def get_comments(page):
    """获取评论信息"""
    # 评论API地址
    url = 'http://music.163.com/api/v1/resource/comments/R_SO_4_2641347768?limit=100&offset=' + str(page)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    result = json.loads(response.text)
    # 只提取comments的内容
    items = result['comments']
    for item in items:
        # 用户ID
        user_id = str(item['user']['userId'])
        # 4、评论时间
        pub_time = item['time']
        pub_time = time.strftime("%Y-%m-%d", time.localtime(pub_time / 1000))
        # 获取用户信息
        user_message = get_user(user_id)
        # 用户年龄
        user_age = str(user_message['age'])
        # 用户性别
        user_gender = str(user_message['gender'])
        # 用户所在地区
        user_city = str(user_message['city'])
        # 保存到本地
        with open('comments_data45.csv', 'a', encoding='utf-8-sig') as f:
            f.write(user_id + ',' + pub_time +',' + user_age + ',' + user_gender + ',' + user_city + ','  +'\n')


def get_user(user_id):
    """ 获取用户注册时间"""
    data = {}
    # 用户API
    url = 'https://music.163.com/api/v1/user/detail/' + str(user_id)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    js = json.loads(response.text)
    if js['code'] == 200:
        # 性别
        data['gender'] = js['profile']['gender']
        # 年龄
        if int(js['profile']['birthday']) < 0:
            data['age'] = 0
        else:
            data['age'] = (2018 - 1970) - (int(js['profile']['birthday']) // (1000 * 365 * 24 * 3600))
        if int(data['age']) < 0:
            data['age'] = 0
        # 城市
        data['city'] = js['profile']['city']
    else:
        data['gender'] = '无'
        data['age'] = '无'
        data['city'] = '无'
    return data

def main():
    for i in range(0, 1050, 20):
        print('\n---------------第 ' + str(i // 20 + 1) + ' 页---------------')
        get_comments(i)

if __name__ == '__main__':
    main()
# Out:
# ---------------第 1 页---------------
#
# ---------------第 2 页---------------
#
# ---------------第 3 页---------------
#
# ---------------第 4 页---------------
#
# ---------------第 5 页---------------
#
# ---------------第 6 页---------------
#
# ---------------第 7 页---------------
#
# ---------------第 8 页---------------
#
# ---------------第 9 页---------------
#
# ---------------第 10 页---------------
#
# ---------------第 11 页---------------
#
# ---------------第 12 页---------------
#
# ---------------第 13 页---------------
#
# ---------------第 14 页---------------
#
# ---------------第 15 页---------------
#
# ---------------第 16 页---------------
#
# ---------------第 17 页---------------
#
# ---------------第 18 页---------------
#
# ---------------第 19 页---------------
#
# ---------------第 20 页---------------
#
# ---------------第 21 页---------------
#
# ---------------第 22 页---------------
#
# ---------------第 23 页---------------
#
# ---------------第 24 页---------------
#
# ---------------第 25 页---------------
#
# ---------------第 26 页---------------
#
# ---------------第 27 页---------------
#
# ---------------第 28 页---------------
#
# ---------------第 29 页---------------
#
# ---------------第 30 页---------------
#
# ---------------第 31 页---------------
#
# ---------------第 32 页---------------
#
# ---------------第 33 页---------------
#
# ---------------第 34 页---------------
#
# ---------------第 35 页---------------
#
# ---------------第 36 页---------------
#
# ---------------第 37 页---------------
#
# ---------------第 38 页---------------
#
# ---------------第 39 页---------------
#
# ---------------第 40 页---------------
#
# ---------------第 41 页---------------
#
# ---------------第 42 页---------------
#
# ---------------第 43 页---------------
#
# ---------------第 44 页---------------
#
# ---------------第 45 页---------------
#
# ---------------第 46 页---------------
#
# ---------------第 47 页---------------
#
# ---------------第 48 页---------------
#
# ---------------第 49 页---------------
#
# ---------------第 50 页---------------
#
# ---------------第 51 页---------------
#
# ---------------第 52 页---------------
#
# ---------------第 53 页---------------

# %%
import json
import time
import requests

headers = {
    'Host': 'music.163.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
}

def get_comments(page):
    """获取评论信息"""
    # 评论API地址
    url = 'http://music.163.com/api/v1/resource/comments/R_SO_4_2639636157?limit=100&offset=' + str(page)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    result = json.loads(response.text)
    # 只提取comments的内容
    items = result['comments']
    for item in items:
        # 用户ID
        user_id = str(item['user']['userId'])
        # 4、评论时间
        pub_time = item['time']
        pub_time = time.strftime("%Y-%m-%d", time.localtime(pub_time / 1000))
        # 获取用户信息
        user_message = get_user(user_id)
        # 用户年龄
        user_age = str(user_message['age'])
        # 用户性别
        user_gender = str(user_message['gender'])
        # 用户所在地区
        user_city = str(user_message['city'])
        # 保存到本地
        with open('comments_data46.csv', 'a', encoding='utf-8-sig') as f:
            f.write(user_id + ',' + pub_time +',' + user_age + ',' + user_gender + ',' + user_city + ','  +'\n')


def get_user(user_id):
    """ 获取用户注册时间"""
    data = {}
    # 用户API
    url = 'https://music.163.com/api/v1/user/detail/' + str(user_id)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    js = json.loads(response.text)
    if js['code'] == 200:
        # 性别
        data['gender'] = js['profile']['gender']
        # 年龄
        if int(js['profile']['birthday']) < 0:
            data['age'] = 0
        else:
            data['age'] = (2018 - 1970) - (int(js['profile']['birthday']) // (1000 * 365 * 24 * 3600))
        if int(data['age']) < 0:
            data['age'] = 0
        # 城市
        data['city'] = js['profile']['city']
    else:
        data['gender'] = '无'
        data['age'] = '无'
        data['city'] = '无'
    return data

def main():
    for i in range(0, 1050, 20):
        print('\n---------------第 ' + str(i // 20 + 1) + ' 页---------------')
        get_comments(i)

if __name__ == '__main__':
    main()
# Out:
# ---------------第 1 页---------------
#
# ---------------第 2 页---------------
#
# ---------------第 3 页---------------
#
# ---------------第 4 页---------------
#
# ---------------第 5 页---------------
#
# ---------------第 6 页---------------
#
# ---------------第 7 页---------------
#
# ---------------第 8 页---------------
#
# ---------------第 9 页---------------
#
# ---------------第 10 页---------------
#
# ---------------第 11 页---------------
#
# ---------------第 12 页---------------
#
# ---------------第 13 页---------------
#
# ---------------第 14 页---------------
#
# ---------------第 15 页---------------
#
# ---------------第 16 页---------------
#
# ---------------第 17 页---------------
#
# ---------------第 18 页---------------
#
# ---------------第 19 页---------------
#
# ---------------第 20 页---------------
#
# ---------------第 21 页---------------
#
# ---------------第 22 页---------------
#
# ---------------第 23 页---------------
#
# ---------------第 24 页---------------
#
# ---------------第 25 页---------------
#
# ---------------第 26 页---------------
#
# ---------------第 27 页---------------
#
# ---------------第 28 页---------------
#
# ---------------第 29 页---------------
#
# ---------------第 30 页---------------
#
# ---------------第 31 页---------------
#
# ---------------第 32 页---------------
#
# ---------------第 33 页---------------
#
# ---------------第 34 页---------------
#
# ---------------第 35 页---------------
#
# ---------------第 36 页---------------
#
# ---------------第 37 页---------------
#
# ---------------第 38 页---------------
#
# ---------------第 39 页---------------
#
# ---------------第 40 页---------------
#
# ---------------第 41 页---------------
#
# ---------------第 42 页---------------
#
# ---------------第 43 页---------------
#
# ---------------第 44 页---------------
#
# ---------------第 45 页---------------
#
# ---------------第 46 页---------------
#
# ---------------第 47 页---------------
#
# ---------------第 48 页---------------
#
# ---------------第 49 页---------------
#
# ---------------第 50 页---------------
#
# ---------------第 51 页---------------
#
# ---------------第 52 页---------------
#
# ---------------第 53 页---------------

# %%
import json
import time
import requests

headers = {
    'Host': 'music.163.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
}

def get_comments(page):
    """获取评论信息"""
    # 评论API地址
    url = 'http://music.163.com/api/v1/resource/comments/R_SO_4_2640512689?limit=100&offset=' + str(page)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    result = json.loads(response.text)
    # 只提取comments的内容
    items = result['comments']
    for item in items:
        # 用户ID
        user_id = str(item['user']['userId'])
        # 4、评论时间
        pub_time = item['time']
        pub_time = time.strftime("%Y-%m-%d", time.localtime(pub_time / 1000))
        # 获取用户信息
        user_message = get_user(user_id)
        # 用户年龄
        user_age = str(user_message['age'])
        # 用户性别
        user_gender = str(user_message['gender'])
        # 用户所在地区
        user_city = str(user_message['city'])
        # 保存到本地
        with open('comments_data47.csv', 'a', encoding='utf-8-sig') as f:
            f.write(user_id + ',' + pub_time +',' + user_age + ',' + user_gender + ',' + user_city + ','  +'\n')


def get_user(user_id):
    """ 获取用户注册时间"""
    data = {}
    # 用户API
    url = 'https://music.163.com/api/v1/user/detail/' + str(user_id)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    js = json.loads(response.text)
    if js['code'] == 200:
        # 性别
        data['gender'] = js['profile']['gender']
        # 年龄
        if int(js['profile']['birthday']) < 0:
            data['age'] = 0
        else:
            data['age'] = (2018 - 1970) - (int(js['profile']['birthday']) // (1000 * 365 * 24 * 3600))
        if int(data['age']) < 0:
            data['age'] = 0
        # 城市
        data['city'] = js['profile']['city']
    else:
        data['gender'] = '无'
        data['age'] = '无'
        data['city'] = '无'
    return data

def main():
    for i in range(0, 1050, 20):
        print('\n---------------第 ' + str(i // 20 + 1) + ' 页---------------')
        get_comments(i)

if __name__ == '__main__':
    main()
# Out:
# ---------------第 1 页---------------
#
# ---------------第 2 页---------------
#
# ---------------第 3 页---------------
#
# ---------------第 4 页---------------
#
# ---------------第 5 页---------------
#
# ---------------第 6 页---------------
#
# ---------------第 7 页---------------
#
# ---------------第 8 页---------------
#
# ---------------第 9 页---------------
#
# ---------------第 10 页---------------
#
# ---------------第 11 页---------------
#
# ---------------第 12 页---------------
#
# ---------------第 13 页---------------
#
# ---------------第 14 页---------------
#
# ---------------第 15 页---------------
#
# ---------------第 16 页---------------
#
# ---------------第 17 页---------------
#
# ---------------第 18 页---------------
#
# ---------------第 19 页---------------
#
# ---------------第 20 页---------------
#
# ---------------第 21 页---------------
#
# ---------------第 22 页---------------
#
# ---------------第 23 页---------------
#
# ---------------第 24 页---------------
#
# ---------------第 25 页---------------
#
# ---------------第 26 页---------------
#
# ---------------第 27 页---------------
#
# ---------------第 28 页---------------
#
# ---------------第 29 页---------------
#
# ---------------第 30 页---------------
#
# ---------------第 31 页---------------
#
# ---------------第 32 页---------------
#
# ---------------第 33 页---------------
#
# ---------------第 34 页---------------
#
# ---------------第 35 页---------------
#
# ---------------第 36 页---------------
#
# ---------------第 37 页---------------
#
# ---------------第 38 页---------------
#
# ---------------第 39 页---------------
#
# ---------------第 40 页---------------
#
# ---------------第 41 页---------------
#
# ---------------第 42 页---------------
#
# ---------------第 43 页---------------
#
# ---------------第 44 页---------------
#
# ---------------第 45 页---------------
#
# ---------------第 46 页---------------
#
# ---------------第 47 页---------------
#
# ---------------第 48 页---------------
#
# ---------------第 49 页---------------
#
# ---------------第 50 页---------------
#
# ---------------第 51 页---------------
#
# ---------------第 52 页---------------
#
# ---------------第 53 页---------------

# %%
import json
import time
import requests

headers = {
    'Host': 'music.163.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
}

def get_comments(page):
    """获取评论信息"""
    # 评论API地址
    url = 'http://music.163.com/api/v1/resource/comments/R_SO_4_2639723874?limit=100&offset=' + str(page)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    result = json.loads(response.text)
    # 只提取comments的内容
    items = result['comments']
    for item in items:
        # 用户ID
        user_id = str(item['user']['userId'])
        # 4、评论时间
        pub_time = item['time']
        pub_time = time.strftime("%Y-%m-%d", time.localtime(pub_time / 1000))
        # 获取用户信息
        user_message = get_user(user_id)
        # 用户年龄
        user_age = str(user_message['age'])
        # 用户性别
        user_gender = str(user_message['gender'])
        # 用户所在地区
        user_city = str(user_message['city'])
        # 保存到本地
        with open('comments_data48.csv', 'a', encoding='utf-8-sig') as f:
            f.write(user_id + ',' + pub_time +',' + user_age + ',' + user_gender + ',' + user_city + ','  +'\n')


def get_user(user_id):
    """ 获取用户注册时间"""
    data = {}
    # 用户API
    url = 'https://music.163.com/api/v1/user/detail/' + str(user_id)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    js = json.loads(response.text)
    if js['code'] == 200:
        # 性别
        data['gender'] = js['profile']['gender']
        # 年龄
        if int(js['profile']['birthday']) < 0:
            data['age'] = 0
        else:
            data['age'] = (2018 - 1970) - (int(js['profile']['birthday']) // (1000 * 365 * 24 * 3600))
        if int(data['age']) < 0:
            data['age'] = 0
        # 城市
        data['city'] = js['profile']['city']
    else:
        data['gender'] = '无'
        data['age'] = '无'
        data['city'] = '无'
    return data

def main():
    for i in range(0, 1050, 20):
        print('\n---------------第 ' + str(i // 20 + 1) + ' 页---------------')
        get_comments(i)

if __name__ == '__main__':
    main()
# Out:
# ---------------第 1 页---------------
#
# ---------------第 2 页---------------
#
# ---------------第 3 页---------------
#
# ---------------第 4 页---------------
#
# ---------------第 5 页---------------
#
# ---------------第 6 页---------------
#
# ---------------第 7 页---------------
#
# ---------------第 8 页---------------
#
# ---------------第 9 页---------------
#
# ---------------第 10 页---------------
#
# ---------------第 11 页---------------
#
# ---------------第 12 页---------------
#
# ---------------第 13 页---------------
#
# ---------------第 14 页---------------
#
# ---------------第 15 页---------------
#
# ---------------第 16 页---------------
#
# ---------------第 17 页---------------
#
# ---------------第 18 页---------------
#
# ---------------第 19 页---------------
#
# ---------------第 20 页---------------
#
# ---------------第 21 页---------------
#
# ---------------第 22 页---------------
#
# ---------------第 23 页---------------
#
# ---------------第 24 页---------------
#
# ---------------第 25 页---------------
#
# ---------------第 26 页---------------
#
# ---------------第 27 页---------------
#
# ---------------第 28 页---------------
#
# ---------------第 29 页---------------
#
# ---------------第 30 页---------------
#
# ---------------第 31 页---------------
#
# ---------------第 32 页---------------
#
# ---------------第 33 页---------------
#
# ---------------第 34 页---------------
#
# ---------------第 35 页---------------
#
# ---------------第 36 页---------------
#
# ---------------第 37 页---------------
#
# ---------------第 38 页---------------
#
# ---------------第 39 页---------------
#
# ---------------第 40 页---------------
#
# ---------------第 41 页---------------
#
# ---------------第 42 页---------------
#
# ---------------第 43 页---------------
#
# ---------------第 44 页---------------
#
# ---------------第 45 页---------------
#
# ---------------第 46 页---------------
#
# ---------------第 47 页---------------
#
# ---------------第 48 页---------------
#
# ---------------第 49 页---------------
#
# ---------------第 50 页---------------
#
# ---------------第 51 页---------------
#
# ---------------第 52 页---------------
#
# ---------------第 53 页---------------

# %%
import json
import time
import requests

headers = {
    'Host': 'music.163.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
}

def get_comments(page):
    """获取评论信息"""
    # 评论API地址
    url = 'http://music.163.com/api/v1/resource/comments/R_SO_4_2640997675?limit=100&offset=' + str(page)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    result = json.loads(response.text)
    # 只提取comments的内容
    items = result['comments']
    for item in items:
        # 用户ID
        user_id = str(item['user']['userId'])
        # 4、评论时间
        pub_time = item['time']
        pub_time = time.strftime("%Y-%m-%d", time.localtime(pub_time / 1000))
        # 获取用户信息
        user_message = get_user(user_id)
        # 用户年龄
        user_age = str(user_message['age'])
        # 用户性别
        user_gender = str(user_message['gender'])
        # 用户所在地区
        user_city = str(user_message['city'])
        # 保存到本地
        with open('comments_data49.csv', 'a', encoding='utf-8-sig') as f:
            f.write(user_id + ',' + pub_time +',' + user_age + ',' + user_gender + ',' + user_city + ','  +'\n')


def get_user(user_id):
    """ 获取用户注册时间"""
    data = {}
    # 用户API
    url = 'https://music.163.com/api/v1/user/detail/' + str(user_id)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    js = json.loads(response.text)
    if js['code'] == 200:
        # 性别
        data['gender'] = js['profile']['gender']
        # 年龄
        if int(js['profile']['birthday']) < 0:
            data['age'] = 0
        else:
            data['age'] = (2018 - 1970) - (int(js['profile']['birthday']) // (1000 * 365 * 24 * 3600))
        if int(data['age']) < 0:
            data['age'] = 0
        # 城市
        data['city'] = js['profile']['city']
    else:
        data['gender'] = '无'
        data['age'] = '无'
        data['city'] = '无'
    return data

def main():
    for i in range(0, 1050, 20):
        print('\n---------------第 ' + str(i // 20 + 1) + ' 页---------------')
        get_comments(i)

if __name__ == '__main__':
    main()
# Out:
# ---------------第 1 页---------------
#
# ---------------第 2 页---------------
#
# ---------------第 3 页---------------
#
# ---------------第 4 页---------------
#
# ---------------第 5 页---------------
#
# ---------------第 6 页---------------
#
# ---------------第 7 页---------------
#
# ---------------第 8 页---------------
#
# ---------------第 9 页---------------
#
# ---------------第 10 页---------------
#
# ---------------第 11 页---------------
#
# ---------------第 12 页---------------
#
# ---------------第 13 页---------------
#
# ---------------第 14 页---------------
#
# ---------------第 15 页---------------
#
# ---------------第 16 页---------------
#
# ---------------第 17 页---------------
#
# ---------------第 18 页---------------
#
# ---------------第 19 页---------------
#
# ---------------第 20 页---------------
#
# ---------------第 21 页---------------
#
# ---------------第 22 页---------------
#
# ---------------第 23 页---------------
#
# ---------------第 24 页---------------
#
# ---------------第 25 页---------------
#
# ---------------第 26 页---------------
#
# ---------------第 27 页---------------
#
# ---------------第 28 页---------------
#
# ---------------第 29 页---------------
#
# ---------------第 30 页---------------
#
# ---------------第 31 页---------------
#
# ---------------第 32 页---------------
#
# ---------------第 33 页---------------
#
# ---------------第 34 页---------------
#
# ---------------第 35 页---------------
#
# ---------------第 36 页---------------
#
# ---------------第 37 页---------------
#
# ---------------第 38 页---------------
#
# ---------------第 39 页---------------
#
# ---------------第 40 页---------------
#
# ---------------第 41 页---------------
#
# ---------------第 42 页---------------
#
# ---------------第 43 页---------------
#
# ---------------第 44 页---------------
#
# ---------------第 45 页---------------
#
# ---------------第 46 页---------------
#
# ---------------第 47 页---------------
#
# ---------------第 48 页---------------
#
# ---------------第 49 页---------------
#
# ---------------第 50 页---------------
#
# ---------------第 51 页---------------
#
# ---------------第 52 页---------------
#
# ---------------第 53 页---------------

# %%
import json
import time
import requests

headers = {
    'Host': 'music.163.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
}

def get_comments(page):
    """获取评论信息"""
    # 评论API地址
    url = 'http://music.163.com/api/v1/resource/comments/R_SO_4_2639350114?limit=100&offset=' + str(page)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    result = json.loads(response.text)
    # 只提取comments的内容
    items = result['comments']
    for item in items:
        # 用户ID
        user_id = str(item['user']['userId'])
        # 4、评论时间
        pub_time = item['time']
        pub_time = time.strftime("%Y-%m-%d", time.localtime(pub_time / 1000))
        # 获取用户信息
        user_message = get_user(user_id)
        # 用户年龄
        user_age = str(user_message['age'])
        # 用户性别
        user_gender = str(user_message['gender'])
        # 用户所在地区
        user_city = str(user_message['city'])
        # 保存到本地
        with open('comments_data50.csv', 'a', encoding='utf-8-sig') as f:
            f.write(user_id + ',' + pub_time +',' + user_age + ',' + user_gender + ',' + user_city + ','  +'\n')


def get_user(user_id):
    """ 获取用户注册时间"""
    data = {}
    # 用户API
    url = 'https://music.163.com/api/v1/user/detail/' + str(user_id)
    response = requests.get(url=url, headers=headers)
    # 将字符串转为json格式
    js = json.loads(response.text)
    if js['code'] == 200:
        # 性别
        data['gender'] = js['profile']['gender']
        # 年龄
        if int(js['profile']['birthday']) < 0:
            data['age'] = 0
        else:
            data['age'] = (2018 - 1970) - (int(js['profile']['birthday']) // (1000 * 365 * 24 * 3600))
        if int(data['age']) < 0:
            data['age'] = 0
        # 城市
        data['city'] = js['profile']['city']
    else:
        data['gender'] = '无'
        data['age'] = '无'
        data['city'] = '无'
    return data

def main():
    for i in range(0, 1050, 20):
        print('\n---------------第 ' + str(i // 20 + 1) + ' 页---------------')
        get_comments(i)

if __name__ == '__main__':
    main()
# Out:
# ---------------第 1 页---------------
#
# ---------------第 2 页---------------
#
# ---------------第 3 页---------------
#
# ---------------第 4 页---------------
#
# ---------------第 5 页---------------
#
# ---------------第 6 页---------------
#
# ---------------第 7 页---------------
#
# ---------------第 8 页---------------
#
# ---------------第 9 页---------------
#
# ---------------第 10 页---------------
#
# ---------------第 11 页---------------
#
# ---------------第 12 页---------------
#
# ---------------第 13 页---------------
#
# ---------------第 14 页---------------
#
# ---------------第 15 页---------------
#
# ---------------第 16 页---------------
#
# ---------------第 17 页---------------
#
# ---------------第 18 页---------------
#
# ---------------第 19 页---------------
#
# ---------------第 20 页---------------
#
# ---------------第 21 页---------------
#
# ---------------第 22 页---------------
#
# ---------------第 23 页---------------
#
# ---------------第 24 页---------------
#
# ---------------第 25 页---------------
#
# ---------------第 26 页---------------
#
# ---------------第 27 页---------------
#
# ---------------第 28 页---------------
#
# ---------------第 29 页---------------
#
# ---------------第 30 页---------------
#
# ---------------第 31 页---------------
#
# ---------------第 32 页---------------
#
# ---------------第 33 页---------------
#
# ---------------第 34 页---------------
#
# ---------------第 35 页---------------
#
# ---------------第 36 页---------------
#
# ---------------第 37 页---------------
#
# ---------------第 38 页---------------
#
# ---------------第 39 页---------------
#
# ---------------第 40 页---------------
#
# ---------------第 41 页---------------
#
# ---------------第 42 页---------------
#
# ---------------第 43 页---------------
#
# ---------------第 44 页---------------
#
# ---------------第 45 页---------------
#
# ---------------第 46 页---------------
#
# ---------------第 47 页---------------
#
# ---------------第 48 页---------------
#
# ---------------第 49 页---------------
#
# ---------------第 50 页---------------
#
# ---------------第 51 页---------------
#
# ---------------第 52 页---------------
#
# ---------------第 53 页---------------
